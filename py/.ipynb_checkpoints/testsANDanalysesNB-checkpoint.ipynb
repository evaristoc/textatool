# %% [markdown]
# ### Starting with the analysis
#
# Calling global packages

# %%
import sys, os

from dotenv import load_dotenv
load_dotenv(dotenv_path='../.env')
load_dotenv()

import pickle, json
import time
import processingData
import collections, itertools, copy, operator

import nltk
import pandas
import gensim
import sklearn
import re
import string
import math
import scipy
import numpy
# Out:
# in the other hello\nworld
# Using TensorFlow backend.

# %% [markdown]
# # IN processingData.py

# %% [markdown]
# ### Packages

# %%
import os
import re
import nltk
import json
print("in the other",os.getenv("TEST_MULTILINE_VAR"))
nltk.data.path.append(os.getenv("NLTKDATADIR"))
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
import copy
import math
# Out:
# in the other hello\nworld

# %% [markdown]
# ### Functions for first Data Preparation adding POS

# %%
############################
## allrecordsPreparation 1: original
############################

def allrecordsPreparation1(allrecords):
    '''
    description: tokenization and POS tagging
    input: dict of allrecords texts and data from different sources
    treatment: separating only those with posts in the forum and tokenizing the posts
    output:
    1) list of lists, each with:
    -- id
    -- username
    -- link of the post
    -- tokenized text
    -- POS tagged text
    2) list of post ids
    '''
    print('in allrecordsPreparation (len(allrecords))::',len(allrecords))
    #global var to this scope
    #forum_tonltk = []
    tktexts = []
    soup_forum = None
    forum_ids = []
    all_posedsts = []
    count = 0
    for u in allrecords:
        #block arguments
        record = u["data"]
        forumpost = record['forum']['foundjob_msg']['text']
        if forumpost == '':
            continue
        forumpostID = record['forum']['foundjob_msg']['id']
        forumpostLINK = record['forum']['foundjob_msg']['link']
        soup_forumpost = BeautifulSoup(forumpost)
        soup_forumpostTEXT = soup_forumpost.find('body').get_text()
        tksoup_forumpostTEXT = nltk.word_tokenize(soup_forumpostTEXT)

        #forum_tonltk.append(soup_forumpostTEXT)

        #listoftexts_forum.append(('f_'+forumpostID,
        #                          [w.lower() for w in tksoup_forumpostTEXT],
        #                          forumpostLINK,
        #                          u))

        modtext = []
        
        ## Get an approximation of sentences
        for w in tksoup_forumpostTEXT:
            w = w.lower()
            rws = []
            if len(w) > 1 and len({'.','-',':'}.intersection(w)) >= 1:
                #print(w)
                for punc in {'.','-',':'}.intersection(w):
                    rws = w.replace(punc, ' '+punc+' ').split()
                #print(rws)
            if len(rws) == 0:
                modtext.append(w)
            else:
                for w in rws:
                    modtext.append(w)

        ## 
        #[w.lower() for w in nltk.word_tokenize(soup_forum.find('body').get_text())]
        all_posedsts.append((
                            'f_'+forumpostID,
                            u["user"],
                            forumpostLINK,
                            modtext,
                            nltk.pos_tag(modtext)
                            ))
        #forum_ids.append(forumpostID)

        count += 1

    print("number of treated posts (len(count)) ::", count)
    #return all_posedsts, forum_ids
    return all_posedsts


############################
## allrecordsPreparation 2: revision of 1
############################

def allrecordsPreparation2(allrecords):
    '''
    description: tokenization and POS tagging
    input: dict of allrecords texts and data from different sources
    treatment: separating only those with posts in the forum and tokenizing the posts
    output:
    1) list of lists, each with:
    -- id
    -- username
    -- link of the post
    -- tokenized text
    -- POS tagged text
    2) list of post ids
    '''
    print('in allrecordsPreparation (len(allrecords))::',len(allrecords))
    #global var to this scope
    #forum_tonltk = []
    tktexts = []
    soup_forum = None
    forum_ids = []
    all_lemmpostxts = []
    count = 0
    
       
    def HTMLtoText(u):
        #block arguments
        record = u["data"]
        forumpost = record['forum']['foundjob_msg']['text']
        if forumpost == '':
            return False
        forumpostID = record['forum']['foundjob_msg']['id']
        forumpostLINK = record['forum']['foundjob_msg']['link']
        soup_forumpost = BeautifulSoup(forumpost)
        soup_forumpostTEXT = soup_forumpost.find('body').get_text()
        tksoup_forumpostTEXT = nltk.word_tokenize(soup_forumpostTEXT)
        return forumpostID, forumpostLINK, tksoup_forumpostTEXT
    
    def approxsts(text):
        modtext = []
        for w in tksoup_forumpostTEXT:
            w = w.lower()
            rws = []
            if len(w) > 1 and len({'.','-',':'}.intersection(w)) >= 1:
                #print(w)
                for punc in {'.','-',':'}.intersection(w):
                    rws = w.replace(punc, ' '+punc+' ').split()
                #print(rws)
            if len(rws) == 0:
                modtext.append(w)
            else:
                for w in rws:
                    modtext.append(w)
        return modtext
    
    def lemmatizationofpos(postxt, lemmws):
        lemmposws = []
        for posw in postxt:
            w = posw[0]
            pos = posw[1]
            if nltk.corpus.wordnet.synsets(w):
                try:
                    n = ''
                    if nltk.corpus.wordnet.synsets(w,pos[0].lower())[0].root_hypernyms()[0].name().split('.')[0] == 'entity':
                        n = w
                    else:
                        n = nltk.corpus.wordnet.synsets(w,pos[0].lower())[0].root_hypernyms()[0].name().split('.')[0]
                    if pos[0] == 'V':
                        n = nltk.stem.wordnet.WordNetLemmatizer().lemmatize(w,'v')
                    if pos == 'NNS' or pos == 'NN$':
                        n = nltk.stem.wordnet.WordNetLemmatizer().lemmatize(w)
                    #print(w, nltk.corpus.wordnet.synsets(w,pos[0].lower())[0].root_hypernyms(), n)
                    lemmposws.append((w,True,n,pos))
                    lemmws.append(n)
                except KeyError: #in some cases the POS tag is not recognised by wordnet synset
                    print("pos KeyErrors", w,pos)
                    lemmposws.append((w,False,w,pos))
                    lemmws.append(w)
                except IndexError:
                    print("IndexErrors (not found)", w,pos) #in some cases (w,pos) pair was not found at some point of the synsets root hyernyms
                    #print(nltk.corpus.wordnet.synsets(w,pos[0].lower()))
                    lemmposws.append((w,False,w,pos))
                    lemmws.append(w)
            else:
                #print(w, [])
                lemmposws.append((w,False,w,pos))
                lemmws.append(w)
        return lemmposws
      
    
    lemmws = []
    lemmposrecs = []
    
    for u in allrecords:
        ## Getting the data as a text from HTML format (raw dataset)
        userdata = HTMLtoText(u)
        if userdata != False:
            forumpostID, forumpostLINK, tksoup_forumpostTEXT = userdata
            
            ## Get an approximation of sentences
            modtxt = approxsts(tksoup_forumpostTEXT)
            
            ## POS
            postxt = nltk.pos_tag(modtxt)
            
            ## Lemm text
            lemmpostxt = lemmatizationofpos(postxt,lemmws)
            
            ## Adding data to the new created dataset
            lemmposrecs.append((
                            'f_'+forumpostID,
                            u["user"],
                            forumpostLINK,
                            lemmpostxt
                            ))

    print("number of treated posts (len(count)) ::", count)
    #return all_posedsts, forum_ids
    return lemmposrecs, nltk.FreqDist(lemmws)

# %% [markdown]
# ### Functions for Lemmatized Dataset

# %%
############################
## allrecordsLemmatization1: original
############################

def allrecordsLemmatization1(all_posedsts):
    '''
    description: lemmatization
    input: list of tokenized texts (sentences)
    output:
        1) same list of texts but each with the lematized words when found
        2) freqDist of the words after trying lematization
    '''
    all_lemmposedsts = []
    lemmposedwords = []

    print("-"*15+"\nFails to lematize will be printed below\n"+"-"*15)
    for posedpost in all_posedsts:
        lemmposedws = []
        merged_posedsts = posedpost[4]
                
        for posw in  merged_posedsts:
            w = posw[0]
            pos = posw[1]
            if nltk.corpus.wordnet.synsets(w):
                try:
                    n = ''
                    if nltk.corpus.wordnet.synsets(w,pos[0].lower())[0].root_hypernyms()[0].name().split('.')[0] == 'entity':
                        n = w
                    else:
                        n = nltk.corpus.wordnet.synsets(w,pos[0].lower())[0].root_hypernyms()[0].name().split('.')[0]
                    if pos[0] == 'V':
                        n = nltk.stem.wordnet.WordNetLemmatizer().lemmatize(w,'v')
                    if pos == 'NNS' or pos == 'NN$':
                        n = nltk.stem.wordnet.WordNetLemmatizer().lemmatize(w)
                    #print(w, nltk.corpus.wordnet.synsets(w,pos[0].lower())[0].root_hypernyms(), n)
                    lemmposedws.append(n)
                    lemmposedwords.append(n)
                except KeyError: #in some cases the POS tag is not recognised by wordnet synset
                    print("pos KeyErrors", w,pos)
                    lemmposedws.append(w)
                    lemmposedwords.append(w)
                except IndexError:
                    print("IndexErrors (not found)", w,pos) #in some cases (w,pos) pair was not found at some point of the synsets root hyernyms
                    #print(nltk.corpus.wordnet.synsets(w,pos[0].lower()))
                    lemmposedws.append(w)
                    lemmposedwords.append(w)                    
            else:
                #print(w, [])
                lemmposedws.append(w)
                lemmposedwords.append(w)
        
        all_lemmposedsts.append(lemmposedws)
    
    all_fd = nltk.FreqDist(lemmposedwords)
    
    return all_posedsts, all_lemmposedsts, all_fd

# %% [markdown]
# ### Words Importance metrics

# %%
############################
## wordimportance_var1: original
############################
def wordimportance_var1(all_lemmposedsts, all_fd):
    '''
    description:
    
    This metric was originally called "enlargedopacity"; renamed as wordimportance_var1.
    
    "enlargedopacity" is just a variation of the TF-IDF metric to measure word importance; the naming is just arbitrary and related to its use in this specific project.
    
    The importance of a word in this case is based on the combined effect of two metrics:
    --- opacity: 1 - total count of word against total count of the most frequent word (1 - log(f_w)/log(f_maxw)):
        this range between [0,1); the metric will penalize those words that are too frequent in the corpus, giving it a small value (close to 0)
    --- sizing: 1 - (max count of a word in a text) / (total count of the word in all texts):
        this range between [0,1); this metric is mostly a dispersion metric: the smaller the value, the larger the likelihood
        that the word concentrates in only one text; it also penalises very rare words

    opacity is about a complement of a TF variation (a standard TF is corpus' term frequency).
    
    sizing is about a complement of a IDF variation (a standard IDF is log( (Total Documents) / (Documents containing the term) )).
 
    While opacity will favour the less frequent words, sizing will adjust opacity so those that are too concentrated in very few texts (too rare) get penalized.
   
    Using sizing as dispersion metric, words that are more common between different text receive better ranking.

    "enlargedopacity" is the product of the frequency of the word against the most frequent word by its dispersion in the corpus, just like TF-IDF.
    Its calculation doesn't deviate much from other variations of the standard metric (https://en.wikipedia.org/wiki/Tf%E2%80%93idf).
      
    The idea is to highlight those words that are more shared in the corpus without being too frequent ones. Those are more like (shared) topic words.

    However:
    --- Be aware that the metric is not normalized by text's length: the effect of the frequent appearance of a word because the text is long is not considered
        This could affect mostly the dispersion metric.
    --- The metric favours words that are shared; for topic modelling it will excludes words that define topics specific to few texts
    --- The metrics assign value of (close to) 0 to penalised words: that makes those words to dissappear from the radar; it is like a hard L1 measure 
    --- In fact, it assigns value of 0 to less and very frequent words, suggesting they are the same when they are not
    
    input:
        1) tokenized list of texts
        2) freqDist of lemmatized words
    
    output: wordimportance_var1 
    '''

    maxdiv = math.log(sorted(all_fd.items(), key=lambda x: x[1], reverse=True)[0][1])
    opacity = dict([(k, 1-math.log(v)/maxdiv) for k,v in all_fd.items()])
    sizing_matrix = dict([(k, [0]*len(norm_posedsts)) for k in list(all_fd.keys())])
    data_out = []
    l = 0
    for i,lemmpos_t in enumerate(all_lemmposedsts):
        for k, lemmpos_w in enumerate(lemmpos_t):
            sizing_matrix[lemmpos_w][i] = sizing_matrix[lemmpos_w][i] + 1
       
    sizing = dict([(k, 1 - max(vector)/sum(vector)) for k, vector in sizing_matrix.items()])
    
    wordimportance_var1 = dict([(k, valsizing*opacity[k]) for k, valsizing in sizing.items()])

    return wordimportance

############################
## wordimportance_var2: modified to fit my heuristic for word ranking 
############################
def wordimportance_var2(all_lemmposedsts, all_fd):
    '''
    description:
    
    This metric tries to solve some of the issues that appeared in `wordimportance_var1` metric, in particular the values of zero.
    
    This is done by setting lower bounds when required.
    
    --- In the case of opacity, a non-zero lower bound is set by changing the equation to the following:
        ```
        if 1-math.log(v)/maxdiv == 0: 1-math.log(maxdiv-1)/maxdiv # 1-math.log(v)/maxdiv == 0 if v == maxdiv
        ```
    --- In the case of sizing, a redefinition of the metric force a non-zero lower bound as well as rebumpimg rare terms in documents:
        ```
        (sum(vector)-max(vector))/sum(vector)
        ```
    
    input:
        1) tokenized list of texts
        2) freqDist of lemmatized words
    
    output: wordimportance 
    '''

    maxdiv = math.log(sorted(all_fd.items(), key=lambda x: x[1], reverse=True)[0][1])
    opacity = dict([(k, 1-math.log(v)/maxdiv) if 1-math.log(v)/maxdiv != 0 else (k,1-math.log(maxdiv-1)/maxdiv) for k,v in all_fd.items()])
    sizing_matrix = dict([(k, [0]*len(all_lemmposedsts)) for k in list(all_fd.keys())])
    data_out = []
    l = 0
    for i,lemmpos_t in enumerate(all_lemmposedsts):
        for k, lemmpos_w in enumerate(lemmpos_t):
            sizing_matrix[lemmpos_w][i] = sizing_matrix[lemmpos_w][i] + 1
       
    sizing = dict([(k, (sum(vector)-max(vector))/sum(vector)) for k, vector in sizing_matrix.items()])
    
    wordimportance = dict([(k, valsizing*opacity[k]) for k, valsizing in sizing.items()])

    return wordimportance


############################
## wordimportance_var3: wordimportance_var2 modified to fit allrecordsPreparation2
############################
def wordimportance_var3(lemmpostxts, lemmws_fd):
    '''
    description:
    
    This metric tries to solve some of the issues that appeared in `wordimportance_var1` metric, in particular the values of zero.
    
    This is done by setting lower bounds when required.
    
    --- In the case of opacity, a non-zero lower bound is set by changing the equation to the following:
        ```
        if 1-math.log(v)/maxdiv == 0: 1-math.log(maxdiv-1)/maxdiv # 1-math.log(v)/maxdiv == 0 if v == maxdiv
        ```
    --- In the case of sizing, a redefinition of the metric force a non-zero lower bound as well as rebumpimg rare terms in documents:
        ```
        (sum(vector)-max(vector))/sum(vector)
        ```
    
    input:
        1) tokenized list of texts
        2) freqDist of lemmatized words
    
    output: wordimportance 
    '''

    maxdiv = math.log(sorted(lemmws_fd.items(), key=lambda x: x[1], reverse=True)[0][1])
    opacity = dict([(k, 1-math.log(v)/maxdiv) if 1-math.log(v)/maxdiv != 0 else (k,1-math.log(maxdiv-1)/maxdiv) for k,v in lemmws_fd.items()])
    sizing_matrix = dict([(k, [0]*len(lemmpostxts)) for k in list(lemmws_fd.keys())])

    ## Count lemmatized words/characters per text  
    for i,lemmpos_t in enumerate(lemmpostxts):
        for k, lemmpos_TUPLE in enumerate(lemmpos_t):
            ## Use lemmatized word
            lemmw = lemmpos_TUPLE[2]
            sizing_matrix[lemmw][i] = sizing_matrix[lemmw][i] + 1
       
    ## Normalization
    normalization = dict([(k, (sum(vector)-max(vector))/sum(vector)) for k, vector in sizing_matrix.items()])
    
    wordimportance = dict([(k, valnorm*opacity[k]) for k, valnorm in normalization.items()])

    return wordimportance

# %% [markdown]
# # UNDER TEST

# %% [markdown]
# ## Topic Modeling

# %% [markdown]
# ### Stopwords and Punctuation removal
#
# A very simple one

# %%
def cleaningtext(st, STOPWORDS = nltk.corpus.stopwords.words('english')):
    treated_st = []
    countwds = len(st)
    for w in st:
        if re.match(r'\w+', w) and not re.match(r'\d+?', w) and w not in ('merely', 'truly') and w not in STOPWORDS:
            if w == 'freecodecamp':
                w = 'fcc'
            treated_st.append(w)
    return treated_st, countwds

# %% [markdown]
# ### Variations of Gensim Models for LSI and LDA

# %%
############################
## gensim_models1: substantial modification of original to embed data transformations within this function
############################

def gensim_models1(all_lemmposedsts, all_fd = {}, wordimportance = {}):
    NUM_TOPICS = 15
    STOPWORDS = nltk.corpus.stopwords.words('english') 
    redo_corpus_by_sts = []
    for lemmpos_t in all_lemmposedsts:
        lemmpos_sts = lemmpos_t.split('.')
        for lemmpos_st in lemmpos_sts:
            redo_corpus_by_sts.append(cleaningtext(lemmpos_st)[0])
    
    def basedonBOW(redo_corpus_by_sts):
        dictionary = gensim.corpora.Dictionary(redo_corpus_by_sts)
        corpus = [dictionary.doc2bow(text) for text in redo_corpus_by_sts]
    return corpus, dictionary
    
    def basedonTFIDF(corpus):
        return gensim.models.TfidfModel(corpus)
    
    def basedonOTHER(redo_corpus_by_sts, dictionary, wordimportance):
        def metriccalc1(w):
            return 1.0+2.0**float(wordimportance[w])
        
        corpus = []
        for sts in redo_corpus_by_sts:
            st = []
            for w in sts:
                st.append((dictionary.token2id[w], metriccalc1(w)))
            corpus.append(st)
        return corpus
        
    corpus, dictionary = basedonBOW(redo_corpus_by_sts)
    if wordimportance == {'tfidf':True}:
        tfidf = basedonTFIDF(corpus)
        corpus = tfidf[corpus]
    if wordimportance != {} and wordimportance != {'tfidf':True}:
        corpus = basedonOTHER(redo_corpus_by_sts, dictionary, wordimportance)
    
    
    lda_model = gensim.models.LdaModel(corpus=corpus, num_topics=NUM_TOPICS, id2word=dictionary)
    lsi_model = gensim.models.LsiModel(corpus=corpus, num_topics=NUM_TOPICS, id2word=dictionary)

   
    return lda_model, lsi_model

############################
## gensim_models2: modification of gensim_model1 to fit allrecordsPreparation2
############################

def gensim_models2(lemmposrecs, NUM_TOPICS = 15, lemmws_fd = {}, wordimportance = {}, nltk = nltk, gensim = gensim):
    
    def cleanedsts_from_lemmpostxts(lemmposrecs, STOPWORDS = nltk.corpus.stopwords.words('english')):
        redo_corpus_by_sts = []
        for lemmpos_r in lemmposrecs:
            lemmpos_t = lemmpos_r[3]
            lemm_sts = ''
            for lemmpos_TUPLE in lemmpos_t:
                w = lemmpos_TUPLE[2]
                lemm_sts = lemm_sts + w + ' '
            sts = lemm_sts.split('.')
            for st in sts:
                redo_corpus_by_sts.append(cleaningtext(st.split())[0])
        
        #print(len(redo_corpus_by_sts), redo_corpus_by_sts[-1])
        return redo_corpus_by_sts
        
    def basedonBOW(redo_corpus_by_sts):
        dictionary = gensim.corpora.Dictionary(redo_corpus_by_sts) #[token for st in redo_corpus_by_sts for token in st]
        corpus = [dictionary.doc2bow(text) for text in redo_corpus_by_sts]
        return corpus, dictionary
    
    def basedonTFIDF(corpus):
        return gensim.models.TfidfModel(corpus)
    
    def basedonOTHER(redo_corpus_by_sts, dictionary, wordimportance):
        
        def metriccalc1(w):
            return 1.0+2.0**float(wordimportance[w])

        corpus = []
        for sts in redo_corpus_by_sts:
            st = []
            for w in sts:
                st.append((dictionary.token2id[w], metriccalc1(w)))
            corpus.append(st)
        return corpus
        
    
    redo_corpus_by_sts  = cleanedsts_from_lemmpostxts(lemmpostxts)
    
    corpus, dictionary = basedonBOW(redo_corpus_by_sts)
    if wordimportance == {'tfidf':True}:
        tfidf = basedonTFIDF(corpus)
        corpus = tfidf[corpus]
    if wordimportance != {} and wordimportance != {'tfidf':True}:
        corpus = basedonOTHER(redo_corpus_by_sts, dictionary, wordimportance)
    
    
    lda_model = gensim.models.LdaModel(corpus=corpus, num_topics=NUM_TOPICS, id2word=dictionary)
    lsi_model = gensim.models.LsiModel(corpus=corpus, num_topics=NUM_TOPICS, id2word=dictionary)

   
    return lda_model, lsi_model

# %% [markdown]
# ### A more Raw LDA implementation

# %%
def raw_lda_frankjupyter(all_lemmposedsts, wordimportance):
    '''
    description: modified model based on https://www.frankcleary.com/svd/ for a more raw construction of a lda
    '''
    
    def metriccalc(st, normalizer, wordimportance):
        '''
        description:
        text normalization based on ALL characters in the sentence; why? Example: if two writers wrote 20 words, 2 of them very important, but one of them wrote half of characters stopwords, those 2 words wouldnt be penalized accordingly for this writer: the other wrote more important content
        '''       
        likedict = collections.defaultdict(float)
        textbow = collections.Counter(st)
        for w in st:
            #likedict[w] = math.pow(0.1+float(wordimportance[w]),textbow[w]/normalizer) #a sort of idf-normalization based on number of words in the text: the more the words in a text, the more important
            #likedict[w] = float(wordimportance[w])*textbow[w] #good but ignore those words with worimportance too low or 0 but that are frequent in text
            likedict[w] = 1.0+2.0**float(wordimportance[w]) #because it is not normilized this indicator would simply say that if it has the word at least once is already on topic
        return likedict
            
            
    STOPWORDS = nltk.corpus.stopwords.words('english')
    #redo_corpus_by_sts = []
    words_df = pandas.DataFrame()
    textreference = {}
    for textindex, lemmpos_t in enumerate(all_lemmposedsts):
        print('lemmpos_t', len(lemmpos_t))
        redo_corpus_by_sts = []
        lensts = []
        lemmpos_sts = lemmpos_t.split('.')
        for stindex, lemmpos_st in enumerate(lemmpos_sts):
            treated_st, lensts = cleaningtext(lemmpos_st)        
            print('treated_st', lensts)
            if len(treated_st) > 3:
                likedict = metriccalc(treated_st, lensts[stindex], wordimportance)
                st_df = pandas.DataFrame.from_dict(likedict, orient='index')
                textindexing = str(textindex)+'_'+str(stindex)
                st_df.columns = [textindexing]
                textreference[textindexing] = {}
                textreference[textindexing]['treated_st'] = treated_st
                #st_df.columns = [str(count)]
                words_df = words_df.join(st_df, how='outer', )
    
    words_df = words_df.fillna(0)
    print("Number of unique words: %s" % len(words_df))
    print(words_df.sort(columns=words_df.columns[0], ascending=False).head(10))
    
    return words_df, textreference

# %%
def dist(col1, col2, sigma):
    """Return the norm of (col1 - col2), where the differences in 
    each dimension are wighted by the values in sigma."""
    return numpy.linalg.norm(numpy.array(col1 - col2) * sigma)
    #return scipy.spatial.distance.cosine(col1,col2) #always saying they are different; also http://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html


def similarityanalysis(words_df):
    
    U, sigma, V = numpy.linalg.svd(words_df)
    v_df = pandas.DataFrame(V, columns=words_df.columns)
    v_df.apply(lambda x: numpy.round(x, decimals=2))
     
    dist_df = pandas.DataFrame(index=v_df.columns, columns=v_df.columns)
    for cname in v_df.columns:
        dist_df[cname] = v_df.apply(lambda x: dist(v_df[cname].values, x.values, sigma))
    
    return dist_df, U, sigma, V, v_df

# %% [markdown]
# ## Running LDA and LSI models

# %%
with open('../data/jobproject_forum.json','r') as message:
    otp = json.load(message)
print(len(otp))
allrecords = [{ "user": k, "data": otp[k] }  for k in otp]
print(len(allrecords))
# Out:
# 90
# 90

# %%
lemmposrecs, lemmws_fd = allrecordsPreparation2(allrecords)
# Out:
# in allrecordsPreparation (len(allrecords)):: 90
# pos KeyErrors about IN
# pos KeyErrors good JJ
# pos KeyErrors but CC
# pos KeyErrors great JJ
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors salary JJ
# pos KeyErrors me PRP
# pos KeyErrors but CC
# pos KeyErrors five CD
# pos KeyErrors it PRP
# pos KeyErrors fulfilling JJ
# pos KeyErrors a DT
# pos KeyErrors little JJ
# pos KeyErrors about IN
# pos KeyErrors me PRP
# pos KeyErrors i JJ
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors important JJ
# pos KeyErrors a DT
# pos KeyErrors no DT
# pos KeyErrors will MD
# pos KeyErrors a DT
# pos KeyErrors hard JJ
# pos KeyErrors a DT
# pos KeyErrors rich JJ
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors i JJ
# pos KeyErrors in IN
# pos KeyErrors so IN
# pos KeyErrors as IN
# pos KeyErrors it PRP
# pos KeyErrors four CD
# pos KeyErrors all DT
# pos KeyErrors in IN
# pos KeyErrors can MD
# pos KeyErrors a DT
# pos KeyErrors 70 CD
# pos KeyErrors or CC
# pos KeyErrors a DT
# pos KeyErrors while IN
# pos KeyErrors helpful JJ
# pos KeyErrors in IN
# pos KeyErrors it PRP
# pos KeyErrors much JJ
# pos KeyErrors practical JJ
# IndexErrors (not found) fcc RB
# pos KeyErrors it PRP
# pos KeyErrors real JJ
# pos KeyErrors in IN
# pos KeyErrors its PRP$
# IndexErrors (not found) november VB
# pos KeyErrors on IN
# pos KeyErrors any DT
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors different JJ
# pos KeyErrors regular JJ
# pos KeyErrors out IN
# pos KeyErrors on IN
# pos KeyErrors while IN
# pos KeyErrors basic JJ
# pos KeyErrors in IN
# pos KeyErrors three CD
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors after IN
# pos KeyErrors possible JJ
# pos KeyErrors amazing JJ
# pos KeyErrors important JJ
# pos KeyErrors in IN
# pos KeyErrors as IN
# pos KeyErrors algorithm JJ
# pos KeyErrors me PRP
# pos KeyErrors in IN
# pos KeyErrors me PRP
# pos KeyErrors there EX
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors particular JJ
# IndexErrors (not found) i RB
# pos KeyErrors utmost JJ
# pos KeyErrors who WP
# pos KeyErrors me PRP
# pos KeyErrors in IN
# pos KeyErrors me PRP
# pos KeyErrors it PRP
# pos KeyErrors better JJR
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors it PRP
# pos KeyErrors me PRP
# pos KeyErrors but CC
# pos KeyErrors personal JJ
# pos KeyErrors as IN
# pos KeyErrors on IN
# pos KeyErrors in IN
# pos KeyErrors as IN
# pos KeyErrors me PRP
# pos KeyErrors better JJR
# pos KeyErrors every DT
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors while IN
# pos KeyErrors special JJ
# pos KeyErrors all PDT
# pos KeyErrors about IN
# pos KeyErrors every DT
# IndexErrors (not found) i VBP
# pos KeyErrors or CC
# IndexErrors (not found) lonely RB
# pos KeyErrors all DT
# pos KeyErrors in IN
# pos KeyErrors web JJ
# IndexErrors (not found) i VBP
# pos KeyErrors us PRP
# pos KeyErrors it PRP
# pos KeyErrors after IN
# pos KeyErrors a DT
# pos KeyErrors hard JJ
# IndexErrors (not found) i VBP
# pos KeyErrors a DT
# pos KeyErrors next JJ
# pos KeyErrors will MD
# pos KeyErrors at IN
# pos KeyErrors an DT
# pos KeyErrors it PRP
# pos KeyErrors in IN
# pos KeyErrors will MD
# pos KeyErrors me PRP
# pos KeyErrors at IN
# pos KeyErrors biggest JJS
# pos KeyErrors in IN
# pos KeyErrors glad JJ
# pos KeyErrors can MD
# pos KeyErrors a DT
# pos KeyErrors little JJ
# pos KeyErrors about IN
# pos KeyErrors will MD
# pos KeyErrors hard JJ
# pos KeyErrors at IN
# pos KeyErrors a DT
# IndexErrors (not found) i VBZ
# pos KeyErrors 28 CD
# pos KeyErrors old JJ
# pos KeyErrors as IN
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors former JJ
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors in IN
# IndexErrors (not found) i VB
# pos KeyErrors i JJ
# pos KeyErrors entire JJ
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors about IN
# pos KeyErrors i JJ
# pos KeyErrors an DT
# pos KeyErrors in IN
# pos KeyErrors it PRP
# pos KeyErrors first JJ
# pos KeyErrors full JJ
# pos KeyErrors it PRP
# pos KeyErrors in IN
# IndexErrors (not found) i VB
# pos KeyErrors any DT
# pos KeyErrors real JJ
# pos KeyErrors real JJ
# pos KeyErrors before IN
# pos KeyErrors funny JJ
# pos KeyErrors 1 CD
# pos KeyErrors 5 CD
# pos KeyErrors i JJ
# pos KeyErrors able JJ
# IndexErrors (not found) properly VB
# pos KeyErrors all DT
# pos KeyErrors but CC
# pos KeyErrors i JJ
# IndexErrors (not found) passionate NN
# pos KeyErrors about IN
# pos KeyErrors can MD
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors first JJ
# pos KeyErrors but CC
# pos KeyErrors it PRP
# pos KeyErrors theoretical JJ
# pos KeyErrors a DT
# pos KeyErrors better JJR
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors available JJ
# pos KeyErrors glad JJ
# pos KeyErrors i JJ
# pos KeyErrors passionate JJ
# pos KeyErrors about IN
# pos KeyErrors it PRP
# pos KeyErrors easy JJ
# pos KeyErrors i JJ
# IndexErrors (not found) sure NN
# pos KeyErrors it PRP
# pos KeyErrors some DT
# pos KeyErrors due JJ
# pos KeyErrors long JJ
# pos KeyErrors late JJ
# pos KeyErrors supportive JJ
# pos KeyErrors it PRP
# pos KeyErrors all DT
# pos KeyErrors only JJ
# pos KeyErrors but CC
# IndexErrors (not found) i VBP
# pos KeyErrors like IN
# pos KeyErrors it PRP
# pos KeyErrors me PRP
# IndexErrors (not found) furthermore NN
# IndexErrors (not found) i VBP
# pos KeyErrors like IN
# pos KeyErrors on IN
# pos KeyErrors why WRB
# pos KeyErrors i JJ
# pos KeyErrors like IN
# pos KeyErrors it PRP
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors big JJ
# IndexErrors (not found) thank NN
# pos KeyErrors many JJ
# pos KeyErrors other JJ
# pos KeyErrors like IN
# pos KeyErrors other JJ
# pos KeyErrors it PRP
# pos KeyErrors important JJ
# pos KeyErrors me PRP
# IndexErrors (not found) consult NN
# pos KeyErrors different JJ
# pos KeyErrors understood JJ
# IndexErrors (not found) whatever NN
# pos KeyErrors at IN
# pos KeyErrors on IN
# pos KeyErrors while IN
# pos KeyErrors new JJ
# pos KeyErrors but CC
# pos KeyErrors enough JJ
# pos KeyErrors it PRP
# pos KeyErrors me PRP
# pos KeyErrors over IN
# pos KeyErrors able JJ
# pos KeyErrors on IN
# pos KeyErrors trough JJ
# pos KeyErrors why WRB
# pos KeyErrors i JJ
# pos KeyErrors 2 CD
# pos KeyErrors after IN
# pos KeyErrors 3rd CD
# pos KeyErrors fortunate JJ
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors me PRP
# pos KeyErrors will MD
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors at IN
# pos KeyErrors all DT
# pos KeyErrors in IN
# pos KeyErrors all DT
# pos KeyErrors must MD
# pos KeyErrors about IN
# pos KeyErrors before IN
# pos KeyErrors many JJ
# pos KeyErrors can MD
# pos KeyErrors hard JJ
# pos KeyErrors patient JJ
# pos KeyErrors hard JJ
# pos KeyErrors off IN
# pos KeyErrors most JJS
# pos KeyErrors off IN
# pos KeyErrors all DT
# pos KeyErrors in IN
# pos KeyErrors happy JJ
# pos KeyErrors front JJ
# pos KeyErrors past JJ
# pos KeyErrors 3 CD
# pos KeyErrors remote JJ
# pos KeyErrors on IN
# IndexErrors (not found) i RB
# pos KeyErrors one CD
# pos KeyErrors me PRP
# IndexErrors (not found) i VB
# pos KeyErrors but CC
# pos KeyErrors by IN
# pos KeyErrors on IN
# pos KeyErrors as IN
# pos KeyErrors some DT
# pos KeyErrors on IN
# pos KeyErrors a DT
# pos KeyErrors simple JJ
# pos KeyErrors ready JJ
# pos KeyErrors 4 CD
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors in IN
# IndexErrors (not found) i VBP
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors more JJR
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors remote JJ
# pos KeyErrors more JJR
# pos KeyErrors 100 CD
# pos KeyErrors web JJ
# pos KeyErrors around IN
# pos KeyErrors 5 CD
# pos KeyErrors out IN
# pos KeyErrors a DT
# pos KeyErrors more JJR
# pos KeyErrors i JJ
# pos KeyErrors like IN
# pos KeyErrors will MD
# pos KeyErrors me PRP
# pos KeyErrors in IN
# pos KeyErrors stable JJ
# pos KeyErrors in IN
# pos KeyErrors as IN
# pos KeyErrors can MD
# pos KeyErrors in IN
# pos KeyErrors best JJS
# IndexErrors (not found) i VB
# pos KeyErrors front JJ
# pos KeyErrors 34 CD
# pos KeyErrors 15 CD
# pos KeyErrors 5 CD
# pos KeyErrors 1 CD
# IndexErrors (not found) i VBP
# IndexErrors (not found) react NN
# pos KeyErrors 1 CD
# pos KeyErrors 30 CD
# pos KeyErrors through IN
# pos KeyErrors 36 CD
# IndexErrors (not found) fcc RB
# pos KeyErrors front JJ
# pos KeyErrors 45 CD
# IndexErrors (not found) react NN
# pos KeyErrors 48 CD
# pos KeyErrors 50 CD
# pos KeyErrors 60 CD
# pos KeyErrors 60 CD
# pos KeyErrors 75 CD
# pos KeyErrors web JJ
# pos KeyErrors 83 CD
# pos KeyErrors 85 CD
# pos KeyErrors 95 CD
# pos KeyErrors prepared JJ
# pos KeyErrors 97 CD
# pos KeyErrors 1st CD
# IndexErrors (not found) everyday NN
# pos KeyErrors important JJ
# pos KeyErrors it PRP
# pos KeyErrors initial JJ
# pos KeyErrors at IN
# pos KeyErrors least JJS
# pos KeyErrors 100 CD
# pos KeyErrors better JJR
# pos KeyErrors i JJ
# IndexErrors (not found) confident NN
# pos KeyErrors can MD
# pos KeyErrors any DT
# pos KeyErrors about IN
# pos KeyErrors me PRP
# pos KeyErrors front JJ
# pos KeyErrors 100 CD
# pos KeyErrors all DT
# pos KeyErrors after IN
# pos KeyErrors a DT
# pos KeyErrors ups JJ
# pos KeyErrors a DT
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors senior JJ
# pos KeyErrors might MD
# pos KeyErrors different JJ
# pos KeyErrors a DT
# pos KeyErrors on IN
# pos KeyErrors but CC
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors little JJ
# pos KeyErrors any DT
# pos KeyErrors one CD
# pos KeyErrors can MD
# pos KeyErrors an DT
# pos KeyErrors no DT
# IndexErrors (not found) degree SYM
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors former JJ
# pos KeyErrors military JJ
# pos KeyErrors in IN
# pos KeyErrors it PRP
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors past JJ
# pos KeyErrors 3 CD
# pos KeyErrors 3 CD
# pos KeyErrors front JJ
# pos KeyErrors current JJ
# pos KeyErrors me PRP
# pos KeyErrors all DT
# pos KeyErrors it PRP
# pos KeyErrors it PRP
# pos KeyErrors important JJ
# pos KeyErrors it PRP
# pos KeyErrors me PRP
# pos KeyErrors distributed JJ
# pos KeyErrors key JJ
# IndexErrors (not found) networking NN
# pos KeyErrors me PRP
# pos KeyErrors i JJ
# pos KeyErrors through IN
# pos KeyErrors any DT
# pos KeyErrors new JJ
# IndexErrors (not found) threw NN
# pos KeyErrors at IN
# pos KeyErrors me PRP
# pos KeyErrors first JJ
# pos KeyErrors it PRP
# IndexErrors (not found) easier RBR
# pos KeyErrors current JJ
# pos KeyErrors i JJ
# pos KeyErrors on IN
# pos KeyErrors december $
# pos KeyErrors 14th CD
# pos KeyErrors a DT
# pos KeyErrors 500 CD
# pos KeyErrors in IN
# IndexErrors (not found) i VB
# IndexErrors (not found) scripting NN
# pos KeyErrors in IN
# pos KeyErrors current JJ
# pos KeyErrors it PRP
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors mixed JJ
# pos KeyErrors a DT
# pos KeyErrors past JJ
# pos KeyErrors or CC
# pos KeyErrors but CC
# pos KeyErrors as IN
# pos KeyErrors it PRP
# pos KeyErrors me PRP
# pos KeyErrors new JJ
# pos KeyErrors will MD
# pos KeyErrors in IN
# pos KeyErrors restful JJ
# pos KeyErrors might MD
# pos KeyErrors who WP
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors technical JJ
# pos KeyErrors one CD
# pos KeyErrors might MD
# pos KeyErrors a DT
# pos KeyErrors dead JJ
# pos KeyErrors old JJ
# pos KeyErrors at IN
# pos KeyErrors a DT
# pos KeyErrors wonderful JJ
# pos KeyErrors all DT
# pos KeyErrors all DT
# /home/ec/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# pos KeyErrors last JJ
# pos KeyErrors a DT
# pos KeyErrors on IN
# pos KeyErrors it PRP
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors up IN
# pos KeyErrors 3 CD
# pos KeyErrors an DT
# pos KeyErrors a DT
# pos KeyErrors decent JJ
# pos KeyErrors but CC
# IndexErrors (not found) i VB
# pos KeyErrors a DT
# pos KeyErrors full JJ
# pos KeyErrors a DT
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors so IN
# pos KeyErrors i JJ
# pos KeyErrors about IN
# IndexErrors (not found) halfway NN
# pos KeyErrors through IN
# pos KeyErrors any DT
# pos KeyErrors a DT
# pos KeyErrors few JJ
# pos KeyErrors but CC
# pos KeyErrors a DT
# pos KeyErrors little JJ
# pos KeyErrors at IN
# pos KeyErrors no DT
# pos KeyErrors substantial JJ
# pos KeyErrors in IN
# pos KeyErrors so IN
# IndexErrors (not found) i RB
# pos KeyErrors on IN
# pos KeyErrors enough JJ
# pos KeyErrors a DT
# pos KeyErrors regular JJ
# pos KeyErrors full JJ
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors on IN
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors who WP
# pos KeyErrors a DT
# pos KeyErrors react JJ
# pos KeyErrors i JJ
# pos KeyErrors no DT
# pos KeyErrors professional JJ
# pos KeyErrors but CC
# pos KeyErrors confident JJ
# pos KeyErrors good JJ
# pos KeyErrors he PRP
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors under IN
# pos KeyErrors front JJ
# pos KeyErrors who WP
# pos KeyErrors on IN
# pos KeyErrors out IN
# pos KeyErrors three CD
# pos KeyErrors on IN
# pos KeyErrors front JJ
# pos KeyErrors on IN
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors real JJ
# pos KeyErrors professional JJ
# pos KeyErrors two CD
# pos KeyErrors three CD
# pos KeyErrors but CC
# pos KeyErrors a DT
# pos KeyErrors huge JJ
# IndexErrors (not found) i VB
# pos KeyErrors like IN
# pos KeyErrors at IN
# pos KeyErrors first JJ
# pos KeyErrors but CC
# IndexErrors (not found) i VB
# pos KeyErrors a DT
# pos KeyErrors new JJ
# pos KeyErrors me PRP
# pos KeyErrors me PRP
# pos KeyErrors at IN
# pos KeyErrors least JJS
# pos KeyErrors a DT
# pos KeyErrors full JJ
# pos KeyErrors at IN
# pos KeyErrors an DT
# pos KeyErrors lower JJR
# pos KeyErrors most JJS
# pos KeyErrors higher JJR
# pos KeyErrors any DT
# pos KeyErrors other JJ
# pos KeyErrors steady JJ
# pos KeyErrors he PRP
# pos KeyErrors some DT
# pos KeyErrors experienced JJ
# pos KeyErrors but CC
# IndexErrors (not found) i RB
# pos KeyErrors timely JJ
# pos KeyErrors clear JJ
# pos KeyErrors front JJ
# pos KeyErrors a DT
# pos KeyErrors potential JJ
# pos KeyErrors i JJ
# pos KeyErrors at IN
# pos KeyErrors least JJS
# pos KeyErrors a DT
# pos KeyErrors little JJ
# pos KeyErrors i JJ
# pos KeyErrors in IN
# pos KeyErrors at IN
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors long JJ
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors on IN
# pos KeyErrors other JJ
# IndexErrors (not found) freelancing NN
# pos KeyErrors ca MD
# pos KeyErrors some DT
# pos KeyErrors on IN
# pos KeyErrors such PDT
# pos KeyErrors a DT
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors good JJ
# pos KeyErrors any DT
# pos KeyErrors it PRP
# pos KeyErrors worth JJ
# pos KeyErrors reliable JJ
# pos KeyErrors can MD
# pos KeyErrors big JJ
# pos KeyErrors a DT
# pos KeyErrors or CC
# pos KeyErrors any DT
# pos KeyErrors prior JJ
# pos KeyErrors first JJ
# pos KeyErrors past JJ
# pos KeyErrors two CD
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors like IN
# pos KeyErrors about IN
# pos KeyErrors i JJ
# pos KeyErrors it PRP
# pos KeyErrors might MD
# pos KeyErrors helpful JJ
# pos KeyErrors by IN
# pos KeyErrors on IN
# pos KeyErrors amazing JJ
# IndexErrors (not found) i RB
# pos KeyErrors it PRP
# pos KeyErrors right JJ
# pos KeyErrors on IN
# pos KeyErrors may MD
# IndexErrors (not found) i VB
# pos KeyErrors it PRP
# pos KeyErrors in IN
# pos KeyErrors in IN
# pos KeyErrors why WRB
# pos KeyErrors it PRP
# pos KeyErrors important JJ
# pos KeyErrors best JJS
# pos KeyErrors after IN
# IndexErrors (not found) i VBP
# pos KeyErrors another DT
# IndexErrors (not found) react NN
# pos KeyErrors angular JJ
# IndexErrors (not found) seem NN
# pos KeyErrors important JJ
# pos KeyErrors on IN
# IndexErrors (not found) i RB
# pos KeyErrors after IN
# pos KeyErrors like IN
# pos KeyErrors complete JJ
# pos KeyErrors an DT
# pos KeyErrors much JJ
# pos KeyErrors other JJ
# pos KeyErrors before IN
# pos KeyErrors good JJ
# pos KeyErrors as IN
# pos KeyErrors can MD
# pos KeyErrors helpful JJ
# IndexErrors (not found) i VBP
# pos KeyErrors 1st CD
# pos KeyErrors in IN
# pos KeyErrors in IN
# pos KeyErrors whole JJ
# pos KeyErrors on IN
# pos KeyErrors awesome JJ
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors different JJ
# pos KeyErrors most JJS
# pos KeyErrors so IN
# pos KeyErrors i JJ
# pos KeyErrors will MD
# pos KeyErrors on IN
# pos KeyErrors in IN
# pos KeyErrors more JJR
# pos KeyErrors after IN
# pos KeyErrors fcc JJ
# pos KeyErrors extensive JJ
# IndexErrors (not found) i RB
# pos KeyErrors on IN
# pos KeyErrors in IN
# pos KeyErrors last JJ
# pos KeyErrors after IN
# IndexErrors (not found) cs VB
# pos KeyErrors it PRP
# pos KeyErrors long JJ
# IndexErrors (not found) december VB
# pos KeyErrors fcc JJ
# pos KeyErrors another DT
# pos KeyErrors at IN
# pos KeyErrors in IN
# pos KeyErrors same JJ
# pos KeyErrors can MD
# pos KeyErrors each DT
# pos KeyErrors other JJ
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors on IN
# pos KeyErrors css JJ
# pos KeyErrors me PRP
# pos KeyErrors on IN
# pos KeyErrors or CC
# pos KeyErrors no DT
# pos KeyErrors as IN
# pos KeyErrors or CC
# pos KeyErrors a DT
# pos KeyErrors few JJ
# pos KeyErrors in IN
# pos KeyErrors but CC
# pos KeyErrors a DT
# pos KeyErrors junior JJ
# pos KeyErrors in IN
# pos KeyErrors low JJ
# pos KeyErrors a DT
# pos KeyErrors working JJ
# IndexErrors (not found) uk VB
# pos KeyErrors some DT
# pos KeyErrors progressive JJ
# pos KeyErrors on IN
# pos KeyErrors a DT
# pos KeyErrors good JJ
# pos KeyErrors some DT
# pos KeyErrors good JJ
# pos KeyErrors about IN
# pos KeyErrors me PRP
# pos KeyErrors after IN
# pos KeyErrors some DT
# pos KeyErrors fcc JJ
# pos KeyErrors but CC
# pos KeyErrors all DT
# pos KeyErrors on IN
# pos KeyErrors some DT
# pos KeyErrors own JJ
# pos KeyErrors on IN
# pos KeyErrors while IN
# pos KeyErrors after IN
# pos KeyErrors a DT
# pos KeyErrors few JJ
# pos KeyErrors across IN
# pos KeyErrors an DT
# pos KeyErrors about IN
# pos KeyErrors interested JJ
# pos KeyErrors in IN
# pos KeyErrors it PRP
# pos KeyErrors after IN
# pos KeyErrors legendary JJ
# pos KeyErrors between IN
# pos KeyErrors lee JJ
# pos KeyErrors a DT
# pos KeyErrors high JJ
# pos KeyErrors in IN
# pos KeyErrors some DT
# pos KeyErrors prior JJ
# pos KeyErrors a DT
# pos KeyErrors data JJ
# pos KeyErrors i JJ
# IndexErrors (not found) i VBP
# pos KeyErrors in IN
# pos KeyErrors in IN
# pos KeyErrors smooth JJ
# pos KeyErrors while IN
# pos KeyErrors i JJ
# pos KeyErrors some DT
# pos KeyErrors in IN
# pos KeyErrors some DT
# pos KeyErrors impressive JJ
# pos KeyErrors startup JJ
# pos KeyErrors some DT
# pos KeyErrors me PRP
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors public JJ
# IndexErrors (not found) i VBZ
# pos KeyErrors there EX
# pos KeyErrors i JJ
# pos KeyErrors one CD
# pos KeyErrors there EX
# pos KeyErrors who WP
# pos KeyErrors can MD
# pos KeyErrors some DT
# pos KeyErrors algorithms JJ
# pos KeyErrors it PRP
# pos KeyErrors some DT
# IndexErrors (not found) weekly VBP
# pos KeyErrors can MD
# IndexErrors (not found) i VB
# pos KeyErrors at IN
# pos KeyErrors last JJ
# pos KeyErrors me PRP
# pos KeyErrors it PRP
# pos KeyErrors such JJ
# pos KeyErrors a DT
# pos KeyErrors it PRP
# pos KeyErrors half PDT
# pos KeyErrors a DT
# pos KeyErrors but CC
# pos KeyErrors all DT
# pos KeyErrors big JJ
# pos KeyErrors all PDT
# pos KeyErrors who WP
# pos KeyErrors before IN
# pos KeyErrors on IN
# pos KeyErrors in IN
# pos KeyErrors best JJS
# pos KeyErrors a DT
# pos KeyErrors but CC
# IndexErrors (not found) fcc RB
# pos KeyErrors excited JJ
# pos KeyErrors some DT
# pos KeyErrors on IN
# pos KeyErrors some DT
# pos KeyErrors it PRP
# pos KeyErrors a DT
# IndexErrors (not found) fcc RB
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors long JJ
# pos KeyErrors it PRP
# pos KeyErrors hard JJ
# pos KeyErrors but CC
# pos KeyErrors worth JJ
# IndexErrors (not found) i VB
# pos KeyErrors encouraging JJ
# pos KeyErrors can MD
# pos KeyErrors in IN
# pos KeyErrors 1 CD
# pos KeyErrors a DT
# pos KeyErrors non JJ
# pos KeyErrors degree JJ
# pos KeyErrors like IN
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors typical JJ
# pos KeyErrors hard JJ
# pos KeyErrors some DT
# pos KeyErrors smaller JJR
# pos KeyErrors a DT
# pos KeyErrors low JJ
# pos KeyErrors an DT
# pos KeyErrors intern JJ
# pos KeyErrors a DT
# pos KeyErrors full JJ
# pos KeyErrors 2 CD
# pos KeyErrors important JJ
# pos KeyErrors some DT
# pos KeyErrors as IN
# pos KeyErrors much JJ
# pos KeyErrors as IN
# pos KeyErrors possible JJ
# pos KeyErrors in IN
# pos KeyErrors might MD
# pos KeyErrors any DT
# pos KeyErrors a DT
# pos KeyErrors who WP
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors good JJ
# pos KeyErrors he PRP
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors 3 CD
# pos KeyErrors at IN
# pos KeyErrors some DT
# pos KeyErrors after IN
# pos KeyErrors all DT
# pos KeyErrors about IN
# pos KeyErrors it PRP
# pos KeyErrors all PDT
# pos KeyErrors best JJS
# pos KeyErrors 4 CD
# pos KeyErrors a DT
# pos KeyErrors fcc JJ
# pos KeyErrors a DT
# pos KeyErrors but CC
# pos KeyErrors good JJ
# pos KeyErrors at IN
# pos KeyErrors but CC
# pos KeyErrors good JJ
# pos KeyErrors at IN
# pos KeyErrors like IN
# pos KeyErrors me PRP
# pos KeyErrors more JJR
# pos KeyErrors professional JJ
# pos KeyErrors on IN
# pos KeyErrors as IN
# pos KeyErrors good JJ
# pos KeyErrors at IN
# pos KeyErrors but CC
# pos KeyErrors more JJR
# pos KeyErrors professional JJ
# pos KeyErrors on IN
# pos KeyErrors as IN
# pos KeyErrors 5 CD
# pos KeyErrors all DT
# pos KeyErrors out IN
# pos KeyErrors might MD
# pos KeyErrors as IN
# pos KeyErrors confident JJ
# pos KeyErrors other JJ
# pos KeyErrors on IN
# pos KeyErrors some DT
# pos KeyErrors curious JJ
# pos KeyErrors after IN
# pos KeyErrors all DT
# pos KeyErrors 6 CD
# pos KeyErrors but CC
# pos KeyErrors can MD
# pos KeyErrors about IN
# pos KeyErrors capable JJ
# pos KeyErrors who WP
# pos KeyErrors might MD
# pos KeyErrors worth IN
# pos KeyErrors it PRP
# pos KeyErrors hard JJ
# pos KeyErrors fellow JJ
# pos KeyErrors a DT
# pos KeyErrors about IN
# pos KeyErrors i JJ
# pos KeyErrors free JJ
# pos KeyErrors love IN
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors it PRP
# pos KeyErrors 1 CD
# pos KeyErrors satisfied JJ
# pos KeyErrors current JJ
# pos KeyErrors like IN
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors after IN
# pos KeyErrors about IN
# pos KeyErrors 9 CD
# pos KeyErrors 10 CD
# pos KeyErrors after IN
# pos KeyErrors about IN
# pos KeyErrors other JJ
# pos KeyErrors who WP
# pos KeyErrors a DT
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors i JJ
# pos KeyErrors it PRP
# pos KeyErrors nice JJ
# pos KeyErrors some DT
# pos KeyErrors it PRP
# pos KeyErrors all DT
# pos KeyErrors about IN
# pos KeyErrors as IN
# pos KeyErrors a DT
# IndexErrors (not found) cs VB
# pos KeyErrors but CC
# IndexErrors (not found) i RB
# pos KeyErrors some DT
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors few JJ
# IndexErrors (not found) i VBP
# pos KeyErrors some DT
# IndexErrors (not found) i VBP
# pos KeyErrors it PRP
# pos KeyErrors important JJ
# pos KeyErrors learn JJ
# pos KeyErrors before IN
# IndexErrors (not found) react NN
# IndexErrors (not found) angular NN
# pos KeyErrors or CC
# pos KeyErrors learn CC
# pos KeyErrors before IN
# pos KeyErrors or CC
# pos KeyErrors will MD
# pos KeyErrors a DT
# pos KeyErrors easier JJR
# pos KeyErrors will MD
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors an DT
# pos KeyErrors in IN
# pos KeyErrors in IN
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors front JJ
# pos KeyErrors it PRP
# pos KeyErrors clear JJ
# IndexErrors (not found) overall VBP
# pos KeyErrors requested JJ
# pos KeyErrors good JJ
# pos KeyErrors or CC
# pos KeyErrors angular JJ
# pos KeyErrors a DT
# pos KeyErrors both DT
# pos KeyErrors but CC
# pos KeyErrors there EX
# pos KeyErrors a DT
# pos KeyErrors it PRP
# pos KeyErrors in IN
# pos KeyErrors in IN
# pos KeyErrors angular JJ
# pos KeyErrors git JJ
# pos KeyErrors it PRP
# pos KeyErrors difficult JJ
# pos KeyErrors but CC
# IndexErrors (not found) i VBZ
# pos KeyErrors it PRP
# pos KeyErrors after IN
# pos KeyErrors real JJ
# pos KeyErrors in IN
# pos KeyErrors can MD
# pos KeyErrors me PRP
# pos KeyErrors it PRP
# pos KeyErrors useful JJ
# pos KeyErrors after IN
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors solid JJ
# pos KeyErrors a DT
# pos KeyErrors few JJ
# pos KeyErrors good JJ
# IndexErrors (not found) i VB
# pos KeyErrors a DT
# pos KeyErrors lucky JJ
# pos KeyErrors in IN
# pos KeyErrors many JJ
# pos KeyErrors before IN
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors small JJ
# pos KeyErrors in IN
# pos KeyErrors angular JJ
# pos KeyErrors an DT
# pos KeyErrors certain JJ
# pos KeyErrors though IN
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors best JJS
# pos KeyErrors good JJ
# IndexErrors (not found) i VBP
# pos KeyErrors knew CD
# pos KeyErrors it PRP
# pos KeyErrors perfect JJ
# pos KeyErrors but CC
# pos KeyErrors an DT
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors good JJ
# pos KeyErrors excited JJ
# pos KeyErrors new JJ
# IndexErrors (not found) i VB
# pos KeyErrors aware JJ
# pos KeyErrors will MD
# pos KeyErrors best JJS
# pos KeyErrors i JJ
# pos KeyErrors can MD
# pos KeyErrors a DT
# pos KeyErrors competent JJ
# pos KeyErrors grateful JJ
# pos KeyErrors though IN
# pos KeyErrors through IN
# pos KeyErrors other JJ
# pos KeyErrors it PRP
# pos KeyErrors important JJ
# pos KeyErrors me PRP
# pos KeyErrors in IN
# pos KeyErrors structured JJ
# pos KeyErrors nice JJ
# pos KeyErrors important JJ
# pos KeyErrors all DT
# pos KeyErrors happy JJ
# pos KeyErrors first JJ
# pos KeyErrors a DT
# pos KeyErrors digital JJ
# pos KeyErrors graphic JJ
# pos KeyErrors some DT
# pos KeyErrors basic JJ
# pos KeyErrors will MD
# pos KeyErrors graphic JJ
# pos KeyErrors basic JJ
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors paid JJ
# pos KeyErrors full JJ
# pos KeyErrors but CC
# pos KeyErrors by IN
# pos KeyErrors a DT
# pos KeyErrors 3 CD
# pos KeyErrors after IN
# pos KeyErrors will MD
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors full JJ
# IndexErrors (not found) i VBN
# IndexErrors (not found) deliver NN
# IndexErrors (not found) fcc RB
# pos KeyErrors 4 CD
# pos KeyErrors basic JJ
# IndexErrors (not found) js VBP
# pos KeyErrors on IN
# pos KeyErrors through IN
# pos KeyErrors a DT
# pos KeyErrors scratch JJ
# pos KeyErrors on IN
# pos KeyErrors in IN
# pos KeyErrors off IN
# pos KeyErrors 3 CD
# pos KeyErrors i JJ
# pos KeyErrors financial JJ
# pos KeyErrors significant JJ
# pos KeyErrors other JJ
# pos KeyErrors on IN
# pos KeyErrors another DT
# pos KeyErrors retail JJ
# pos KeyErrors on IN
# pos KeyErrors all DT
# pos KeyErrors in IN
# pos KeyErrors all DT
# pos KeyErrors no DT
# pos KeyErrors real JJ
# pos KeyErrors in IN
# pos KeyErrors or CC
# pos KeyErrors it PRP
# pos KeyErrors me PRP
# IndexErrors (not found) i VB
# pos KeyErrors a DT
# pos KeyErrors graphic JJ
# pos KeyErrors adapted JJ
# pos KeyErrors one CD
# pos KeyErrors motivational JJ
# pos KeyErrors i JJ
# pos KeyErrors willing JJ
# pos KeyErrors new JJ
# pos KeyErrors weird JJ
# pos KeyErrors graphic JJ
# pos KeyErrors basic JJ
# pos KeyErrors most JJS
# IndexErrors (not found) i RB
# pos KeyErrors but CC
# pos KeyErrors through IN
# pos KeyErrors previous JJ
# pos KeyErrors some DT
# pos KeyErrors various JJ
# pos KeyErrors i JJ
# pos KeyErrors most JJS
# pos KeyErrors all DT
# pos KeyErrors who WP
# pos KeyErrors will MD
# pos KeyErrors different JJ
# pos KeyErrors new JJ
# pos KeyErrors as IN
# IndexErrors (not found) arises NNS
# pos KeyErrors 3 CD
# pos KeyErrors foreign JJ
# pos KeyErrors english JJ
# pos KeyErrors one CD
# pos KeyErrors all DT
# pos KeyErrors in IN
# pos KeyErrors all DT
# pos KeyErrors happy JJ
# pos KeyErrors will MD
# pos KeyErrors able JJ
# pos KeyErrors new JJ
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors real JJ
# pos KeyErrors a DT
# pos KeyErrors small JJ
# pos KeyErrors so IN
# pos KeyErrors i JJ
# IndexErrors (not found) i RB
# pos KeyErrors will MD
# pos KeyErrors many JJ
# pos KeyErrors free JJ
# pos KeyErrors all PDT
# pos KeyErrors technical JJ
# pos KeyErrors but CC
# pos KeyErrors important JJ
# pos KeyErrors i JJ
# pos KeyErrors wish JJ
# pos KeyErrors me PRP
# pos KeyErrors i JJ
# pos KeyErrors two CD
# pos KeyErrors full JJ
# pos KeyErrors all DT
# IndexErrors (not found) fcc VB
# pos KeyErrors one CD
# pos KeyErrors mean JJ
# pos KeyErrors while IN
# pos KeyErrors other JJ
# pos KeyErrors angular JJ
# pos KeyErrors a DT
# pos KeyErrors brief JJ
# pos KeyErrors about IN
# pos KeyErrors in IN
# pos KeyErrors i JJ
# pos KeyErrors in IN
# pos KeyErrors signal JJ
# pos KeyErrors on IN
# pos KeyErrors audio JJ
# pos KeyErrors like IN
# pos KeyErrors two CD
# pos KeyErrors a DT
# pos KeyErrors few JJ
# pos KeyErrors across IN
# pos KeyErrors one CD
# pos KeyErrors about IN
# pos KeyErrors fcc JJ
# pos KeyErrors on IN
# pos KeyErrors same JJ
# pos KeyErrors professional JJ
# pos KeyErrors all DT
# pos KeyErrors on IN
# pos KeyErrors fcc JJ
# pos KeyErrors after IN
# pos KeyErrors 6 CD
# pos KeyErrors hard JJ
# pos KeyErrors i JJ
# pos KeyErrors two CD
# pos KeyErrors full JJ
# pos KeyErrors best JJS
# pos KeyErrors both DT
# pos KeyErrors remote JJ
# pos KeyErrors so IN
# pos KeyErrors i JJ
# pos KeyErrors will MD
# pos KeyErrors both DT
# pos KeyErrors 70 CD
# pos KeyErrors a DT
# pos KeyErrors much JJ
# pos KeyErrors as IN
# pos KeyErrors can MD
# IndexErrors (not found) hence VB
# pos KeyErrors 1 CD
# pos KeyErrors it PRP
# pos KeyErrors may MD
# pos KeyErrors but CC
# pos KeyErrors me PRP
# pos KeyErrors 2 CD
# pos KeyErrors on IN
# pos KeyErrors few JJ
# IndexErrors (not found) online NN
# pos KeyErrors full JJ
# pos KeyErrors mean JJ
# pos KeyErrors me PRP
# pos KeyErrors some DT
# pos KeyErrors good JJ
# pos KeyErrors 3 CD
# pos KeyErrors or CC
# pos KeyErrors a DT
# IndexErrors (not found) i RB
# pos KeyErrors great JJ
# pos KeyErrors all DT
# pos KeyErrors by IN
# IndexErrors (not found) thank NN
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors whole JJ
# pos KeyErrors unprecedented JJ
# pos KeyErrors at IN
# pos KeyErrors a DT
# pos KeyErrors small JJ
# pos KeyErrors 15 CD
# pos KeyErrors 30 CD
# pos KeyErrors front JJ
# pos KeyErrors on IN
# pos KeyErrors on IN
# pos KeyErrors some DT
# pos KeyErrors big JJ
# pos KeyErrors all DT
# pos KeyErrors over IN
# pos KeyErrors needless JJ
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors first JJ
# pos KeyErrors it PRP
# pos KeyErrors exciting JJ
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors web JJ
# pos KeyErrors no DT
# pos KeyErrors right JJ
# pos KeyErrors or CC
# pos KeyErrors right JJ
# pos KeyErrors or CC
# IndexErrors (not found) i VBN
# pos KeyErrors right JJ
# pos KeyErrors right JJ
# IndexErrors (not found) i VB
# pos KeyErrors as IN
# IndexErrors (not found) guiding NN
# pos KeyErrors much JJ
# pos KeyErrors as IN
# pos KeyErrors possible JJ
# pos KeyErrors as IN
# pos KeyErrors many JJ
# pos KeyErrors as IN
# pos KeyErrors possible JJ
# pos KeyErrors outside IN
# pos KeyErrors between IN
# pos KeyErrors new JJ
# pos KeyErrors in IN
# pos KeyErrors next JJ
# pos KeyErrors learn JJ
# pos KeyErrors can MD
# pos KeyErrors technical JJ
# pos KeyErrors on IN
# pos KeyErrors a DT
# pos KeyErrors countless JJ
# pos KeyErrors who WP
# pos KeyErrors on IN
# pos KeyErrors but CC
# pos KeyErrors know JJ
# pos KeyErrors simple JJ
# IndexErrors (not found) manipulating NN
# pos KeyErrors through IN
# pos KeyErrors algorithm JJ
# pos KeyErrors on IN
# pos KeyErrors me PRP
# pos KeyErrors beyond IN
# pos KeyErrors more JJR
# pos KeyErrors learn CC
# pos KeyErrors additional JJ
# pos KeyErrors enough JJ
# pos KeyErrors but CC
# pos KeyErrors can MD
# pos KeyErrors own JJ
# pos KeyErrors within IN
# pos KeyErrors additional JJ
# pos KeyErrors will MD
# pos KeyErrors a DT
# pos KeyErrors i JJ
# pos KeyErrors at IN
# pos KeyErrors popular JJ
# pos KeyErrors in IN
# pos KeyErrors but CC
# pos KeyErrors good JJ
# pos KeyErrors another DT
# pos KeyErrors in IN
# pos KeyErrors mind IN
# pos KeyErrors it PRP
# pos KeyErrors but CC
# pos KeyErrors a DT
# pos KeyErrors strong JJ
# pos KeyErrors can MD
# pos KeyErrors on IN
# pos KeyErrors own JJ
# pos KeyErrors nice JJ
# pos KeyErrors off IN
# pos KeyErrors but CC
# pos KeyErrors at IN
# pos KeyErrors comfortable JJ
# pos KeyErrors in IN
# pos KeyErrors own JJ
# pos KeyErrors like IN
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors professional JJ
# pos KeyErrors all PDT
# pos KeyErrors will MD
# pos KeyErrors around IN
# pos KeyErrors on IN
# pos KeyErrors 1 CD
# pos KeyErrors all DT
# pos KeyErrors or CC
# pos KeyErrors outlandish JJ
# pos KeyErrors wild JJ
# pos KeyErrors much JJ
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors at IN
# pos KeyErrors or CC
# pos KeyErrors at IN
# pos KeyErrors or CC
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors past JJ
# pos KeyErrors it PRP
# pos KeyErrors will MD
# pos KeyErrors will MD
# pos KeyErrors no DT
# pos KeyErrors he PRP
# pos KeyErrors in IN
# pos KeyErrors some DT
# pos KeyErrors amazing JJ
# pos KeyErrors relevant JJ
# pos KeyErrors current JJ
# pos KeyErrors overall JJ
# pos KeyErrors it PRP
# pos KeyErrors me PRP
# pos KeyErrors 6 CD
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors web JJ
# pos KeyErrors 3 CD
# pos KeyErrors 12 CD
# pos KeyErrors a DT
# pos KeyErrors other JJ
# pos KeyErrors 4 CD
# pos KeyErrors off IN
# pos KeyErrors me PRP
# pos KeyErrors much JJ
# pos KeyErrors on IN
# pos KeyErrors me PRP
# pos KeyErrors but CC
# IndexErrors (not found) i VBZ
# pos KeyErrors in IN
# pos KeyErrors in IN
# IndexErrors (not found) i VB
# pos KeyErrors switched JJ
# pos KeyErrors due JJ
# IndexErrors (not found) happiness VB
# pos KeyErrors every DT
# pos KeyErrors like IN
# pos KeyErrors many JJ
# pos KeyErrors no DT
# pos KeyErrors long JJ
# pos KeyErrors it PRP
# pos KeyErrors me PRP
# pos KeyErrors any DT
# pos KeyErrors below IN
# pos KeyErrors much JJ
# pos KeyErrors can MD
# pos KeyErrors any DT
# pos KeyErrors a DT
# pos KeyErrors web JJ
# pos KeyErrors best JJS
# pos KeyErrors much JJ
# pos KeyErrors as IN
# pos KeyErrors can MD
# pos KeyErrors on IN
# pos KeyErrors but CC
# IndexErrors (not found) i RB
# pos KeyErrors around IN
# pos KeyErrors last JJ
# pos KeyErrors after IN
# pos KeyErrors about IN
# pos KeyErrors it PRP
# pos KeyErrors through IN
# pos KeyErrors a DT
# pos KeyErrors i JJ
# pos KeyErrors some DT
# pos KeyErrors at IN
# pos KeyErrors it PRP
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors good JJ
# pos KeyErrors other JJ
# pos KeyErrors out IN
# IndexErrors (not found) i VB
# pos KeyErrors me PRP
# IndexErrors (not found) practising NN
# pos KeyErrors a DT
# pos KeyErrors as IN
# pos KeyErrors a DT
# IndexErrors (not found) i VB
# pos KeyErrors many JJ
# pos KeyErrors many JJ
# pos KeyErrors through IN
# pos KeyErrors some DT
# pos KeyErrors main JJ
# pos KeyErrors it PRP
# pos KeyErrors at IN
# pos KeyErrors least JJS
# pos KeyErrors a DT
# pos KeyErrors interested JJ
# pos KeyErrors i JJ
# pos KeyErrors picky JJ
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors january JJ
# pos KeyErrors on IN
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors pro JJ
# pos KeyErrors it PRP
# pos KeyErrors in IN
# pos KeyErrors an DT
# pos KeyErrors me PRP
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors small JJ
# pos KeyErrors gig JJ
# pos KeyErrors i JJ
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors able JJ
# pos KeyErrors current JJ
# pos KeyErrors at IN
# pos KeyErrors first JJ
# pos KeyErrors full JJ
# pos KeyErrors a DT
# pos KeyErrors me PRP
# pos KeyErrors any DT
# pos KeyErrors front JJ
# pos KeyErrors me PRP
# pos KeyErrors about IN
# IndexErrors (not found) i VBP
# IndexErrors (not found) knew NNS
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors small JJ
# pos KeyErrors real JJ
# pos KeyErrors similar JJ
# pos KeyErrors a DT
# pos KeyErrors overall JJ
# pos KeyErrors on IN
# pos KeyErrors own JJ
# pos KeyErrors helpful JJ
# pos KeyErrors i JJ
# pos KeyErrors own JJ
# pos KeyErrors though IN
# pos KeyErrors likely JJ
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors similar JJ
# pos KeyErrors it PRP
# pos KeyErrors own JJ
# pos KeyErrors will MD
# pos KeyErrors all DT
# pos KeyErrors it PRP
# pos KeyErrors own JJ
# pos KeyErrors a DT
# IndexErrors (not found) i RB
# pos KeyErrors out IN
# pos KeyErrors possible JJ
# pos KeyErrors a DT
# pos KeyErrors hard JJ
# IndexErrors (not found) i RB
# pos KeyErrors awesome JJ
# pos KeyErrors me PRP
# pos KeyErrors motivated JJ
# pos KeyErrors every DT
# pos KeyErrors much JJ
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors last JJ
# pos KeyErrors 34 CD
# pos KeyErrors old JJ
# pos KeyErrors front JJ
# pos KeyErrors self PRP
# pos KeyErrors like IN
# pos KeyErrors most JJS
# pos KeyErrors no DT
# pos KeyErrors or CC
# pos KeyErrors a DT
# pos KeyErrors couple JJ
# pos KeyErrors ago IN
# pos KeyErrors a DT
# pos KeyErrors little JJ
# pos KeyErrors about IN
# pos KeyErrors after IN
# pos KeyErrors a DT
# pos KeyErrors long JJ
# pos KeyErrors free JJ
# pos KeyErrors on IN
# IndexErrors (not found) taught NN
# pos KeyErrors its PRP$
# pos KeyErrors a DT
# pos KeyErrors at IN
# pos KeyErrors a DT
# pos KeyErrors great JJ
# pos KeyErrors by IN
# pos KeyErrors vast JJ
# pos KeyErrors on IN
# pos KeyErrors but CC
# IndexErrors (not found) losing NN
# pos KeyErrors in IN
# pos KeyErrors i JJ
# pos KeyErrors it PRP
# IndexErrors (not found) friend VB
# pos KeyErrors a DT
# pos KeyErrors better JJR
# pos KeyErrors us PRP
# pos KeyErrors on IN
# pos KeyErrors a DT
# pos KeyErrors long JJ
# pos KeyErrors can MD
# pos KeyErrors a DT
# pos KeyErrors upper JJ
# pos KeyErrors i JJ
# IndexErrors (not found) though NN
# pos KeyErrors a DT
# pos KeyErrors restricted JJ
# pos KeyErrors around IN
# pos KeyErrors free JJ
# pos KeyErrors like IN
# pos KeyErrors why WRB
# pos KeyErrors can MD
# pos KeyErrors all DT
# pos KeyErrors over IN
# pos KeyErrors some DT
# pos KeyErrors usual JJ
# pos KeyErrors great JJ
# pos KeyErrors on IN
# pos KeyErrors current JJ
# pos KeyErrors on IN
# pos KeyErrors different JJ
# pos KeyErrors front JJ
# pos KeyErrors at IN
# pos KeyErrors only JJ
# pos KeyErrors front JJ
# pos KeyErrors on IN
# pos KeyErrors a DT
# pos KeyErrors 25 CD
# pos KeyErrors me PRP
# pos KeyErrors but CC
# IndexErrors (not found) somehow VBP
# pos KeyErrors it PRP
# pos KeyErrors munch JJ
# pos KeyErrors a DT
# pos KeyErrors able JJ
# pos KeyErrors on IN
# pos KeyErrors or CC
# IndexErrors (not found) i VBP
# pos KeyErrors on IN
# pos KeyErrors another DT
# pos KeyErrors me PRP
# pos KeyErrors upset JJ
# pos KeyErrors uneducated JJ
# pos KeyErrors in IN
# pos KeyErrors high JJ
# pos KeyErrors a DT
# pos KeyErrors 80 CD
# pos KeyErrors mechanical JJ
# pos KeyErrors on IN
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors new JJ
# pos KeyErrors 4 CD
# pos KeyErrors on IN
# pos KeyErrors current JJ
# IndexErrors (not found) i VB
# pos KeyErrors rentable JJ
# pos KeyErrors lucky JJ
# pos KeyErrors will MD
# pos KeyErrors able JJ
# pos KeyErrors in IN
# pos KeyErrors 2 CD
# pos KeyErrors or CC
# pos KeyErrors 3 CD
# pos KeyErrors hard JJ
# pos KeyErrors a DT
# pos KeyErrors more JJR
# pos KeyErrors so IN
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors or CC
# pos KeyErrors like IN
# pos KeyErrors impossible JJ
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors remote JJ
# pos KeyErrors on IN
# pos KeyErrors allow IN
# pos KeyErrors about IN
# pos KeyErrors or CC
# pos KeyErrors a DT
# pos KeyErrors some DT
# pos KeyErrors like IN
# pos KeyErrors german JJ
# pos KeyErrors let JJ
# pos KeyErrors international JJ
# pos KeyErrors a DT
# IndexErrors (not found) theres VBZ
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors current JJ
# pos KeyErrors free JJ
# pos KeyErrors a DT
# pos KeyErrors online JJ
# pos KeyErrors online JJ
# pos KeyErrors like IN
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors personal JJ
# pos KeyErrors on IN
# IndexErrors (not found) i VB
# pos KeyErrors why WRB
# IndexErrors (not found) realize NN
# pos KeyErrors or CC
# pos KeyErrors about IN
# pos KeyErrors important JJ
# pos KeyErrors outside IN
# IndexErrors (not found) i VB
# pos KeyErrors ta JJ
# IndexErrors (not found) i VBP
# pos KeyErrors a DT
# pos KeyErrors better JJR
# pos KeyErrors little JJ
# IndexErrors (not found) i VB
# pos KeyErrors programming JJ
# pos KeyErrors but CC
# pos KeyErrors i JJ
# pos KeyErrors some DT
# IndexErrors (not found) i VBP
# pos KeyErrors like IN
# pos KeyErrors pragmatic JJ
# pos KeyErrors about IN
# IndexErrors (not found) taught NN
# pos KeyErrors sure JJ
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors but CC
# pos KeyErrors some DT
# pos KeyErrors a DT
# pos KeyErrors or CC
# pos KeyErrors a DT
# pos KeyErrors before IN
# IndexErrors (not found) concise VBN
# pos KeyErrors but CC
# pos KeyErrors effective JJ
# pos KeyErrors about IN
# pos KeyErrors me PRP
# pos KeyErrors 23 CD
# pos KeyErrors afford JJ
# pos KeyErrors no DT
# pos KeyErrors us PRP
# pos KeyErrors strong JJ
# pos KeyErrors technical JJ
# pos KeyErrors impatient JJ
# pos KeyErrors at IN
# pos KeyErrors 13 CD
# pos KeyErrors at IN
# IndexErrors (not found) i VBZ
# pos KeyErrors developer IN
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors me PRP
# pos KeyErrors some DT
# pos KeyErrors challenging JJ
# pos KeyErrors an DT
# pos KeyErrors angular JJ
# pos KeyErrors 2 CD
# pos KeyErrors on IN
# pos KeyErrors some DT
# pos KeyErrors like IN
# pos KeyErrors five CD
# pos KeyErrors eight CD
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors after IN
# pos KeyErrors may MD
# pos KeyErrors relevant JJ
# pos KeyErrors after IN
# pos KeyErrors he PRP
# pos KeyErrors degree JJ
# pos KeyErrors needless JJ
# pos KeyErrors a DT
# pos KeyErrors at IN
# pos KeyErrors a DT
# pos KeyErrors 10 CD
# pos KeyErrors it PRP
# pos KeyErrors best JJS
# pos KeyErrors it PRP
# pos KeyErrors 0 CD
# pos KeyErrors 100 CD
# pos KeyErrors other JJ
# pos KeyErrors prototype JJ
# pos KeyErrors an DT
# pos KeyErrors updated JJ
# pos KeyErrors i JJ
# pos KeyErrors after IN
# IndexErrors (not found) i VBP
# pos KeyErrors on IN
# pos KeyErrors angular JJ
# pos KeyErrors 1 CD
# pos KeyErrors x JJ
# pos KeyErrors after IN
# IndexErrors (not found) i VB
# pos KeyErrors brave JJ
# IndexErrors (not found) i VB
# pos KeyErrors through IN
# pos KeyErrors a DT
# pos KeyErrors big JJ
# pos KeyErrors a DT
# pos KeyErrors through IN
# pos KeyErrors large JJ
# pos KeyErrors hard JJ
# pos KeyErrors at IN
# pos KeyErrors in IN
# IndexErrors (not found) e RB
# pos KeyErrors a DT
# pos KeyErrors front JJ
# IndexErrors (not found) angular NN
# pos KeyErrors or CC
# pos KeyErrors after IN
# pos KeyErrors about IN
# pos KeyErrors 8 CD
# pos KeyErrors or CC
# pos KeyErrors 9 CD
# pos KeyErrors on IN
# pos KeyErrors applied JJ
# IndexErrors (not found) recruiter VB
# pos KeyErrors after IN
# pos KeyErrors impressive JJ
# pos KeyErrors as IN
# pos KeyErrors possible JJ
# pos KeyErrors prayed JJ
# pos KeyErrors a DT
# pos KeyErrors after IN
# pos KeyErrors on IN
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors 3 CD
# pos KeyErrors at IN
# pos KeyErrors a DT
# pos KeyErrors but CC
# pos KeyErrors will MD
# pos KeyErrors skeptical JJ
# pos KeyErrors a DT
# pos KeyErrors most JJS
# pos KeyErrors me PRP
# pos KeyErrors cosmopolitan JJ
# pos KeyErrors worthy JJ
# pos KeyErrors though IN
# pos KeyErrors important JJ
# pos KeyErrors all DT
# pos KeyErrors a DT
# pos KeyErrors top JJ
# pos KeyErrors most JJS
# pos KeyErrors indian JJ
# pos KeyErrors spam JJ
# pos KeyErrors will MD
# pos KeyErrors ineligible JJ
# pos KeyErrors wherever IN
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors whole JJ
# pos KeyErrors a DT
# pos KeyErrors can MD
# pos KeyErrors build JJ
# pos KeyErrors more JJR
# pos KeyErrors in IN
# pos KeyErrors likely JJ
# pos KeyErrors a DT
# pos KeyErrors on IN
# pos KeyErrors cosmopolitan JJ
# IndexErrors (not found) worthy VBP
# pos KeyErrors avoid JJ
# pos KeyErrors retail JJ
# IndexErrors (not found) half VB
# pos KeyErrors will MD
# pos KeyErrors proficient JJ
# pos KeyErrors there EX
# pos KeyErrors will MD
# pos KeyErrors more JJR
# pos KeyErrors on IN
# pos KeyErrors can MD
# pos KeyErrors a DT
# pos KeyErrors coding JJ
# pos KeyErrors at IN
# pos KeyErrors arizona JJ
# pos KeyErrors major JJ
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors logical JJ
# pos KeyErrors at IN
# pos KeyErrors all DT
# pos KeyErrors social JJ
# pos KeyErrors whatever WDT
# pos KeyErrors much JJ
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors may MD
# pos KeyErrors but CC
# pos KeyErrors will MD
# pos KeyErrors more JJR
# pos KeyErrors motivated JJ
# IndexErrors (not found) learn NN
# pos KeyErrors after IN
# pos KeyErrors all DT
# pos KeyErrors a DT
# pos KeyErrors a DT
# IndexErrors (not found) afraid VBN
# IndexErrors (not found) i VB
# pos KeyErrors at IN
# pos KeyErrors a DT
# pos KeyErrors fair JJ
# pos KeyErrors okay JJ
# pos KeyErrors will MD
# pos KeyErrors many JJ
# pos KeyErrors but CC
# pos KeyErrors it PRP
# pos KeyErrors will MD
# pos KeyErrors worth IN
# pos KeyErrors it PRP
# pos KeyErrors free JJ
# pos KeyErrors lost JJS
# pos KeyErrors 9 CD
# pos KeyErrors 5 CD
# pos KeyErrors good JJ
# pos KeyErrors a DT
# IndexErrors (not found) whatever NN
# pos KeyErrors important JJ
# IndexErrors (not found) networking NN
# pos KeyErrors many JJ
# pos KeyErrors over IN
# IndexErrors (not found) i VBP
# pos KeyErrors there EX
# pos KeyErrors likeable JJ
# pos KeyErrors at IN
# pos KeyErrors likely JJ
# pos KeyErrors a DT
# pos KeyErrors who WP
# pos KeyErrors nice JJ
# pos KeyErrors good JJ
# pos KeyErrors at IN
# IndexErrors (not found) afraid VBN
# pos KeyErrors in IN
# IndexErrors (not found) ask NN
# pos KeyErrors a DT
# pos KeyErrors there EX
# pos KeyErrors who WP
# pos KeyErrors me PRP
# IndexErrors (not found) i VB
# pos KeyErrors sure JJ
# pos KeyErrors at IN
# IndexErrors (not found) i VBP
# pos KeyErrors all DT
# IndexErrors (not found) emotionally NN
# pos KeyErrors least JJS
# pos KeyErrors favorite JJ
# pos KeyErrors cool JJ
# pos KeyErrors fcc JJ
# pos KeyErrors thank IN
# pos KeyErrors or CC
# pos KeyErrors like IN
# pos KeyErrors a DT
# pos KeyErrors great JJ
# pos KeyErrors on IN
# IndexErrors (not found) react NN
# IndexErrors (not found) egghead VB
# pos KeyErrors io JJ
# IndexErrors (not found) io VB
# pos KeyErrors other JJ
# pos KeyErrors learned JJ
# pos KeyErrors in IN
# pos KeyErrors will MD
# pos KeyErrors up IN
# pos KeyErrors a DT
# pos KeyErrors or CC
# pos KeyErrors library JJ
# pos KeyErrors one CD
# pos KeyErrors sure JJ
# pos KeyErrors it PRP
# pos KeyErrors it PRP
# pos KeyErrors several JJ
# pos KeyErrors in IN
# pos KeyErrors past JJ
# pos KeyErrors all DT
# pos KeyErrors little JJ
# pos KeyErrors through IN
# pos KeyErrors by IN
# pos KeyErrors why WRB
# pos KeyErrors it PRP
# pos KeyErrors much JJ
# pos KeyErrors faster JJR
# pos KeyErrors will MD
# pos KeyErrors at IN
# pos KeyErrors difficult JJ
# pos KeyErrors need JJ
# pos KeyErrors a DT
# pos KeyErrors there EX
# pos KeyErrors will MD
# pos KeyErrors a DT
# pos KeyErrors sure JJ
# pos KeyErrors i JJ
# pos KeyErrors me PRP
# pos KeyErrors i JJ
# pos KeyErrors i JJ
# pos KeyErrors i JJ
# pos KeyErrors in IN
# pos KeyErrors i JJ
# pos KeyErrors like IN
# pos KeyErrors there EX
# pos KeyErrors few JJ
# pos KeyErrors american JJ
# pos KeyErrors off IN
# pos KeyErrors fellow JJ
# IndexErrors (not found) proud NN
# pos KeyErrors a DT
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors full JJ
# pos KeyErrors i JJ
# pos KeyErrors next JJ
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors long JJ
# pos KeyErrors after IN
# pos KeyErrors on IN
# pos KeyErrors long JJ
# pos KeyErrors it PRP
# pos KeyErrors before IN
# pos KeyErrors a DT
# pos KeyErrors own JJ
# pos KeyErrors 2 CD
# pos KeyErrors along IN
# pos KeyErrors some DT
# pos KeyErrors some DT
# pos KeyErrors additional JJ
# pos KeyErrors all PDT
# pos KeyErrors local JJ
# pos KeyErrors throughout IN
# pos KeyErrors me PRP
# pos KeyErrors in IN
# pos KeyErrors a DT
# IndexErrors (not found) surreal VB
# pos KeyErrors all DT
# pos KeyErrors hard JJ
# pos KeyErrors first JJ
# pos KeyErrors in IN
# pos KeyErrors it PRP
# pos KeyErrors through IN
# pos KeyErrors in IN
# pos KeyErrors 9 CD
# pos KeyErrors 2 CD
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors open JJ
# pos KeyErrors good JJ
# pos KeyErrors a DT
# pos KeyErrors new JJ
# pos KeyErrors another DT
# pos KeyErrors in IN
# pos KeyErrors weekly JJ
# pos KeyErrors a DT
# pos KeyErrors upcoming JJ
# pos KeyErrors it PRP
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors about IN
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors general JJ
# pos KeyErrors can MD
# pos KeyErrors a DT
# pos KeyErrors free JJ
# pos KeyErrors on IN
# pos KeyErrors but CC
# pos KeyErrors on IN
# pos KeyErrors a DT
# pos KeyErrors other JJ
# pos KeyErrors difficult JJ
# pos KeyErrors outside IN
# pos KeyErrors i JJ
# pos KeyErrors enough IN
# IndexErrors (not found) networking NN
# pos KeyErrors out IN
# pos KeyErrors necessary JJ
# pos KeyErrors great JJ
# pos KeyErrors strong JJ
# pos KeyErrors important JJ
# pos KeyErrors aware JJ
# pos KeyErrors available JJ
# pos KeyErrors capable JJ
# pos KeyErrors i JJ
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors remote JJ
# pos KeyErrors a DT
# pos KeyErrors but CC
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors weekly JJ
# pos KeyErrors at IN
# pos KeyErrors a DT
# pos KeyErrors by IN
# pos KeyErrors professional JJ
# pos KeyErrors as IN
# pos KeyErrors on IN
# pos KeyErrors on IN
# pos KeyErrors or CC
# pos KeyErrors on IN
# pos KeyErrors me PRP
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors must MD
# pos KeyErrors on IN
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors human JJ
# pos KeyErrors any DT
# pos KeyErrors any DT
# pos KeyErrors an DT
# pos KeyErrors enormous JJ
# pos KeyErrors high JJ
# IndexErrors (not found) involves NNS
# pos KeyErrors objective JJ
# pos KeyErrors a DT
# pos KeyErrors mobile JJ
# pos KeyErrors any DT
# pos KeyErrors a DT
# pos KeyErrors mobile JJ
# pos KeyErrors but CC
# pos KeyErrors confident JJ
# pos KeyErrors on IN
# pos KeyErrors he PRP
# pos KeyErrors about IN
# pos KeyErrors me PRP
# pos KeyErrors unlikely JJ
# pos KeyErrors an DT
# pos KeyErrors secret JJ
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors most JJS
# pos KeyErrors any DT
# ...
# pos KeyErrors about IN
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors out IN
# pos KeyErrors before IN
# pos KeyErrors some DT
# pos KeyErrors like IN
# pos KeyErrors but CC
# pos KeyErrors most JJS
# pos KeyErrors organic JJ
# pos KeyErrors a DT
# pos KeyErrors nanny JJ
# IndexErrors (not found) fcc RB
# pos KeyErrors after IN
# pos KeyErrors most JJS
# pos KeyErrors on IN
# pos KeyErrors while IN
# pos KeyErrors other JJ
# pos KeyErrors around IN
# pos KeyErrors while IN
# pos KeyErrors but CC
# pos KeyErrors i JJ
# pos KeyErrors on IN
# pos KeyErrors in IN
# pos KeyErrors may MD
# pos KeyErrors nanny JJ
# pos KeyErrors grateful JJ
# pos KeyErrors open JJ
# pos KeyErrors while IN
# pos KeyErrors a DT
# pos KeyErrors full JJ
# pos KeyErrors several JJ
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors tech JJ
# pos KeyErrors related JJ
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors techy JJ
# pos KeyErrors me PRP
# pos KeyErrors about IN
# pos KeyErrors a DT
# pos KeyErrors some DT
# pos KeyErrors minor JJ
# pos KeyErrors a DT
# pos KeyErrors highest JJS
# pos KeyErrors after IN
# pos KeyErrors a DT
# pos KeyErrors couple JJ
# pos KeyErrors an DT
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors web JJ
# pos KeyErrors me PRP
# pos KeyErrors next JJ
# pos KeyErrors i JJ
# pos KeyErrors vague JJ
# pos KeyErrors no DT
# pos KeyErrors at IN
# pos KeyErrors all DT
# pos KeyErrors about IN
# pos KeyErrors except IN
# pos KeyErrors in IN
# IndexErrors (not found) adobe VBP
# pos KeyErrors in IN
# IndexErrors (not found) i VBP
# pos KeyErrors note JJ
# pos KeyErrors an DT
# pos KeyErrors but CC
# pos KeyErrors a DT
# pos KeyErrors small JJ
# pos KeyErrors in IN
# pos KeyErrors or CC
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors responsive JJ
# pos KeyErrors in IN
# pos KeyErrors but CC
# pos KeyErrors on IN
# pos KeyErrors a DT
# pos KeyErrors conversational JJ
# pos KeyErrors a DT
# pos KeyErrors gigantic JJ
# pos KeyErrors as IN
# pos KeyErrors an DT
# pos KeyErrors chrome JJ
# pos KeyErrors about IN
# pos KeyErrors clean JJ
# pos KeyErrors on IN
# pos KeyErrors in IN
# pos KeyErrors general JJ
# pos KeyErrors impostor JJ
# pos KeyErrors can MD
# pos KeyErrors wary JJ
# pos KeyErrors about IN
# pos KeyErrors as IN
# pos KeyErrors arrogant JJ
# pos KeyErrors or CC
# pos KeyErrors it PRP
# pos KeyErrors like IN
# pos KeyErrors salary JJ
# pos KeyErrors career JJ
# pos KeyErrors quiet JJ
# pos KeyErrors non JJ
# pos KeyErrors confrontational JJ
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors salary JJ
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors little JJ
# pos KeyErrors in IN
# pos KeyErrors it PRP
# pos KeyErrors last JJ
# pos KeyErrors many JJ
# pos KeyErrors an DT
# pos KeyErrors hourly JJ
# pos KeyErrors i JJ
# pos KeyErrors about IN
# pos KeyErrors it PRP
# pos KeyErrors about IN
# IndexErrors (not found) i RB
# pos KeyErrors salary JJ
# pos KeyErrors higher JJR
# IndexErrors (not found) behold NN
# pos KeyErrors after IN
# IndexErrors (not found) i RB
# pos KeyErrors an DT
# pos KeyErrors a DT
# pos KeyErrors second JJ
# pos KeyErrors by IN
# pos KeyErrors it PRP
# pos KeyErrors through IN
# pos KeyErrors salary JJ
# pos KeyErrors willing JJ
# pos KeyErrors further JJ
# pos KeyErrors in IN
# pos KeyErrors 6 CD
# pos KeyErrors perspective JJ
# pos KeyErrors at IN
# pos KeyErrors after IN
# pos KeyErrors there EX
# pos KeyErrors every DT
# pos KeyErrors on IN
# pos KeyErrors there EX
# pos KeyErrors on IN
# pos KeyErrors sure JJ
# pos KeyErrors some DT
# IndexErrors (not found) backtracking NN
# pos KeyErrors but CC
# pos KeyErrors there EX
# pos KeyErrors no DT
# pos KeyErrors over IN
# pos KeyErrors i JJ
# pos KeyErrors free JJ
# pos KeyErrors like IN
# pos KeyErrors a DT
# pos KeyErrors virtual JJ
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors local JJ
# pos KeyErrors as IN
# pos KeyErrors can MD
# IndexErrors (not found) i VB
# pos KeyErrors a DT
# pos KeyErrors website JJ
# pos KeyErrors it PRP
# IndexErrors (not found) matter RBR
# pos KeyErrors it PRP
# pos KeyErrors one CD
# IndexErrors (not found) up NN
# pos KeyErrors valuable JJ
# pos KeyErrors it PRP
# pos KeyErrors great JJ
# pos KeyErrors on IN
# pos KeyErrors about IN
# pos KeyErrors cool JJ
# pos KeyErrors like IN
# pos KeyErrors modular JJ
# pos KeyErrors functional JJ
# pos KeyErrors out IN
# pos KeyErrors a DT
# pos KeyErrors will MD
# pos KeyErrors a DT
# pos KeyErrors me PRP
# pos KeyErrors uncomfortable JJ
# pos KeyErrors its PRP$
# IndexErrors (not found) afraid VBN
# pos KeyErrors in IN
# pos KeyErrors free JJ
# pos KeyErrors all PDT
# pos KeyErrors free JJ
# pos KeyErrors out IN
# pos KeyErrors but CC
# pos KeyErrors there EX
# pos KeyErrors some DT
# pos KeyErrors me PRP
# pos KeyErrors right JJ
# pos KeyErrors about IN
# pos KeyErrors me PRP
# pos KeyErrors many JJ
# pos KeyErrors over IN
# pos KeyErrors insanely JJ
# pos KeyErrors clear JJ
# pos KeyErrors big JJ
# pos KeyErrors on IN
# pos KeyErrors best JJS
# pos KeyErrors a DT
# pos KeyErrors best JJS
# pos KeyErrors by IN
# pos KeyErrors who WP
# pos KeyErrors can MD
# pos KeyErrors a DT
# pos KeyErrors huge JJ
# pos KeyErrors stuck JJ
# IndexErrors (not found) i VB
# pos KeyErrors many JJ
# IndexErrors (not found) gotten NNS
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors about IN
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors glorious JJ
# pos KeyErrors a DT
# pos KeyErrors cool JJ
# pos KeyErrors a DT
# pos KeyErrors good JJ
# pos KeyErrors in IN
# pos KeyErrors in IN
# pos KeyErrors awesome JJ
# pos KeyErrors a DT
# pos KeyErrors cover JJ
# pos KeyErrors more JJR
# pos KeyErrors more JJR
# pos KeyErrors can MD
# pos KeyErrors at IN
# pos KeyErrors twitter JJ
# pos KeyErrors in IN
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors but CC
# pos KeyErrors on IN
# pos KeyErrors around IN
# pos KeyErrors new JJ
# pos KeyErrors live JJ
# pos KeyErrors it PRP
# pos KeyErrors i JJ
# pos KeyErrors any DT
# pos KeyErrors though IN
# pos KeyErrors all DT
# pos KeyErrors a DT
# pos KeyErrors simple JJ
# pos KeyErrors much JJ
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors no DT
# pos KeyErrors no DT
# pos KeyErrors real JJ
# IndexErrors (not found) i VB
# pos KeyErrors as IN
# pos KeyErrors possible JJ
# pos KeyErrors a DT
# pos KeyErrors few JJ
# pos KeyErrors a DT
# pos KeyErrors polish JJ
# pos KeyErrors a DT
# pos KeyErrors after IN
# pos KeyErrors first JJ
# pos KeyErrors in IN
# pos KeyErrors it PRP
# pos KeyErrors much JJ
# pos KeyErrors dumb JJ
# pos KeyErrors luck LS
# pos KeyErrors a DT
# pos KeyErrors junior JJ
# IndexErrors (not found) asap NN
# IndexErrors (not found) i VBP
# pos KeyErrors a DT
# pos KeyErrors modest JJ
# pos KeyErrors i JJ
# pos KeyErrors several JJ
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors junior JJ
# IndexErrors (not found) i RB
# pos KeyErrors in IN
# pos KeyErrors nervous JJ
# pos KeyErrors i JJ
# IndexErrors (not found) i VBP
# pos KeyErrors by IN
# IndexErrors (not found) i VB
# pos KeyErrors at IN
# IndexErrors (not found) blankly VBZ
# pos KeyErrors like IN
# pos KeyErrors a DT
# pos KeyErrors possessed JJ
# pos KeyErrors a DT
# pos KeyErrors about IN
# pos KeyErrors 15 CD
# pos KeyErrors me PRP
# pos KeyErrors me PRP
# pos KeyErrors like IN
# pos KeyErrors wrong JJ
# pos KeyErrors it PRP
# pos KeyErrors 0 CD
# pos KeyErrors i JJ
# pos KeyErrors 5 CD
# IndexErrors (not found) i RB
# pos KeyErrors 1000 CD
# pos KeyErrors it PRP
# pos KeyErrors an DT
# pos KeyErrors so IN
# pos KeyErrors 0 CD
# pos KeyErrors 1 CD
# pos KeyErrors i JJ
# pos KeyErrors 5 CD
# pos KeyErrors 5 CD
# pos KeyErrors well UH
# pos KeyErrors other JJ
# pos KeyErrors about IN
# pos KeyErrors prototypal JJ
# pos KeyErrors one CD
# pos KeyErrors biggest JJS
# pos KeyErrors 5 CD
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors like IN
# pos KeyErrors some DT
# pos KeyErrors basic JJ
# pos KeyErrors me PRP
# pos KeyErrors about IN
# pos KeyErrors i JJ
# pos KeyErrors or CC
# pos KeyErrors asynchronous JJ
# pos KeyErrors there EX
# pos KeyErrors no DT
# pos KeyErrors great JJ
# pos KeyErrors no DT
# pos KeyErrors useful JJ
# pos KeyErrors can MD
# pos KeyErrors new JJ
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors it PRP
# pos KeyErrors doable JJ
# pos KeyErrors or CC
# pos KeyErrors okay JJ
# pos KeyErrors every DT
# pos KeyErrors but CC
# pos KeyErrors some DT
# IndexErrors (not found) i VB
# pos KeyErrors 1 CD
# pos KeyErrors or CC
# pos KeyErrors 2 CD
# pos KeyErrors some DT
# IndexErrors (not found) i VBP
# pos KeyErrors lazy JJ
# IndexErrors (not found) i VB
# pos KeyErrors some DT
# pos KeyErrors on IN
# pos KeyErrors best JJS
# pos KeyErrors me PRP
# pos KeyErrors but CC
# pos KeyErrors helpful JJ
# pos KeyErrors all PDT
# pos KeyErrors by IN
# pos KeyErrors but CC
# pos KeyErrors an DT
# pos KeyErrors important JJ
# pos KeyErrors but CC
# pos KeyErrors in IN
# pos KeyErrors me PRP
# pos KeyErrors can MD
# pos KeyErrors so IN
# IndexErrors (not found) i RB
# pos KeyErrors fcc JJ
# pos KeyErrors best JJS
# IndexErrors (not found) i VBP
# pos KeyErrors it PRP
# pos KeyErrors all DT
# pos KeyErrors possible JJ
# pos KeyErrors all DT
# pos KeyErrors on IN
# pos KeyErrors nervous JJ
# pos KeyErrors wish JJ
# pos KeyErrors me PRP
# pos KeyErrors luck JJ
# pos KeyErrors a DT
# pos KeyErrors perfect JJ
# pos KeyErrors at IN
# pos KeyErrors on IN
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors huge JJ
# pos KeyErrors a DT
# pos KeyErrors different JJ
# pos KeyErrors a DT
# pos KeyErrors web JJ
# pos KeyErrors or CC
# pos KeyErrors an DT
# pos KeyErrors on IN
# pos KeyErrors on IN
# pos KeyErrors own JJ
# pos KeyErrors a DT
# pos KeyErrors own JJ
# pos KeyErrors powerful JJ
# pos KeyErrors but CC
# pos KeyErrors hard JJ
# pos KeyErrors in IN
# pos KeyErrors so IN
# pos KeyErrors i JJ
# pos KeyErrors comfortable JJ
# pos KeyErrors but CC
# IndexErrors (not found) i VBZ
# pos KeyErrors after IN
# pos KeyErrors 8 CD
# pos KeyErrors worth IN
# pos KeyErrors like IN
# pos KeyErrors me PRP
# pos KeyErrors learn JJ
# pos KeyErrors but CC
# pos KeyErrors all DT
# pos KeyErrors in IN
# pos KeyErrors all DT
# pos KeyErrors i JJ
# pos KeyErrors sure JJ
# pos KeyErrors can MD
# pos KeyErrors a DT
# IndexErrors (not found) i RB
# pos KeyErrors but CC
# pos KeyErrors happy JJ
# IndexErrors (not found) thank NN
# pos KeyErrors all DT
# pos KeyErrors me PRP
# pos KeyErrors luck JJ
# pos KeyErrors me PRP
# pos KeyErrors on IN
# pos KeyErrors or CC
# pos KeyErrors na TO
# pos KeyErrors or CC
# IndexErrors (not found) chat RB
# pos KeyErrors fellow JJ
# pos KeyErrors after IN
# pos KeyErrors many JJ
# pos KeyErrors many JJ
# pos KeyErrors an DT
# pos KeyErrors a DT
# pos KeyErrors couple JJ
# pos KeyErrors an DT
# pos KeyErrors a DT
# pos KeyErrors same JJ
# pos KeyErrors excited JJ
# pos KeyErrors who WP
# pos KeyErrors it PRP
# pos KeyErrors i JJ
# IndexErrors (not found) gaining NN
# pos KeyErrors through IN
# pos KeyErrors a DT
# pos KeyErrors full JJ
# pos KeyErrors a DT
# pos KeyErrors little JJ
# pos KeyErrors in IN
# pos KeyErrors free JJ
# pos KeyErrors some DT
# pos KeyErrors helpful JJ
# pos KeyErrors all DT
# pos KeyErrors me PRP
# pos KeyErrors can MD
# IndexErrors (not found) i VB
# pos KeyErrors full JJ
# pos KeyErrors any DT
# pos KeyErrors excited JJ
# pos KeyErrors terrified JJ
# pos KeyErrors first JJ
# pos KeyErrors a DT
# pos KeyErrors front JJ
# pos KeyErrors html JJ
# pos KeyErrors i JJ
# pos KeyErrors upfront JJ
# pos KeyErrors honest JJS
# pos KeyErrors i JJ
# pos KeyErrors self JJ
# IndexErrors (not found) taught NN
# pos KeyErrors through IN
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors me PRP
# pos KeyErrors no DT
# pos KeyErrors but CC
# pos KeyErrors i JJ
# pos KeyErrors all DT
# IndexErrors (not found) i VB
# pos KeyErrors it PRP
# pos KeyErrors all DT
# pos KeyErrors after IN
# pos KeyErrors about IN
# pos KeyErrors a DT
# pos KeyErrors a DT
# pos KeyErrors few JJ
# pos KeyErrors 8 CD
# pos KeyErrors an DT
# pos KeyErrors amazing JJ
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors front JJ
# pos KeyErrors huge JJ
# pos KeyErrors out IN
# pos KeyErrors all DT
# IndexErrors (not found) i RB
# pos KeyErrors so IN
# pos KeyErrors a DT
# pos KeyErrors little JJ
# pos KeyErrors about IN
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors few JJ
# pos KeyErrors in IN
# IndexErrors (not found) i RB
# pos KeyErrors front JJ
# pos KeyErrors most JJS
# IndexErrors (not found) react NN
# pos KeyErrors or CC
# pos KeyErrors 2 CD
# pos KeyErrors full JJ
# pos KeyErrors after IN
# IndexErrors (not found) i VB
# pos KeyErrors on IN
# pos KeyErrors more JJR
# pos KeyErrors fine JJ
# pos KeyErrors old JJ
# pos KeyErrors some DT
# pos KeyErrors a DT
# pos KeyErrors as IN
# pos KeyErrors there EX
# pos KeyErrors a DT
# pos KeyErrors like JJ
# pos KeyErrors a DT
# pos KeyErrors 2 CD
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors first JJ
# pos KeyErrors few JJ
# pos KeyErrors in IN
# pos KeyErrors in IN
# pos KeyErrors some DT
# IndexErrors (not found) please NN
# pos KeyErrors up IN
# pos KeyErrors past JJ
# pos KeyErrors a DT
# pos KeyErrors vacant JJ
# pos KeyErrors but CC
# pos KeyErrors as IN
# pos KeyErrors i JJ
# IndexErrors (not found) i VB
# pos KeyErrors as IN
# pos KeyErrors yes UH
# pos KeyErrors it PRP
# pos KeyErrors me PRP
# pos KeyErrors over IN
# pos KeyErrors 100 CD
# pos KeyErrors i JJ
# pos KeyErrors some DT
# pos KeyErrors so IN
# pos KeyErrors it PRP
# pos KeyErrors might MD
# pos KeyErrors in IN
# pos KeyErrors out IN
# pos KeyErrors i JJ
# pos KeyErrors in IN
# pos KeyErrors new JJ
# pos KeyErrors a DT
# pos KeyErrors single JJ
# pos KeyErrors it PRP
# pos KeyErrors but CC
# pos KeyErrors free JJ
# pos KeyErrors me PRP
# pos KeyErrors any DT
# pos KeyErrors happy JJ
# pos KeyErrors it PRP
# pos KeyErrors important JJ
# pos KeyErrors me PRP
# pos KeyErrors it PRP
# pos KeyErrors may MD
# pos KeyErrors some DT
# IndexErrors (not found) i VB
# pos KeyErrors brazilian JJ
# pos KeyErrors 28 CD
# pos KeyErrors old JJ
# pos KeyErrors no DT
# pos KeyErrors in IN
# pos KeyErrors i JJ
# pos KeyErrors as IN
# pos KeyErrors a DT
# pos KeyErrors 4 CD
# IndexErrors (not found) i RB
# pos KeyErrors it PRP
# pos KeyErrors i JJ
# pos KeyErrors before IN
# pos KeyErrors i JJ
# pos KeyErrors much JJ
# pos KeyErrors old JJ
# pos KeyErrors so IN
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors in IN
# pos KeyErrors 18 CD
# pos KeyErrors after IN
# pos KeyErrors a DT
# pos KeyErrors at IN
# pos KeyErrors least JJS
# pos KeyErrors 8 CD
# pos KeyErrors long JJ
# pos KeyErrors it PRP
# pos KeyErrors me PRP
# pos KeyErrors first JJ
# pos KeyErrors i JJ
# pos KeyErrors 4 CD
# pos KeyErrors first JJ
# pos KeyErrors but CC
# pos KeyErrors i JJ
# pos KeyErrors 5 CD
# pos KeyErrors a DT
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors little JJ
# pos KeyErrors hard JJ
# pos KeyErrors in IN
# pos KeyErrors all DT
# pos KeyErrors all DT
# pos KeyErrors in IN
# pos KeyErrors its PRP$
# pos KeyErrors at IN
# pos KeyErrors first JJ
# pos KeyErrors some DT
# pos KeyErrors free JJ
# IndexErrors (not found) online NN
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors little JJ
# pos KeyErrors about IN
# pos KeyErrors no DT
# pos KeyErrors in IN
# IndexErrors (not found) god VBP
# pos KeyErrors i JJ
# pos KeyErrors i JJ
# pos KeyErrors an DT
# pos KeyErrors in IN
# pos KeyErrors about IN
# pos KeyErrors free JJ
# IndexErrors (not found) i RB
# pos KeyErrors it PRP
# pos KeyErrors it PRP
# IndexErrors (not found) september VBN
# pos KeyErrors 27 CD
# pos KeyErrors it PRP
# pos KeyErrors 3 CD
# pos KeyErrors while IN
# pos KeyErrors a DT
# pos KeyErrors brazilian JJ
# IndexErrors (not found) podcast NN
# IndexErrors (not found) i RB
# pos KeyErrors ready JJ
# IndexErrors (not found) jr VB
# pos KeyErrors front JJ
# IndexErrors (not found) i RB
# pos KeyErrors some DT
# pos KeyErrors in IN
# pos KeyErrors me PRP
# IndexErrors (not found) i VB
# pos KeyErrors 20 CD
# pos KeyErrors front JJ
# pos KeyErrors but CC
# pos KeyErrors all DT
# pos KeyErrors but CC
# pos KeyErrors there EX
# pos KeyErrors 2 CD
# pos KeyErrors 2 CD
# pos KeyErrors me PRP
# pos KeyErrors an DT
# pos KeyErrors both DT
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors in IN
# IndexErrors (not found) i RB
# pos KeyErrors two CD
# pos KeyErrors in IN
# pos KeyErrors one CD
# pos KeyErrors one CD
# pos KeyErrors me PRP
# pos KeyErrors other JJ
# pos KeyErrors but CC
# pos KeyErrors will MD
# pos KeyErrors first JJ
# pos KeyErrors it PRP
# pos KeyErrors near IN
# IndexErrors (not found) i VB
# pos KeyErrors at IN
# pos KeyErrors in IN
# pos KeyErrors i JJ
# pos KeyErrors first JJ
# pos KeyErrors some DT
# pos KeyErrors cool JJ
# pos KeyErrors in IN
# pos KeyErrors as IN
# pos KeyErrors free JJ
# pos KeyErrors me PRP
# pos KeyErrors any DT
# IndexErrors (not found) merry NN
# pos KeyErrors all DT
# IndexErrors (not found) sorry VB
# pos KeyErrors english JJ
# pos KeyErrors it PRP
# pos KeyErrors a DT
# IndexErrors (not found) bit RB
# pos KeyErrors awkward JJ
# number of treated posts (len(count)) :: 0

# %%
len(lemmposrecs), type(lemmws_fd)
# Out:
# (53, nltk.probability.FreqDist)

# %%
lda_model, lsi_model = gensim_models2(lemmposrecs)

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.017*"job" + 0.015*"get" + 0.014*"much" + 0.013*"make" + 0.012*"developer" + 0.009*"work" + 0.009*"merely" + 0.008*"excessively" + 0.007*"say" + 0.007*"fcc"'),
#  (1,
#   '0.028*"interview" + 0.020*"work" + 0.016*"job" + 0.015*"time" + 0.010*"get" + 0.009*"merely" + 0.008*"people" + 0.008*"day" + 0.007*"ask" + 0.007*"want"'),
#  (2,
#   '0.021*"get" + 0.015*"merely" + 0.011*"fcc" + 0.011*"start" + 0.011*"work" + 0.011*"time" + 0.010*"first" + 0.009*"truly" + 0.009*"learn" + 0.008*"job"'),
#  (3,
#   '0.025*"get" + 0.021*"learn" + 0.017*"like" + 0.015*"company" + 0.010*"project" + 0.010*"start" + 0.010*"want" + 0.008*"lot" + 0.008*"job" + 0.007*"even"'),
#  (4,
#   '0.014*"learn" + 0.012*"thing" + 0.011*"truly" + 0.011*"would" + 0.009*"project" + 0.008*"right" + 0.008*"know" + 0.008*"like" + 0.007*"time" + 0.007*"fcc"'),
#  (5,
#   '0.016*"company" + 0.014*"code" + 0.012*"interview" + 0.011*"make" + 0.010*"job" + 0.010*"time" + 0.010*"get" + 0.009*"want" + 0.009*"work" + 0.009*"project"'),
#  (6,
#   '0.021*"merely" + 0.015*"work" + 0.011*"time" + 0.011*"end" + 0.010*"lesson" + 0.010*"get" + 0.009*"job" + 0.009*"i’m" + 0.008*"know" + 0.007*"front"'),
#  (7,
#   '0.015*"interview" + 0.014*"end" + 0.013*"use" + 0.012*"get" + 0.012*"job" + 0.011*"truly" + 0.010*"front" + 0.010*"project" + 0.010*"code" + 0.010*"company"'),
#  (8,
#   '0.015*"learn" + 0.015*"project" + 0.012*"find" + 0.010*"interview" + 0.008*"fcc" + 0.007*"ago" + 0.007*"start" + 0.007*"way" + 0.007*"take" + 0.007*"n\'t"'),
#  (9,
#   '0.035*"job" + 0.023*"project" + 0.013*"get" + 0.013*"work" + 0.011*"interview" + 0.010*"start" + 0.009*"offer" + 0.008*"learn" + 0.008*"month" + 0.008*"time"'),
#  (10,
#   '0.029*"get" + 0.024*"job" + 0.016*"learn" + 0.013*"time" + 0.010*"look" + 0.007*"week" + 0.007*"need" + 0.007*"find" + 0.007*"besides" + 0.006*"much"'),
#  (11,
#   '0.020*"job" + 0.013*"fcc" + 0.012*"get" + 0.011*"make" + 0.011*"experience" + 0.010*"course" + 0.008*"learn" + 0.007*"need" + 0.007*"year" + 0.006*"besides"'),
#  (12,
#   '0.020*"job" + 0.014*"get" + 0.013*"apply" + 0.012*"make" + 0.009*"start" + 0.008*"company" + 0.007*"merely" + 0.007*"sure" + 0.007*"code" + 0.007*"good"'),
#  (13,
#   '0.017*"job" + 0.014*"company" + 0.012*"one" + 0.011*"learn" + 0.010*"get" + 0.010*"work" + 0.009*"take" + 0.009*"use" + 0.009*"start" + 0.008*"interview"'),
#  (14,
#   '0.013*"work" + 0.012*"job" + 0.011*"build" + 0.011*"get" + 0.010*"start" + 0.010*"project" + 0.008*"company" + 0.008*"know" + 0.008*"truly" + 0.008*"development"')]

# %%
lda_model, lsi_model = gensim_models2(lemmposrecs, wordimportance = {'tfidf':True})

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.007*"it’s" + 0.007*"job" + 0.006*"company" + 0.005*"interview" + 0.005*"end" + 0.005*"merely" + 0.004*"always" + 0.004*"study" + 0.004*"get" + 0.004*"try"'),
#  (1,
#   '0.007*"job" + 0.006*"get" + 0.005*"work" + 0.005*"fcc" + 0.005*"learn" + 0.005*"https" + 0.005*"start" + 0.005*"month" + 0.004*"ago" + 0.004*"1"'),
#  (2,
#   '0.008*"much" + 0.006*"learn" + 0.005*"web" + 0.005*"time" + 0.005*"would" + 0.005*"take" + 0.005*"i’m" + 0.005*"start" + 0.004*"get" + 0.004*"developer"'),
#  (3,
#   '0.006*"good" + 0.005*"time" + 0.005*"probably" + 0.005*"get" + 0.005*"job" + 0.004*"developer" + 0.004*"go" + 0.004*"work" + 0.004*"need" + 0.004*"merely"'),
#  (4,
#   '0.006*"interview" + 0.006*"company" + 0.005*"way" + 0.005*"end" + 0.005*"developer" + 0.005*"get" + 0.004*"around" + 0.004*"front" + 0.004*"thanks" + 0.004*"don’t"'),
#  (5,
#   '0.007*"get" + 0.006*"fcc" + 0.005*"interview" + 0.005*"learn" + 0.005*"way" + 0.005*"test" + 0.004*"want" + 0.004*"start" + 0.004*"call" + 0.004*"need"'),
#  (6,
#   '0.006*"job" + 0.005*"interview" + 0.005*"hard" + 0.005*"take" + 0.005*"first" + 0.005*"group" + 0.004*"company" + 0.004*"role" + 0.004*"send" + 0.004*"help"'),
#  (7,
#   '0.006*"get" + 0.005*"end" + 0.005*"job" + 0.004*"code" + 0.004*"project" + 0.004*"day" + 0.004*"talk" + 0.004*"merely" + 0.004*"experience" + 0.004*"better"'),
#  (8,
#   '0.008*"one" + 0.007*"fcc" + 0.006*"start" + 0.005*"interview" + 0.005*"year" + 0.004*"time" + 0.004*"developer" + 0.004*"project" + 0.004*"offer" + 0.004*"internship"'),
#  (9,
#   '0.008*"thank" + 0.007*"e" + 0.006*"portfolio" + 0.006*"job" + 0.005*"freecodecamp" + 0.005*"end" + 0.005*"work" + 0.004*"project" + 0.004*"github" + 0.004*"start"'),
#  (10,
#   '0.007*"get" + 0.007*"job" + 0.006*"merely" + 0.006*"try" + 0.005*"truly" + 0.005*"keep" + 0.005*"start" + 0.005*"want" + 0.005*"learn" + 0.004*"project"'),
#  (11,
#   '0.006*"well" + 0.006*"get" + 0.005*"interview" + 0.005*"job" + 0.004*"improve" + 0.004*"truly" + 0.004*"project" + 0.004*"feel" + 0.004*"learn" + 0.004*"company"'),
#  (12,
#   '0.006*"3" + 0.005*"company" + 0.004*"you’re" + 0.004*"read" + 0.004*"job" + 0.004*"don’t" + 0.004*"project" + 0.004*"time" + 0.004*"people" + 0.004*"thanks"'),
#  (13,
#   '0.007*"work" + 0.005*"learn" + 0.005*"know" + 0.005*"away" + 0.005*"fcc" + 0.005*"job" + 0.004*"time" + 0.004*"stack" + 0.004*"start" + 0.004*"hire"'),
#  (14,
#   '0.006*"take" + 0.006*"truly" + 0.006*"project" + 0.005*"time" + 0.005*"build" + 0.005*"use" + 0.005*"ask" + 0.005*"job" + 0.004*"resource" + 0.004*"come"')]

# %%
lda_model, lsi_model = gensim_models2(lemmposrecs, NUM_TOPICS = 20)

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.013*"merely" + 0.010*"n\'t" + 0.009*"you’re" + 0.009*"make" + 0.008*"know" + 0.008*"interview" + 0.008*"month" + 0.008*"learn" + 0.008*"like" + 0.008*"time"'),
#  (1,
#   '0.011*"project" + 0.011*"find" + 0.009*"want" + 0.009*"app" + 0.009*"hire" + 0.007*"manager" + 0.007*"work" + 0.007*"much" + 0.007*"finish" + 0.007*"first"'),
#  (2,
#   '0.022*"get" + 0.019*"job" + 0.016*"interview" + 0.014*"time" + 0.010*"truly" + 0.010*"fcc" + 0.009*"help" + 0.009*"find" + 0.008*"merely" + 0.008*"month"'),
#  (3,
#   '0.024*"job" + 0.022*"get" + 0.019*"work" + 0.016*"learn" + 0.014*"end" + 0.012*"front" + 0.011*"project" + 0.010*"merely" + 0.009*"people" + 0.009*"developer"'),
#  (4,
#   '0.020*"get" + 0.012*"learn" + 0.010*"one" + 0.010*"back" + 0.008*"skill" + 0.007*"end" + 0.007*"time" + 0.007*"send" + 0.006*"don’t" + 0.006*"experience"'),
#  (5,
#   '0.020*"merely" + 0.019*"work" + 0.015*"code" + 0.015*"job" + 0.013*"interview" + 0.012*"project" + 0.012*"company" + 0.011*"n\'t" + 0.011*"web" + 0.009*"get"'),
#  (6,
#   '0.024*"job" + 0.023*"get" + 0.015*"end" + 0.013*"learn" + 0.013*"company" + 0.011*"front" + 0.010*"project" + 0.009*"code" + 0.009*"year" + 0.008*"time"'),
#  (7,
#   '0.019*"work" + 0.019*"job" + 0.012*"start" + 0.010*"end" + 0.010*"learn" + 0.010*"developer" + 0.009*"get" + 0.009*"besides" + 0.009*"like" + 0.009*"time"'),
#  (8,
#   '0.028*"get" + 0.014*"learn" + 0.012*"start" + 0.012*"fcc" + 0.011*"interview" + 0.009*"even" + 0.009*"job" + 0.009*"i’ve" + 0.008*"project" + 0.007*"developer"'),
#  (9,
#   '0.015*"go" + 0.015*"fcc" + 0.014*"want" + 0.009*"start" + 0.008*"ask" + 0.008*"time" + 0.007*"real" + 0.007*"least" + 0.007*"n\'t" + 0.007*"try"'),
#  (10,
#   '0.018*"merely" + 0.015*"job" + 0.013*"apply" + 0.011*"interview" + 0.011*"get" + 0.009*"many" + 0.008*"offer" + 0.008*"work" + 0.008*"code" + 0.007*"learn"'),
#  (11,
#   '0.016*"work" + 0.015*"project" + 0.013*"interview" + 0.013*"job" + 0.012*"company" + 0.010*"merely" + 0.010*"fcc" + 0.010*"start" + 0.008*"get" + 0.007*"even"'),
#  (12,
#   '0.019*"company" + 0.016*"interview" + 0.011*"project" + 0.010*"learn" + 0.010*"it’s" + 0.009*"best" + 0.008*"build" + 0.008*"get" + 0.008*"js" + 0.008*"start"'),
#  (13,
#   '0.020*"job" + 0.017*"time" + 0.015*"get" + 0.013*"make" + 0.011*"company" + 0.010*"interview" + 0.010*"day" + 0.009*"take" + 0.009*"learn" + 0.009*"like"'),
#  (14,
#   '0.026*"work" + 0.013*"project" + 0.011*"get" + 0.011*"company" + 0.010*"developer" + 0.010*"lot" + 0.009*"day" + 0.008*"make" + 0.008*"like" + 0.008*"job"'),
#  (15,
#   '0.012*"get" + 0.010*"merely" + 0.010*"don’t" + 0.009*"call" + 0.009*"company" + 0.008*"course" + 0.008*"apply" + 0.008*"javascript" + 0.008*"interview" + 0.007*"fcc"'),
#  (16,
#   '0.021*"job" + 0.018*"time" + 0.014*"get" + 0.013*"project" + 0.013*"i’m" + 0.012*"interview" + 0.010*"study" + 0.010*"find" + 0.009*"make" + 0.009*"take"'),
#  (17,
#   '0.018*"interview" + 0.015*"much" + 0.015*"like" + 0.014*"fcc" + 0.013*"get" + 0.012*"job" + 0.011*"know" + 0.009*"developer" + 0.008*"start" + 0.008*"time"'),
#  (18,
#   '0.020*"get" + 0.020*"learn" + 0.013*"start" + 0.012*"job" + 0.009*"truly" + 0.008*"lesson" + 0.008*"development" + 0.007*"equally" + 0.007*"look" + 0.006*"take"'),
#  (19,
#   '0.027*"job" + 0.017*"want" + 0.016*"learn" + 0.014*"merely" + 0.013*"look" + 0.012*"get" + 0.012*"start" + 0.010*"like" + 0.008*"need" + 0.007*"developer"')]

# %%
lda_model, lsi_model = gensim_models2(lemmposrecs, wordimportance = {'tfidf':True}, NUM_TOPICS=20)

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.006*"skill" + 0.006*"web" + 0.005*"react" + 0.005*"much" + 0.005*"recruiter" + 0.005*"job" + 0.005*"use" + 0.004*"start" + 0.004*"actually" + 0.004*"first"'),
#  (1,
#   '0.009*"thank" + 0.007*"learn" + 0.006*"experience" + 0.006*"ask" + 0.005*"fcc" + 0.005*"you’re" + 0.004*"would" + 0.004*"help" + 0.004*"job" + 0.004*"get"'),
#  (2,
#   '0.008*"month" + 0.007*"keep" + 0.007*"interview" + 0.007*"learn" + 0.007*"time" + 0.006*"well" + 0.005*"get" + 0.005*"ago" + 0.005*"job" + 0.005*"need"'),
#  (3,
#   '0.007*"company" + 0.007*"get" + 0.007*"job" + 0.006*"many" + 0.005*"it’s" + 0.005*"front" + 0.005*"talk" + 0.005*"end" + 0.005*"interview" + 0.005*"try"'),
#  (4,
#   '0.007*"you’re" + 0.006*"start" + 0.006*"fcc" + 0.005*"ask" + 0.005*"make" + 0.005*"learn" + 0.005*"work" + 0.005*"project" + 0.005*"time" + 0.004*"job"'),
#  (5,
#   '0.008*"study" + 0.005*"javascript" + 0.005*"always" + 0.005*"work" + 0.005*"need" + 0.004*"job" + 0.004*"community" + 0.004*"keep" + 0.004*"one" + 0.004*"make"'),
#  (6,
#   '0.005*"get" + 0.005*"story" + 0.005*"take" + 0.005*"come" + 0.005*"ask" + 0.005*"job" + 0.004*"people" + 0.004*"interview" + 0.004*"stuff" + 0.004*"back"'),
#  (7,
#   '0.007*"fcc" + 0.007*"get" + 0.006*"day" + 0.006*"thank" + 0.005*"job" + 0.005*"first" + 0.005*"never" + 0.004*"always" + 0.004*"portfolio" + 0.004*"code"'),
#  (8,
#   '0.006*"course" + 0.006*"like" + 0.005*"advice" + 0.005*"answer" + 0.005*"besides" + 0.005*"networking" + 0.005*"experience" + 0.005*"master" + 0.004*"however" + 0.004*"job"'),
#  (9,
#   '0.009*"job" + 0.008*"get" + 0.007*"interview" + 0.006*"study" + 0.006*"apply" + 0.006*"learn" + 0.006*"first" + 0.006*"good" + 0.005*"help" + 0.005*"equally"'),
#  (10,
#   '0.008*"job" + 0.007*"time" + 0.007*"start" + 0.006*"project" + 0.006*"take" + 0.005*"besides" + 0.005*"freecodecamp" + 0.005*"college" + 0.005*"long" + 0.005*"make"'),
#  (11,
#   '0.008*"get" + 0.007*"job" + 0.005*"offer" + 0.005*"work" + 0.005*"time" + 0.005*"developer" + 0.005*"know" + 0.005*"course" + 0.005*"test" + 0.004*"month"'),
#  (12,
#   '0.009*"get" + 0.006*"around" + 0.006*"https" + 0.005*"job" + 0.005*"first" + 0.005*"i’m" + 0.005*"end" + 0.005*"start" + 0.004*"company" + 0.004*"find"'),
#  (13,
#   '0.008*"finish" + 0.006*"cod" + 0.006*"company" + 0.005*"apply" + 0.005*"web" + 0.005*"take" + 0.005*"away" + 0.004*"get" + 0.004*"learn" + 0.004*"challenge"'),
#  (14,
#   '0.006*"time" + 0.005*"know" + 0.005*"i’m" + 0.005*"end" + 0.005*"every" + 0.005*"interview" + 0.005*"make" + 0.004*"edit" + 0.004*"get" + 0.004*"work"'),
#  (15,
#   '0.007*"fcc" + 0.006*"want" + 0.006*"start" + 0.006*"end" + 0.006*"project" + 0.005*"interview" + 0.005*"code" + 0.005*"lot" + 0.005*"i’m" + 0.005*"next"'),
#  (16,
#   '0.006*"end" + 0.006*"reason" + 0.005*"program" + 0.005*"get" + 0.005*"front" + 0.005*"comfortable" + 0.005*"wasn’t" + 0.004*"make" + 0.004*"failure" + 0.004*"resource"'),
#  (17,
#   '0.010*"work" + 0.008*"learn" + 0.008*"one" + 0.006*"e" + 0.005*"keep" + 0.005*"end" + 0.005*"skill" + 0.004*"read" + 0.004*"time" + 0.004*"go"'),
#  (18,
#   '0.007*"job" + 0.007*"offer" + 0.006*"google" + 0.005*"interview" + 0.005*"get" + 0.005*"one" + 0.005*"project" + 0.005*"company" + 0.005*"developer" + 0.005*"two"'),
#  (19,
#   '0.009*"n\'t" + 0.007*"interview" + 0.006*"job" + 0.005*"get" + 0.005*"project" + 0.005*"work" + 0.005*"well" + 0.004*"company" + 0.004*"try" + 0.004*"fcc"')]

# %%
lda_model, lsi_model = gensim_models2(lemmposrecs, wordimportance = {'tfidf':True})

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.007*"position" + 0.006*"e" + 0.006*"find" + 0.005*"apply" + 0.005*"developer" + 0.005*"look" + 0.005*"fcc" + 0.004*"project" + 0.004*"course" + 0.004*"job"'),
#  (1,
#   '0.007*"first" + 0.007*"job" + 0.006*"help" + 0.006*"get" + 0.006*"group" + 0.005*"interview" + 0.005*"time" + 0.004*"work" + 0.004*"day" + 0.004*"learn"'),
#  (2,
#   '0.014*"fcc" + 0.006*"month" + 0.005*"start" + 0.005*"work" + 0.005*"ago" + 0.005*"job" + 0.004*"n\'t" + 0.004*"thank" + 0.004*"write" + 0.004*"join"'),
#  (3,
#   '0.010*"job" + 0.007*"want" + 0.007*"get" + 0.007*"need" + 0.005*"start" + 0.005*"fcc" + 0.005*"call" + 0.005*"day" + 0.005*"project" + 0.004*"interview"'),
#  (4,
#   '0.007*"study" + 0.006*"job" + 0.006*"apply" + 0.005*"get" + 0.005*"first" + 0.004*"interview" + 0.004*"back" + 0.004*"end" + 0.004*"computer" + 0.004*"look"'),
#  (5,
#   '0.006*"get" + 0.005*"experience" + 0.005*"work" + 0.005*"didn’t" + 0.005*"code" + 0.004*"i’m" + 0.004*"try" + 0.004*"time" + 0.004*"happy" + 0.004*"best"'),
#  (6,
#   '0.006*"get" + 0.005*"developer" + 0.005*"it’s" + 0.005*"web" + 0.005*"good" + 0.005*"job" + 0.005*"work" + 0.004*"first" + 0.004*"time" + 0.004*"make"'),
#  (7,
#   '0.008*"github" + 0.007*"project" + 0.007*"get" + 0.007*"learn" + 0.006*"job" + 0.006*"time" + 0.005*"fcc" + 0.005*"take" + 0.005*"thank" + 0.005*"much"'),
#  (8,
#   '0.006*"job" + 0.006*"need" + 0.006*"want" + 0.005*"company" + 0.005*"start" + 0.005*"one" + 0.004*"get" + 0.004*"like" + 0.004*"possible" + 0.004*"new"'),
#  (9,
#   '0.006*"take" + 0.005*"interview" + 0.005*"good" + 0.004*"javascript" + 0.004*"build" + 0.004*"company" + 0.004*"try" + 0.004*"go" + 0.004*"long" + 0.003*"work"'),
#  (10,
#   '0.006*"interview" + 0.006*"recruiter" + 0.006*"get" + 0.006*"time" + 0.005*"learn" + 0.005*"job" + 0.005*"take" + 0.005*"project" + 0.005*"contact" + 0.004*"lol"'),
#  (11,
#   '0.006*"away" + 0.006*"work" + 0.005*"get" + 0.005*"company" + 0.004*"i’m" + 0.004*"interview" + 0.004*"day" + 0.004*"time" + 0.004*"project" + 0.004*"start"'),
#  (12,
#   '0.006*"get" + 0.005*"finish" + 0.004*"know" + 0.004*"enjoy" + 0.004*"time" + 0.004*"besides" + 0.004*"make" + 0.004*"go" + 0.004*"patient" + 0.004*"keep"'),
#  (13,
#   '0.008*"learn" + 0.007*"use" + 0.005*"js" + 0.005*"job" + 0.005*"e" + 0.004*"work" + 0.004*"need" + 0.004*"don’t" + 0.004*"portfolio" + 0.004*"code"'),
#  (14,
#   '0.007*"work" + 0.006*"end" + 0.006*"n\'t" + 0.005*"make" + 0.005*"get" + 0.005*"front" + 0.005*"company" + 0.004*"learn" + 0.004*"right" + 0.004*"think"')]

# %%
lsi_model.print_topics()
# Out:
# [(0,
#   '-0.256*"job" + -0.242*"get" + -0.187*"fcc" + -0.177*"interview" + -0.163*"start" + -0.159*"time" + -0.154*"project" + -0.154*"work" + -0.153*"learn" + -0.144*"end"'),
#  (1,
#   '0.644*"fcc" + -0.329*"interview" + 0.307*"thank" + 0.212*"start" + -0.194*"get" + -0.176*"company" + -0.143*"job" + -0.118*"day" + -0.118*"apply" + 0.107*"learn"'),
#  (2,
#   '0.308*"learn" + -0.296*"interview" + -0.294*"fcc" + -0.197*"job" + -0.169*"start" + -0.163*"thank" + -0.162*"apply" + -0.156*"day" + -0.153*"offer" + 0.137*"work"'),
#  (3,
#   '0.415*"end" + 0.354*"front" + -0.290*"fcc" + -0.279*"thank" + -0.261*"interview" + 0.186*"start" + 0.183*"developer" + 0.155*"web" + 0.153*"month" + -0.147*"want"'),
#  (4,
#   '0.395*"time" + -0.307*"end" + 0.286*"job" + -0.249*"front" + -0.222*"interview" + 0.219*"take" + -0.200*"company" + 0.169*"month" + -0.168*"project" + 0.158*"full"'),
#  (5,
#   '0.356*"job" + -0.323*"day" + 0.293*"apply" + -0.262*"time" + -0.237*"take" + -0.221*"work" + -0.178*"week" + -0.160*"start" + 0.141*"don’t" + 0.134*"need"'),
#  (6,
#   '-0.460*"learn" + 0.266*"work" + 0.235*"thank" + -0.229*"get" + 0.192*"company" + 0.187*"keep" + -0.176*"interview" + 0.167*"want" + -0.158*"project" + 0.146*"hard"'),
#  (7,
#   '-0.311*"start" + -0.301*"take" + -0.222*"need" + 0.215*"thank" + 0.215*"get" + -0.204*"n\'t" + -0.195*"company" + 0.188*"learn" + -0.169*"don’t" + 0.156*"i’m"'),
#  (8,
#   '0.398*"project" + -0.223*"learn" + 0.217*"time" + 0.189*"build" + -0.184*"developer" + -0.178*"month" + -0.153*"know" + -0.147*"i’m" + 0.138*"job" + 0.136*"portfolio"'),
#  (9,
#   '0.311*"take" + 0.293*"thank" + -0.244*"help" + -0.238*"start" + -0.215*"i’m" + 0.214*"end" + 0.179*"don’t" + 0.164*"front" + -0.153*"ask" + 0.145*"time"'),
#  (10,
#   '-0.374*"one" + 0.286*"company" + -0.219*"n\'t" + -0.216*"need" + 0.210*"want" + -0.203*"get" + 0.201*"learn" + -0.194*"i’m" + -0.175*"finish" + -0.151*"know"'),
#  (11,
#   '0.284*"hard" + 0.275*"work" + 0.259*"keep" + 0.239*"get" + -0.222*"find" + -0.191*"time" + -0.179*"i’m" + -0.168*"one" + 0.167*"away" + -0.153*"take"'),
#  (12,
#   '0.390*"n\'t" + -0.240*"project" + 0.215*"interview" + -0.192*"one" + -0.189*"you’re" + -0.186*"day" + -0.160*"thank" + 0.145*"ask" + -0.134*"it’s" + -0.133*"need"'),
#  (13,
#   '-0.387*"need" + -0.259*"n\'t" + -0.225*"day" + 0.191*"take" + -0.187*"time" + 0.181*"one" + 0.154*"make" + 0.147*"first" + -0.146*"learn" + 0.143*"well"'),
#  (14,
#   '-0.218*"day" + 0.213*"start" + -0.203*"n\'t" + 0.185*"i’m" + -0.177*"help" + -0.174*"month" + 0.167*"find" + -0.159*"want" + 0.150*"equally" + 0.150*"well"')]

# %% [markdown]
# ## Keyphrase Extraction and Graph Analysis

# %%
#TODO
