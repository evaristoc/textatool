# %% [markdown]
# * https://github.com/derekgreene/topic-model-tutorial
# * https://github.com/derekgreene/topic-model-tutorial/blob/master/topic-modelling-with-scikitlearn.pdf
# * https://radimrehurek.com/topic_modeling_tutorial/2%20-%20Topic%20Modeling.html

# %%
#######################
#basic standard modules
#######################
import sys, os
import time
import collections, itertools, copy, operator

#######################
#custom config modules
#######################
from dotenv import load_dotenv
load_dotenv(dotenv_path='../.env')
load_dotenv()

#######################
#file manipulation modules
#######################
import pickle, json

#######################
#string manipulation modules
#######################
import re, string
import nltk
print("in the other",os.getenv("TEST_MULTILINE_VAR"))
nltk.data.path.append(os.getenv("NLTKDATADIR"))
from bs4 import BeautifulSoup

#######################
#general data manipulation and data analysis modules
#######################
import pandas, gensim, sklearn, scipy, numpy, math

#######################
#custom modules
#######################
import processingData
# Out:
# in the other hello\nworld
# in the other hello\nworld

# %%
############################
## extract_candidate_chunks: candidate phrases based on http://bdewilde.github.io/blog/2014/09/23/intro-to-automatic-keyphrase-extraction/
############################
def extract_candidate_chunks(lemmposst, grammar=r'KT: {(<JJ>* <NN.*>+ <IN>)? <JJ>* <NN.*>+}', STOPWORDS = nltk.corpus.stopwords.words('english')):
    #def redotaggedtext(lemmpostxt, lemmpossts = [], lemmposst = []):
    # tokenize, POS-tag, and chunk using regular expressions
    chunker = nltk.chunk.regexp.RegexpParser(grammar)
    lemmposst_redo = []
    for w,val,l,pos in lemmposst:
        if w not in STOPWORDS:
            #or not all(char in punct for char in w):
            lemmposst_redo.append((l,pos))
    
    print('tree2conlltags', nltk.chunk.tree2conlltags(chunker.parse(lemmposst_redo)))
    
    all_chunks = nltk.chunk.tree2conlltags(
                chunker.parse(lemmposst_redo)
            )

    # join constituent chunk words into a single chunked phrase
    candidates = []
    print(itertools.groupby(all_chunks, lambda w_TUPLE: w_TUPLE[2] != 'O'))
    #for key, group in itertools.groupby(all_chunks, lambda w_TUPLE: w_TUPLE[2] != 'O'):
    #    print(key, group)
    #    if key:
    #        print(' '.join(word for word, pos, chunk in group))
    #        #candidates.append(x)
    
    candidates = [' '.join(word for word, pos, chunk in group)
                  for key, group in itertools.groupby(all_chunks, lambda w_TUPLE: w_TUPLE[2] != 'O') if key]
    
    print(candidates)
    
    #print([cand for cand in candidates])
    
    #return [cand for cand in candidates]
    return candidates

# %%
lemmposrecs, lemmws_fd = allrecordsPreparation3(allrecords)
# Out:
# in allrecordsPreparation (len(allrecords)):: 90
# Error (not in corpus) everybody NN
# Error (not in corpus) , ,
# pos KeyErrors i JJ
# Error (not in corpus) 've VBP
# pos KeyErrors two CD
# pos KeyErrors full JJ
# Error (not in corpus) , ,
# pos KeyErrors all DT
# Error (not in corpus) to TO
# IndexErrors (POS not found) fcc VB
# Error (not in corpus) . .
# pos KeyErrors one CD
# pos KeyErrors mean JJ
# pos KeyErrors while IN
# Error (not in corpus) the DT
# pos KeyErrors other JJ
# Error (not in corpus) ror VBP
# Error (not in corpus) + JJ
# pos KeyErrors angular JJ
# Error (not in corpus) + NN
# Error (not in corpus) postgresql NN
# Error (not in corpus) . .
# pos KeyErrors a DT
# pos KeyErrors brief JJ
# pos KeyErrors about IN
# Error (not in corpus) myself PRP
# Error (not in corpus) : :
# pos KeyErrors in IN
# Error (not in corpus) . .
# Error (not in corpus) 've VBP
# Error (not in corpus) my PRP$
# pos KeyErrors in IN
# pos KeyErrors signal JJ
# Error (not in corpus) . .
# Error (not in corpus) 've VBP
# pos KeyErrors on IN
# pos KeyErrors audio JJ
# Error (not in corpus) codecs NN
# Error (not in corpus) , ,
# pos KeyErrors like IN
# Error (not in corpus) atmos NN
# Error (not in corpus) , ,
# Error (not in corpus) dd+ NN
# Error (not in corpus) , ,
# Error (not in corpus) etc NN
# Error (not in corpus) for IN
# pos KeyErrors two CD
# Error (not in corpus) for IN
# pos KeyErrors a DT
# Error (not in corpus) which WDT
# Error (not in corpus) , ,
# pos KeyErrors few JJ
# pos KeyErrors across IN
# Error (not in corpus) the DT
# Error (not in corpus) . .
# pos KeyErrors one CD
# Error (not in corpus) of IN
# Error (not in corpus) them PRP
# Error (not in corpus) . .
# Error (not in corpus) to TO
# pos KeyErrors about IN
# pos KeyErrors fcc JJ
# Error (not in corpus) via IN
# Error (not in corpus) 's POS
# Error (not in corpus) quora JJ
# Error (not in corpus) . .
# Error (not in corpus) my PRP$
# Error (not in corpus) and CC
# Error (not in corpus) of IN
# pos KeyErrors on IN
# Error (not in corpus) the DT
# pos KeyErrors same JJ
# pos KeyErrors professional JJ
# Error (not in corpus) i.e NN
# Error (not in corpus) . .
# Error (not in corpus) codecs NN
# Error (not in corpus) and CC
# pos KeyErrors all DT
# Error (not in corpus) , ,
# pos KeyErrors on IN
# pos KeyErrors fcc JJ
# Error (not in corpus) . .
# pos KeyErrors after IN
# pos KeyErrors 6 CD
# Error (not in corpus) of IN
# pos KeyErrors hard JJ
# Error (not in corpus) , ,
# pos KeyErrors i JJ
# Error (not in corpus) 've VBP
# Error (not in corpus) myself PRP
# pos KeyErrors two CD
# pos KeyErrors full JJ
# Error (not in corpus) ( (
# Error (not in corpus) the DT
# pos KeyErrors best JJS
# Error (not in corpus) , ,
# pos KeyErrors both DT
# pos KeyErrors remote JJ
# Error (not in corpus) ) )
# Error (not in corpus) . .
# pos KeyErrors i JJ
# pos KeyErrors will MD
# Error (not in corpus) from IN
# Error (not in corpus) for IN
# pos KeyErrors both DT
# Error (not in corpus) 70-80hrs CD
# pos KeyErrors a DT
# Error (not in corpus) . .
# Error (not in corpus) to TO
# pos KeyErrors much JJ
# pos KeyErrors as IN
# pos KeyErrors can MD
# Error (not in corpus) , ,
# IndexErrors (POS not found) hence VB
# Error (not in corpus) the DT
# Error (not in corpus) . .
# Error (not in corpus) to TO
# Error (not in corpus) beginners:1 VB
# Error (not in corpus) ) )
# Error (not in corpus) n't RB
# Error (not in corpus) 'why NNP
# Error (not in corpus) ' POS
# Error (not in corpus) and CC
# Error (not in corpus) 'how NNP
# Error (not in corpus) ' POS
# Error (not in corpus) . .
# pos KeyErrors it PRP
# pos KeyErrors may MD
# Error (not in corpus) ' ''
# Error (not in corpus) , ,
# pos KeyErrors but CC
# Error (not in corpus) that DT
# Error (not in corpus) 's VBZ
# Error (not in corpus) what WP
# Error (not in corpus) for IN
# Error (not in corpus) me.2 NN
# Error (not in corpus) ) )
# Error (not in corpus) n't RB
# pos KeyErrors on IN
# Error (not in corpus) . .
# Error (not in corpus) , ,
# Error (not in corpus) stackoverflow VB
# Error (not in corpus) . .
# pos KeyErrors few JJ
# IndexErrors (POS not found) online NN
# Error (not in corpus) . .
# Error (not in corpus) coursera NN
# pos KeyErrors full JJ
# Error (not in corpus) for IN
# pos KeyErrors mean JJ
# Error (not in corpus) . .
# Error (not in corpus) this DT
# pos KeyErrors me PRP
# pos KeyErrors some DT
# pos KeyErrors good JJ
# Error (not in corpus) concepts.3 NN
# Error (not in corpus) ) )
# Error (not in corpus) and CC
# Error (not in corpus) , ,
# Error (not in corpus) n't RB
# Error (not in corpus) the DT
# pos KeyErrors or CC
# Error (not in corpus) . .
# Error (not in corpus) ! .
# pos KeyErrors a DT
# Error (not in corpus) ! .
# IndexErrors (POS not found) i RB
# Error (not in corpus) would MD
# Error (not in corpus) to TO
# Error (not in corpus) from IN
# Error (not in corpus) the DT
# Error (not in corpus) of IN
# Error (not in corpus) my PRP$
# Error (not in corpus) for IN
# Error (not in corpus) and CC
# Error (not in corpus) this DT
# pos KeyErrors great JJ
# Error (not in corpus) . .
# Error (not in corpus) without IN
# Error (not in corpus) would MD
# Error (not in corpus) this DT
# Error (not in corpus) . .
# tree2conlltags [('hello', 'NN', 'B-KT'), ('everybody', 'NN', 'I-KT'), (',', ',', 'O'), ("'ve", 'VBP', 'O'), ('get', 'VBN', 'O'), ('two', 'CD', 'O'), ('full', 'JJ', 'B-KT'), ('stack', 'NN', 'I-KT'), ('developer', 'NN', 'I-KT'), ('job', 'NN', 'I-KT'), ('offer', 'NNS', 'I-KT'), (',', ',', 'O'), ('thanks', 'NNS', 'B-KT'), ('fcc', 'VB', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2778>
# ['hello everybody', 'full stack developer job offer', 'thanks']
# ['hello everybody', 'full stack developer job offer', 'thanks']
# tree2conlltags [('one', 'CD', 'O'), ('organisation', 'NN', 'B-KT'), ('use', 'VBZ', 'O'), ('mean', 'JJ', 'B-KT'), ('stack', 'NN', 'I-KT'), ('us', 'NNS', 'I-KT'), ('ror', 'VBP', 'O'), ('+', 'JJ', 'B-KT'), ('angular', 'JJ', 'I-KT'), ('+', 'NN', 'I-KT'), ('postgresql', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2778>
# ['organisation', 'mean stack us', '+ angular + postgresql']
# ['organisation', 'mean stack us', '+ angular + postgresql']
# tree2conlltags [('brief', 'JJ', 'O'), (':', ':', 'O'), ('reside', 'VBP', 'O'), ('india', 'NN', 'B-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2778>
# ['india']
# ['india']
# tree2conlltags [("'ve", 'VBP', 'O'), ('do', 'VBN', 'O'), ('master', 'NNS', 'B-KT'), ('signal', 'JJ', 'B-KT'), ('processing', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2778>
# ['master signal processing']
# ['master signal processing']
# tree2conlltags [("'ve", 'VBP', 'O'), ('work', 'VBN', 'O'), ('audio', 'JJ', 'B-KT'), ('codecs', 'NN', 'I-KT'), (',', ',', 'O'), ('like', 'IN', 'O'), ('dolby', 'NN', 'B-KT'), ('atmos', 'NN', 'I-KT'), (',', ',', 'O'), ('dd+', 'NN', 'B-KT'), (',', ',', 'O'), ('etc', 'NN', 'B-KT'), ('about', 'RB', 'O'), ('two', 'CD', 'O'), ('year', 'NNS', 'B-KT'), ('uk', 'NN', 'I-KT'), ('base', 'VBN', 'O'), ('company', 'NN', 'B-KT'), ('perform', 'VBG', 'O'), ('well', 'RB', 'O'), ('recently', 'RB', 'O'), (',', ',', 'O'), ('lay', 'VBN', 'O'), ('people', 'NNS', 'B-KT'), ('across', 'IN', 'I-KT'), ('globe', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2778>
# ['audio codecs', 'dolby atmos', 'dd+', 'etc', 'year uk', 'company', 'people across globe']
# ['audio codecs', 'dolby atmos', 'dd+', 'etc', 'year uk', 'company', 'people across globe']
# tree2conlltags [('one', 'CD', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2778>
# []
# []
# tree2conlltags [('meanwhile', 'RB', 'O'), ('come', 'VBD', 'O'), ('know', 'VB', 'O'), ('fcc', 'JJ', 'O'), ('via', 'IN', 'O'), ('quincy', 'NN', 'B-KT'), ("'s", 'POS', 'O'), ('quora', 'JJ', 'B-KT'), ('channel', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2778>
# ['quincy', 'quora channel']
# ['quincy', 'quora channel']
# tree2conlltags [('fcc', 'NN', 'B-KT'), ('catch', 'VBD', 'O'), ('attention', 'NN', 'B-KT'), ('alternatively', 'RB', 'O'), ('continue', 'VBG', 'O'), ('professional', 'JJ', 'B-KT'), ('path', 'NN', 'I-KT'), ('i.e', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2778>
# ['fcc', 'attention', 'professional path i.e']
# ['fcc', 'attention', 'professional path i.e']
# tree2conlltags [('codecs', 'NN', 'B-KT'), (',', ',', 'O'), ('start', 'VBD', 'O'), ('work', 'VBG', 'O'), ('fcc', 'JJ', 'B-KT'), ('curriculum', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2778>
# ['codecs', 'fcc curriculum']
# ['codecs', 'fcc curriculum']
# tree2conlltags [('about', 'RB', 'O'), ('6', 'CD', 'O'), ('month', 'NNS', 'B-KT'), ('hard', 'JJ', 'B-KT'), ('work', 'NN', 'I-KT'), (',', ',', 'O'), ("'ve", 'VBP', 'O'), ('land', 'VBN', 'O'), ('two', 'CD', 'O'), ('full', 'JJ', 'B-KT'), ('stack', 'NN', 'I-KT'), ('developer', 'NN', 'I-KT'), ('job', 'NN', 'I-KT'), ('offer', 'NNS', 'I-KT'), ('(', '(', 'O'), ('best', 'JJS', 'O'), ('part', 'NN', 'B-KT'), (',', ',', 'O'), ('company', 'NNS', 'B-KT'), ('allow', 'VBP', 'O'), ('remote', 'JJ', 'B-KT'), ('work', 'NN', 'I-KT'), (')', ')', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2778>
# ['month hard work', 'full stack developer job offer', 'part', 'company', 'remote work']
# ['month hard work', 'full stack developer job offer', 'part', 'company', 'remote work']
# tree2conlltags [('work', 'VBG', 'O'), ('home', 'NN', 'B-KT'), ('organisation', 'NNS', 'I-KT'), ('contribute', 'VBG', 'O'), ('about', 'RB', 'O'), ('70-80hrs', 'CD', 'O'), ('week', 'NN', 'B-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2778>
# ['home organisation', 'week']
# ['home organisation', 'week']
# tree2conlltags [('want', 'VBP', 'O'), ('learn', 'VB', 'O'), ('much', 'JJ', 'O'), (',', ',', 'O'), ('hence', 'VB', 'O'), ('effort', 'NNS', 'B-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2778>
# ['effort']
# ['effort']
# tree2conlltags [('advice', 'NN', 'B-KT'), ('beginners:1', 'VB', 'O'), (')', ')', 'O'), ("n't", 'RB', 'O'), ('stop', 'VB', 'O'), ('ask', 'VBG', 'O'), ("'why", 'NNP', 'B-KT'), ("'", 'POS', 'O'), ("'how", 'NNP', 'B-KT'), ("'", 'POS', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2778>
# ['advice', "'why", "'how"]
# ['advice', "'why", "'how"]
# tree2conlltags [('know', 'VBP', 'O'), ('may', 'MD', 'O'), ('sound', 'VB', 'O'), ('cliche', 'NN', 'B-KT'), ("'", "''", 'O'), (',', ',', 'O'), ("'s", 'VBZ', 'O'), ('work', 'VBD', 'O'), ('me.2', 'NN', 'B-KT'), (')', ')', 'O'), ("n't", 'RB', 'O'), ('rely', 'VB', 'O'), ('fcc', 'NN', 'B-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2ae8>
# ['cliche', 'me.2', 'fcc']
# ['cliche', 'me.2', 'fcc']
# tree2conlltags [('use', 'NN', 'B-KT'), ('google', 'NN', 'I-KT'), (',', ',', 'O'), ('stackoverflow', 'VB', 'O'), ('efficaciously', 'RB', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2c28>
# ['use google']
# ['use google']
# tree2conlltags [('take', 'VB', 'O'), ('online', 'NN', 'B-KT'), ('course', 'NNS', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2c28>
# ['online course']
# ['online course']
# tree2conlltags [('coursera', 'NN', 'B-KT'), ('full', 'JJ', 'B-KT'), ('stack', 'NN', 'I-KT'), ('course', 'NN', 'I-KT'), ('mean', 'JJ', 'B-KT'), ('stack', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2c28>
# ['coursera full stack course mean stack']
# ['coursera full stack course mean stack']
# tree2conlltags [('course', 'NN', 'B-KT'), ('teach', 'VBD', 'O'), ('good', 'JJ', 'B-KT'), ('concepts.3', 'NN', 'I-KT'), (')', ')', 'O'), ('last', 'RB', 'O'), (',', ',', 'O'), ("n't", 'RB', 'O'), ('read', 'VB', 'O'), ('book', 'NNS', 'B-KT'), ('watch', 'NN', 'I-KT'), ('video', 'NNS', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2c28>
# ['course', 'good concepts.3', 'book watch video']
# ['course', 'good concepts.3', 'book watch video']
# tree2conlltags [('code', 'NN', 'B-KT'), ('!', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2c28>
# ['code']
# ['code']
# tree2conlltags [('lot', 'NN', 'B-KT'), ('!', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2c28>
# ['lot']
# ['lot']
# tree2conlltags [('finally', 'RB', 'O'), ('would', 'MD', 'O'), ('like', 'VB', 'O'), ('thank', 'VB', 'O'), ('quincy', 'NN', 'B-KT'), ('bottom', 'NN', 'I-KT'), ('heart', 'NN', 'I-KT'), ('develop', 'VBG', 'O'), ('maintain', 'VBG', 'O'), ('great', 'JJ', 'B-KT'), ('community', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2c28>
# ['quincy bottom heart', 'great community']
# ['quincy bottom heart', 'great community']
# tree2conlltags [('without', 'IN', 'O'), ('fcc', 'NN', 'B-KT'), ('would', 'MD', 'O'), ('reach', 'VBN', 'O'), ('far', 'RB', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dd4a2c28>
# ['fcc']
# ['fcc']
# tree2conlltags [('cheer', 'NNS', 'B-KT')]
# <itertools.groupby object at 0x7f89dd4a2d18>
# ['cheer']
# ['cheer']
# Error (not in corpus) this DT
# IndexErrors (POS not found) i RB
# pos KeyErrors a DT
# pos KeyErrors junior JJ
# pos KeyErrors at IN
# pos KeyErrors a DT
# pos KeyErrors cool JJ
# pos KeyErrors creative JJ
# pos KeyErrors near IN
# pos KeyErrors old JJ
# pos KeyErrors in IN
# Error (not in corpus) . .
# pos KeyErrors it PRP
# Error (not in corpus) 's VBZ
# Error (not in corpus) the DT
# Error (not in corpus) of IN
# pos KeyErrors over IN
# pos KeyErrors two CD
# Error (not in corpus) of IN
# Error (not in corpus) ( (
# pos KeyErrors on IN
# Error (not in corpus) and CC
# pos KeyErrors off IN
# Error (not in corpus) ) )
# Error (not in corpus) and CC
# pos KeyErrors i JJ
# Error (not in corpus) 'm VBP
# Error (not in corpus) to TO
# Error (not in corpus) this DT
# pos KeyErrors new JJ
# pos KeyErrors in IN
# Error (not in corpus) my PRP$
# Error (not in corpus) with IN
# pos KeyErrors many JJ
# Error (not in corpus) . .
# Error (not in corpus) my PRP$
# Error (not in corpus) 'm VBP
# pos KeyErrors 31 CD
# Error (not in corpus) , ,
# pos KeyErrors a DT
# Error (not in corpus) and CC
# pos KeyErrors in IN
# Error (not in corpus) the DT
# pos KeyErrors in IN
# Error (not in corpus) . .
# Error (not in corpus) , ,
# pos KeyErrors but CC
# Error (not in corpus) with IN
# pos KeyErrors more JJR
# Error (not in corpus) of IN
# pos KeyErrors a DT
# pos KeyErrors recent JJ
# pos KeyErrors on IN
# Error (not in corpus) of IN
# Error (not in corpus) ( (
# Error (not in corpus) , ,
# Error (not in corpus) , ,
# Error (not in corpus) , ,
# pos KeyErrors social JJ
# Error (not in corpus) , ,
# Error (not in corpus) etc NN
# Error (not in corpus) ) )
# Error (not in corpus) . .
# Error (not in corpus) 've VBP
# Error (not in corpus) for IN
# pos KeyErrors some DT
# pos KeyErrors cool JJ
# Error (not in corpus) and CC
# pos KeyErrors on IN
# pos KeyErrors some DT
# pos KeyErrors interesting JJ
# Error (not in corpus) , ,
# pos KeyErrors but CC
# pos KeyErrors i JJ
# Error (not in corpus) 've VBP
# pos KeyErrors unhappy JJ
# Error (not in corpus) with IN
# Error (not in corpus) my PRP$
# Error (not in corpus) for IN
# pos KeyErrors a DT
# pos KeyErrors good JJ
# Error (not in corpus) of IN
# Error (not in corpus) , ,
# Error (not in corpus) and CC
# Error (not in corpus) to TO
# Error (not in corpus) something NN
# pos KeyErrors more JJR
# /home/ec/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# pos KeyErrors technical JJ
# Error (not in corpus) and CC
# Error (not in corpus) . .
# Error (not in corpus) with IN
# pos KeyErrors a DT
# Error (not in corpus) of IN
# Error (not in corpus) , ,
# pos KeyErrors but CC
# pos KeyErrors through IN
# pos KeyErrors a DT
# Error (not in corpus) of IN
# Error (not in corpus) where WRB
# Error (not in corpus) 'd MD
# Error (not in corpus) for IN
# pos KeyErrors a DT
# pos KeyErrors few JJ
# pos KeyErrors before IN
# pos KeyErrors in IN
# Error (not in corpus) the DT
# Error (not in corpus) and CC
# pos KeyErrors i JJ
# Error (not in corpus) 'd MD
# Error (not in corpus) and CC
# Error (not in corpus) for IN
# Error (not in corpus) . .
# Error (not in corpus) this DT
# IndexErrors (POS not found) i VBZ
# pos KeyErrors sat JJ
# pos KeyErrors down IN
# Error (not in corpus) and CC
# Error (not in corpus) to TO
# Error (not in corpus) myself PRP
# Error (not in corpus) to TO
# Error (not in corpus) and CC
# pos KeyErrors it PRP
# Error (not in corpus) 's VBZ
# Error (not in corpus) ! .
# Error (not in corpus) the DT
# pos KeyErrors on IN
# Error (not in corpus) for IN
# Error (not in corpus) the DT
# pos KeyErrors front JJ
# pos KeyErrors before IN
# pos KeyErrors by IN
# Error (not in corpus) myself PRP
# Error (not in corpus) . .
# pos KeyErrors a DT
# pos KeyErrors few JJ
# Error (not in corpus) of IN
# Error (not in corpus) . .
# Error (not in corpus) codepen JJ
# pos KeyErrors as IN
# Error (not in corpus) you PRP
# pos KeyErrors can MD
# Error (not in corpus) . .
# IndexErrors (POS not found) learn NN
# Error (not in corpus) , ,
# Error (not in corpus) the DT
# Error (not in corpus) , ,
# Error (not in corpus) how WRB
# Error (not in corpus) to TO
# pos KeyErrors a DT
# pos KeyErrors professional JJ
# pos KeyErrors front JJ
# Error (not in corpus) , ,
# pos KeyErrors or CC
# Error (not in corpus) , ,
# Error (not in corpus) how WRB
# Error (not in corpus) to TO
# Error (not in corpus) with IN
# Error (not in corpus) npm NN
# Error (not in corpus) , ,
# pos KeyErrors learn JJ
# Error (not in corpus) , ,
# Error (not in corpus) your PRP$
# pos KeyErrors on IN
# Error (not in corpus) github NN
# Error (not in corpus) . .
# Error (not in corpus) of IN
# Error (not in corpus) these DT
# Error (not in corpus) skills/technologies NNS
# Error (not in corpus) to TO
# Error (not in corpus) , ,
# Error (not in corpus) they PRP
# pos KeyErrors will MD
# Error (not in corpus) you PRP
# pos KeyErrors attractive JJ
# Error (not in corpus) to TO
# pos KeyErrors a DT
# pos KeyErrors potential JJ
# Error (not in corpus) and CC
# pos KeyErrors will MD
# Error (not in corpus) you PRP
# Error (not in corpus) 'll MD
# pos KeyErrors on IN
# Error (not in corpus) the DT
# Error (not in corpus) . .
# pos KeyErrors one CD
# Error (not in corpus) of IN
# Error (not in corpus) the DT
# pos KeyErrors biggest JJS
# pos KeyErrors able JJ
# Error (not in corpus) to TO
# pos KeyErrors about IN
# Error (not in corpus) my PRP$
# pos KeyErrors in IN
# Error (not in corpus) because IN
# Error (not in corpus) the DT
# Error (not in corpus) to TO
# Error (not in corpus) and CC
# Error (not in corpus) the DT
# pos KeyErrors modern JJ
# pos KeyErrors front JJ
# Error (not in corpus) eco-system NN
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors reasonably JJ
# pos KeyErrors professional JJ
# Error (not in corpus) . .
# IndexErrors (POS not found) react NN
# Error (not in corpus) n't RB
# pos KeyErrors hard JJ
# Error (not in corpus) to TO
# Error (not in corpus) ( (
# pos KeyErrors as IN
# pos KeyErrors it PRP
# pos KeyErrors might MD
# pos KeyErrors on IN
# pos KeyErrors first JJ
# Error (not in corpus) ) )
# Error (not in corpus) , ,
# pos KeyErrors it PRP
# pos KeyErrors great JJ
# pos KeyErrors on IN
# pos KeyErrors a DT
# Error (not in corpus) , ,
# Error (not in corpus) and CC
# pos KeyErrors in IN
# Error (not in corpus) . .
# Error (not in corpus) n't RB
# pos KeyErrors fcc JJ
# Error (not in corpus) that IN
# pos KeyErrors great JJ
# Error (not in corpus) for IN
# IndexErrors (POS not found) react NN
# Error (not in corpus) ( (
# Error (not in corpus) this DT
# pos KeyErrors may MD
# Error (not in corpus) with IN
# Error (not in corpus) ? .
# Error (not in corpus) ) )
# Error (not in corpus) - :
# pos KeyErrors but CC
# Error (not in corpus) this DT
# pos KeyErrors a DT
# pos KeyErrors good JJ
# Error (not in corpus) to TO
# Error (not in corpus) - :
# Error (not in corpus) : :
# Error (not in corpus) //www.udemy.com/react-redux/learn/v4/overview JJ
# pos KeyErrors consistent JJ
# Error (not in corpus) . .
# Error (not in corpus) myself PRP
# Error (not in corpus) of IN
# pos KeyErrors every DT
# pos KeyErrors in IN
# pos KeyErrors a DT
# Error (not in corpus) to TO
# Error (not in corpus) and CC
# Error (not in corpus) and CC
# pos KeyErrors most JJS
# pos KeyErrors 25 CD
# pos KeyErrors or CC
# pos KeyErrors outside IN
# Error (not in corpus) of IN
# Error (not in corpus) my PRP$
# Error (not in corpus) 9-6 JJ
# Error (not in corpus) ( (
# pos KeyErrors at IN
# Error (not in corpus) 6am CD
# Error (not in corpus) to TO
# Error (not in corpus) for IN
# pos KeyErrors a DT
# Error (not in corpus) of IN
# Error (not in corpus) , ,
# pos KeyErrors in IN
# Error (not in corpus) and CC
# Error (not in corpus) ) )
# Error (not in corpus) . .
# pos KeyErrors smart JJ
# Error (not in corpus) and CC
# pos KeyErrors fit JJ
# pos KeyErrors around IN
# Error (not in corpus) your PRP$
# pos KeyErrors in IN
# pos KeyErrors a DT
# Error (not in corpus) which WDT
# pos KeyErrors sustainable JJ
# Error (not in corpus) for IN
# Error (not in corpus) your PRP$
# pos KeyErrors own JJ
# Error (not in corpus) . .
# Error (not in corpus) codewars NNS
# Error (not in corpus) - :
# Error (not in corpus) this DT
# pos KeyErrors a DT
# pos KeyErrors great JJ
# Error (not in corpus) to TO
# Error (not in corpus) javascript NN
# Error (not in corpus) and CC
# Error (not in corpus) yourself PRP
# Error (not in corpus) . .
# pos KeyErrors it PRP
# pos KeyErrors as IN
# Error (not in corpus) you PRP
# pos KeyErrors can MD
# Error (not in corpus) , ,
# pos KeyErrors while IN
# Error (not in corpus) that IN
# pos KeyErrors it PRP
# Error (not in corpus) your PRP$
# Error (not in corpus) which WDT
# pos KeyErrors will MD
# Error (not in corpus) your PRP$
# pos KeyErrors in IN
# Error (not in corpus) the DT
# Error (not in corpus) for IN
# pos KeyErrors an DT
# Error (not in corpus) . .
# Error (not in corpus) your PRP$
# Error (not in corpus) . .
# pos KeyErrors through IN
# pos KeyErrors in IN
# Error (not in corpus) my PRP$
# pos KeyErrors learning JJ
# Error (not in corpus) to TO
# Error (not in corpus) the DT
# Error (not in corpus) that WDT
# pos KeyErrors by IN
# Error (not in corpus) and CC
# pos KeyErrors a DT
# Error (not in corpus) to TO
# Error (not in corpus) and CC
# IndexErrors (POS not found) showcase VB
# Error (not in corpus) most/all NN
# Error (not in corpus) of IN
# Error (not in corpus) them PRP
# pos KeyErrors in IN
# Error (not in corpus) . .
# pos KeyErrors 90 CD
# Error (not in corpus) % NN
# Error (not in corpus) of IN
# Error (not in corpus) the DT
# Error (not in corpus) against IN
# pos KeyErrors a DT
# pos KeyErrors it PRP
# pos KeyErrors much JJ
# pos KeyErrors easier JJR
# Error (not in corpus) for IN
# Error (not in corpus) you PRP
# Error (not in corpus) to TO
# Error (not in corpus) that DT
# Error (not in corpus) . .
# Error (not in corpus) to TO
# pos KeyErrors local JJ
# Error (not in corpus) . .
# pos KeyErrors other JJ
# pos KeyErrors or CC
# Error (not in corpus) to TO
# Error (not in corpus) to TO
# pos KeyErrors chat DT
# Error (not in corpus) to TO
# Error (not in corpus) . .
# Error (not in corpus) 'm VBP
# pos KeyErrors lucky JJ
# Error (not in corpus) to TO
# pos KeyErrors a DT
# pos KeyErrors few JJ
# pos KeyErrors in IN
# Error (not in corpus) ( (
# Error (not in corpus) from IN
# Error (not in corpus) to TO
# pos KeyErrors senior JJ
# Error (not in corpus) devs NN
# Error (not in corpus) , ,
# Error (not in corpus) , ,
# Error (not in corpus) and CC
# Error (not in corpus) ) )
# pos KeyErrors who WP
# pos KeyErrors invaluable JJ
# pos KeyErrors in IN
# pos KeyErrors me PRP
# Error (not in corpus) with IN
# Error (not in corpus) , ,
# Error (not in corpus) my PRP$
# Error (not in corpus) and CC
# Error (not in corpus) . .
# IndexErrors (POS not found) speak NN
# Error (not in corpus) to TO
# pos KeyErrors as IN
# pos KeyErrors many JJ
# pos KeyErrors as IN
# Error (not in corpus) you PRP
# pos KeyErrors can MD
# Error (not in corpus) ! .
# Error (not in corpus) to TO
# pos KeyErrors worthless JJ
# Error (not in corpus) . .
# pos KeyErrors yes UH
# Error (not in corpus) , ,
# Error (not in corpus) your PRP$
# pos KeyErrors will MD
# pos KeyErrors low JJ
# Error (not in corpus) , ,
# pos KeyErrors but CC
# pos KeyErrors who WP
# Error (not in corpus) when WRB
# Error (not in corpus) you PRP
# pos KeyErrors can MD
# Error (not in corpus) to TO
# Error (not in corpus) scores/hundreds NNS
# Error (not in corpus) of IN
# Error (not in corpus) . .
# pos KeyErrors a DT
# pos KeyErrors good JJ
# Error (not in corpus) and CC
# Error (not in corpus) which WDT
# Error (not in corpus) you PRP
# pos KeyErrors can MD
# Error (not in corpus) for IN
# pos KeyErrors individual JJ
# pos KeyErrors will MD
# Error (not in corpus) you PRP
# Error (not in corpus) to TO
# Error (not in corpus) to TO
# Error (not in corpus) and CC
# Error (not in corpus) . .
# pos KeyErrors why WRB
# Error (not in corpus) your PRP$
# pos KeyErrors much JJ
# pos KeyErrors as IN
# Error (not in corpus) you PRP
# pos KeyErrors can MD
# Error (not in corpus) and CC
# Error (not in corpus) what WP
# Error (not in corpus) the DT
# Error (not in corpus) ? .
# Error (not in corpus) that IN
# Error (not in corpus) - :
# Error (not in corpus) your PRP$
# Error (not in corpus) and CC
# Error (not in corpus) to TO
# Error (not in corpus) to TO
# Error (not in corpus) . .
# pos KeyErrors cold JJ
# Error (not in corpus) them PRP
# Error (not in corpus) if IN
# Error (not in corpus) you PRP
# Error (not in corpus) the DT
# Error (not in corpus) , ,
# Error (not in corpus) and CC
# Error (not in corpus) them PRP
# pos KeyErrors speculative JJ
# Error (not in corpus) them PRP
# IndexErrors (POS not found) briefly VBP
# pos KeyErrors about IN
# Error (not in corpus) your PRP$
# Error (not in corpus) and CC
# Error (not in corpus) what WP
# Error (not in corpus) you PRP
# Error (not in corpus) could MD
# Error (not in corpus) their PRP$
# Error (not in corpus) . .
# Error (not in corpus) this DT
# Error (not in corpus) my PRP$
# IndexErrors (POS not found) background RP
# pos KeyErrors in IN
# pos KeyErrors handy JJ
# Error (not in corpus) , ,
# pos KeyErrors but CC
# Error (not in corpus) the DT
# Error (not in corpus) of IN
# Error (not in corpus) that IN
# Error (not in corpus) you PRP
# Error (not in corpus) yourself PRP
# Error (not in corpus) , ,
# pos KeyErrors act JJ
# pos KeyErrors like IN
# pos KeyErrors a DT
# Error (not in corpus) . .
# Error (not in corpus) n't RB
# Error (not in corpus) for IN
# Error (not in corpus) to TO
# Error (not in corpus) to TO
# Error (not in corpus) you PRP
# Error (not in corpus) , ,
# pos KeyErrors proactive JJ
# Error (not in corpus) . .
# Error (not in corpus) the DT
# pos KeyErrors worst JJS
# Error (not in corpus) that WDT
# pos KeyErrors can MD
# pos KeyErrors a DT
# pos KeyErrors polite JJ
# Error (not in corpus) “no JJ
# Error (not in corpus) thanks” NN
# pos KeyErrors or CC
# Error (not in corpus) you PRP
# Error (not in corpus) . .
# pos KeyErrors no DT
# pos KeyErrors big JJ
# Error (not in corpus) . .
# pos KeyErrors specific JJ
# Error (not in corpus) - :
# pos KeyErrors in IN
# Error (not in corpus) my PRP$
# pos KeyErrors limited JJ
# Error (not in corpus) , ,
# Error (not in corpus) this DT
# pos KeyErrors a DT
# Error (not in corpus) 's POS
# Error (not in corpus) . .
# pos KeyErrors on IN
# pos KeyErrors january JJ
# pos KeyErrors 4 CD
# Error (not in corpus) and CC
# Error (not in corpus) my PRP$
# pos KeyErrors first JJ
# pos KeyErrors on IN
# pos KeyErrors january JJ
# pos KeyErrors 15 CD
# Error (not in corpus) . .
# Error (not in corpus) with IN
# pos KeyErrors 4 CD
# Error (not in corpus) , ,
# Error (not in corpus) myself PRP
# Error (not in corpus) from IN
# IndexErrors (POS not found) prior RB
# Error (not in corpus) to TO
# pos KeyErrors final JJ
# Error (not in corpus) for IN
# pos KeyErrors 3 CD
# pos KeyErrors more JJR
# Error (not in corpus) , ,
# Error (not in corpus) and CC
# Error (not in corpus) to TO
# pos KeyErrors numerous JJ
# pos KeyErrors other JJ
# Error (not in corpus) . .
# Error (not in corpus) emphasie NN
# pos KeyErrors transferrable JJ
# Error (not in corpus) . .
# pos KeyErrors no DT
# pos KeyErrors technical JJ
# pos KeyErrors professional JJ
# pos KeyErrors or CC
# Error (not in corpus) , ,
# pos KeyErrors but CC
# pos KeyErrors a DT
# Error (not in corpus) of IN
# pos KeyErrors in IN
# Error (not in corpus) my PRP$
# pos KeyErrors professional JJ
# Error (not in corpus) and CC
# Error (not in corpus) ( (
# Error (not in corpus) , ,
# Error (not in corpus) and CC
# Error (not in corpus) , ,
# Error (not in corpus) , ,
# pos KeyErrors other JJ
# Error (not in corpus) ) )
# Error (not in corpus) and CC
# Error (not in corpus) this DT
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors in IN
# Error (not in corpus) , ,
# pos KeyErrors in IN
# Error (not in corpus) and CC
# IndexErrors (POS not found) negotiating NN
# Error (not in corpus) . .
# Error (not in corpus) n't RB
# Error (not in corpus) your PRP$
# Error (not in corpus) non-technical JJ
# pos KeyErrors no DT
# pos KeyErrors as IN
# pos KeyErrors a DT
# Error (not in corpus) ! .
# Error (not in corpus) n't RB
# Error (not in corpus) to TO
# pos KeyErrors junior JJ
# Error (not in corpus) . .
# pos KeyErrors most JJS
# Error (not in corpus) of IN
# Error (not in corpus) the DT
# IndexErrors (POS not found) i VBP
# Error (not in corpus) for IN
# pos KeyErrors as IN
# Error (not in corpus) mid-weight JJ
# Error (not in corpus) . .
# Error (not in corpus) of IN
# pos KeyErrors will MD
# pos KeyErrors open JJ
# Error (not in corpus) to TO
# pos KeyErrors at IN
# Error (not in corpus) ! .
# pos KeyErrors all DT
# pos KeyErrors a DT
# pos KeyErrors take JJ
# pos KeyErrors technical JJ
# Error (not in corpus) . .
# Error (not in corpus) these DT
# Error (not in corpus) from IN
# pos KeyErrors multiple JJ
# pos KeyErrors front JJ
# pos KeyErrors technical JJ
# Error (not in corpus) , ,
# Error (not in corpus) to TO
# pos KeyErrors a DT
# pos KeyErrors simple JJ
# pos KeyErrors front JJ
# pos KeyErrors responsive JJ
# Error (not in corpus) , ,
# Error (not in corpus) to TO
# pos KeyErrors complex JJ
# Error (not in corpus) , ,
# Error (not in corpus) , ,
# pos KeyErrors in IN
# Error (not in corpus) interactivity NN
# Error (not in corpus) etc NN
# Error (not in corpus) . .
# Error (not in corpus) if IN
# Error (not in corpus) you PRP
# pos KeyErrors a DT
# Error (not in corpus) - :
# pos KeyErrors sure JJ
# Error (not in corpus) to TO
# pos KeyErrors much JJ
# pos KeyErrors as IN
# Error (not in corpus) you PRP
# pos KeyErrors can MD
# Error (not in corpus) , ,
# Error (not in corpus) the DT
# Error (not in corpus) you PRP
# Error (not in corpus) , ,
# Error (not in corpus) you PRP
# Error (not in corpus) 'd MD
# Error (not in corpus) , ,
# pos KeyErrors additional JJ
# Error (not in corpus) you PRP
# Error (not in corpus) could MD
# Error (not in corpus) and CC
# pos KeyErrors in IN
# Error (not in corpus) with IN
# Error (not in corpus) the DT
# Error (not in corpus) readme NN
# Error (not in corpus) . .
# pos KeyErrors in IN
# pos KeyErrors general JJ
# Error (not in corpus) , ,
# Error (not in corpus) this DT
# Error (not in corpus) the DT
# Error (not in corpus) that IN
# Error (not in corpus) you PRP
# Error (not in corpus) to TO
# pos KeyErrors across IN
# Error (not in corpus) - :
# Error (not in corpus) “i NN
# IndexErrors (POS not found) passionate NN
# pos KeyErrors about IN
# Error (not in corpus) , ,
# pos KeyErrors can MD
# Error (not in corpus) , ,
# pos KeyErrors a DT
# Error (not in corpus) to TO
# pos KeyErrors new JJ
# Error (not in corpus) and CC
# Error (not in corpus) , ,
# pos KeyErrors i JJ
# Error (not in corpus) 'm VBP
# pos KeyErrors open JJ
# Error (not in corpus) to TO
# pos KeyErrors new JJ
# Error (not in corpus) and CC
# pos KeyErrors new JJ
# Error (not in corpus) , ,
# pos KeyErrors can MD
# pos KeyErrors about IN
# Error (not in corpus) what WP
# Error (not in corpus) 'm VBP
# Error (not in corpus) and CC
# Error (not in corpus) when WRB
# Error (not in corpus) help.” NN
# Error (not in corpus) this DT
# Error (not in corpus) what WP
# Error (not in corpus) from IN
# Error (not in corpus) . .
# Error (not in corpus) they PRP
# Error (not in corpus) n't RB
# pos KeyErrors much JJ
# Error (not in corpus) if IN
# Error (not in corpus) you PRP
# Error (not in corpus) n't RB
# Error (not in corpus) the DT
# pos KeyErrors exact JJ
# Error (not in corpus) for IN
# pos KeyErrors an DT
# pos KeyErrors inbuilt JJ
# Error (not in corpus) ( (
# pos KeyErrors i JJ
# Error (not in corpus) what WP
# Error (not in corpus) math.random NN
# Error (not in corpus) ( (
# Error (not in corpus) ) )
# pos KeyErrors in IN
# Error (not in corpus) my PRP$
# pos KeyErrors final JJ
# Error (not in corpus) ) )
# Error (not in corpus) , ,
# pos KeyErrors but CC
# Error (not in corpus) they PRP
# Error (not in corpus) that IN
# Error (not in corpus) you PRP
# pos KeyErrors can MD
# Error (not in corpus) your PRP$
# pos KeyErrors through IN
# pos KeyErrors a DT
# Error (not in corpus) and CC
# Error (not in corpus) that IN
# Error (not in corpus) you PRP
# pos KeyErrors an DT
# Error (not in corpus) and CC
# Error (not in corpus) for IN
# Error (not in corpus) how WRB
# Error (not in corpus) to TO
# Error (not in corpus) something NN
# Error (not in corpus) if IN
# Error (not in corpus) you PRP
# Error (not in corpus) n't RB
# pos KeyErrors it PRP
# Error (not in corpus) . .
# Error (not in corpus) them PRP
# Error (not in corpus) ! .
# pos KeyErrors more JJR
# pos KeyErrors about IN
# Error (not in corpus) their PRP$
# Error (not in corpus) , ,
# Error (not in corpus) what WP
# Error (not in corpus) they PRP
# Error (not in corpus) from IN
# pos KeyErrors a DT
# Error (not in corpus) , ,
# Error (not in corpus) what WP
# Error (not in corpus) their PRP$
# pos KeyErrors tech JJ
# Error (not in corpus) , ,
# Error (not in corpus) how WRB
# Error (not in corpus) , ,
# Error (not in corpus) what WP
# IndexErrors (POS not found) i VBD
# Error (not in corpus) 'd MD
# Error (not in corpus) etc JJR
# Error (not in corpus) than IN
# Error (not in corpus) they PRP
# pos KeyErrors me PRP
# Error (not in corpus) . .
# Error (not in corpus) you PRP
# Error (not in corpus) to TO
# Error (not in corpus) the DT
# pos KeyErrors informed JJ
# pos KeyErrors possible JJ
# pos KeyErrors about IN
# Error (not in corpus) the DT
# Error (not in corpus) you PRP
# Error (not in corpus) 're VBP
# Error (not in corpus) to TO
# Error (not in corpus) for IN
# Error (not in corpus) , ,
# Error (not in corpus) them PRP
# Error (not in corpus) . .
# pos KeyErrors like IN
# Error (not in corpus) this DT
# Error (not in corpus) - :
# pos KeyErrors it PRP
# Error (not in corpus) you PRP
# pos KeyErrors real JJ
# pos KeyErrors in IN
# Error (not in corpus) the DT
# Error (not in corpus) . .
# Error (not in corpus) . .
# Error (not in corpus) n't RB
# Error (not in corpus) the DT
# pos KeyErrors first JJ
# Error (not in corpus) which WDT
# Error (not in corpus) to TO
# Error (not in corpus) you PRP
# Error (not in corpus) . .
# Error (not in corpus) what WP
# Error (not in corpus) you PRP
# Error (not in corpus) from IN
# pos KeyErrors a DT
# Error (not in corpus) ( (
# Error (not in corpus) , ,
# Error (not in corpus) , ,
# Error (not in corpus) , ,
# Error (not in corpus) to TO
# pos KeyErrors senior JJ
# Error (not in corpus) devs NN
# Error (not in corpus) and CC
# Error (not in corpus) , ,
# pos KeyErrors salary JJ
# Error (not in corpus) , ,
# pos KeyErrors commute JJ
# Error (not in corpus) , ,
# Error (not in corpus) etc NN
# Error (not in corpus) ) )
# Error (not in corpus) and CC
# pos KeyErrors an DT
# pos KeyErrors informed JJ
# Error (not in corpus) which WDT
# Error (not in corpus) these DT
# Error (not in corpus) . .
# Error (not in corpus) my PRP$
# pos KeyErrors main JJ
# Error (not in corpus) ( (
# pos KeyErrors in IN
# pos KeyErrors rough JJ
# Error (not in corpus) ) )
# Error (not in corpus) - :
# Error (not in corpus) to TO
# pos KeyErrors senior JJ
# Error (not in corpus) devs/mentors NNS
# Error (not in corpus) , ,
# Error (not in corpus) , ,
# Error (not in corpus) , ,
# pos KeyErrors salary JJ
# Error (not in corpus) , ,
# Error (not in corpus) and CC
# pos KeyErrors i JJ
# Error (not in corpus) 've VBP
# pos KeyErrors lucky JJ
# Error (not in corpus) to TO
# pos KeyErrors a DT
# Error (not in corpus) which WDT
# pos KeyErrors all DT
# Error (not in corpus) of IN
# Error (not in corpus) these DT
# pos KeyErrors more JJR
# Error (not in corpus) than IN
# pos KeyErrors possible JJ
# Error (not in corpus) into IN
# Error (not in corpus) this DT
# Error (not in corpus) ! .
# Error (not in corpus) to TO
# IndexErrors (POS not found) fcc VB
# Error (not in corpus) and CC
# Error (not in corpus) @ NNP
# Error (not in corpus) quincylarson NN
# Error (not in corpus) for IN
# pos KeyErrors such PDT
# pos KeyErrors an DT
# pos KeyErrors amazing JJ
# Error (not in corpus) for IN
# Error (not in corpus) to TO
# Error (not in corpus) , ,
# pos KeyErrors a DT
# Error (not in corpus) and CC
# Error (not in corpus) the DT
# pos KeyErrors about IN
# Error (not in corpus) the DT
# Error (not in corpus) of IN
# Error (not in corpus) to TO
# Error (not in corpus) without IN
# Error (not in corpus) to TO
# pos KeyErrors many JJ
# Error (not in corpus) of IN
# Error (not in corpus) of IN
# pos KeyErrors on IN
# pos KeyErrors or CC
# pos KeyErrors expensive JJ
# Error (not in corpus) bootcamps NNS
# Error (not in corpus) . .
# tree2conlltags [('week', 'NN', 'B-KT'), ('accept', 'VBD', 'O'), ('junior', 'JJ', 'B-KT'), ('developer', 'NN', 'I-KT'), ('job', 'NN', 'I-KT'), ('cool', 'JJ', 'B-KT'), ('creative', 'JJ', 'I-KT'), ('agency', 'NN', 'I-KT'), ('near', 'IN', 'I-KT'), ('old', 'JJ', 'I-KT'), ('street', 'NN', 'I-KT'), ('london', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb704f8>
# ['week', 'junior developer job cool creative agency near old street london']
# ['week', 'junior developer job cool creative agency near old street london']
# tree2conlltags [("'s", 'VBZ', 'O'), ('culmination', 'NN', 'B-KT'), ('two', 'CD', 'O'), ('year', 'NNS', 'B-KT'), ('work', 'NN', 'I-KT'), ('(', '(', 'O'), (')', ')', 'O'), ("'m", 'VBP', 'O'), ('highly', 'RB', 'O'), ('excite', 'VBN', 'O'), ('begin', 'VB', 'O'), ('new', 'JJ', 'B-KT'), ('chapter', 'NN', 'I-KT'), ('life', 'NN', 'I-KT'), ('many', 'JJ', 'B-KT'), ('possibility', 'NNS', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb70548>
# ['culmination', 'year work', 'new chapter life many possibility']
# ['culmination', 'year work', 'new chapter life many possibility']
# tree2conlltags [('background', 'NN', 'B-KT'), ("'m", 'VBP', 'O'), ('31', 'CD', 'O'), (',', ',', 'O'), ('history', 'NN', 'B-KT'), ('degree', 'NN', 'I-KT'), ('work', 'NN', 'I-KT'), ('advertising', 'NN', 'I-KT'), ('industry', 'NN', 'I-KT'), ('london', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb70598>
# ['background', 'history degree work advertising industry london']
# ['background', 'history degree work advertising industry london']
# tree2conlltags [('largely', 'RB', 'O'), ('sale', 'NNS', 'B-KT'), (',', ',', 'O'), ('recent', 'JJ', 'B-KT'), ('focus', 'NN', 'I-KT'), ('project', 'NN', 'I-KT'), ('management', 'NN', 'I-KT'), ('brand', 'VBN', 'O'), ('content', 'NN', 'B-KT'), ('partnership', 'NNS', 'I-KT'), ('(', '(', 'O'), ('video', 'NNS', 'B-KT'), (',', ',', 'O'), ('photography', 'NN', 'B-KT'), (',', ',', 'O'), ('article', 'NNS', 'B-KT'), (',', ',', 'O'), ('social', 'JJ', 'B-KT'), ('medium', 'NNS', 'I-KT'), (',', ',', 'O'), ('tv', 'NN', 'B-KT'), ('etc', 'NN', 'I-KT'), (')', ')', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb70598>
# ['sale', 'recent focus project management', 'content partnership', 'video', 'photography', 'article', 'social medium', 'tv etc']
# ['sale', 'recent focus project management', 'content partnership', 'video', 'photography', 'article', 'social medium', 'tv etc']
# tree2conlltags [("'ve", 'VBP', 'O'), ('work', 'VBN', 'O'), ('truly', 'RB', 'O'), ('cool', 'JJ', 'B-KT'), ('company', 'NNS', 'I-KT'), ('brand', 'NNS', 'I-KT'), ('truly', 'RB', 'O'), ('interesting', 'JJ', 'B-KT'), ('project', 'NNS', 'I-KT'), (',', ',', 'O'), ("'ve", 'VBP', 'O'), ('unhappy', 'JJ', 'B-KT'), ('career', 'NNS', 'I-KT'), ('good', 'JJ', 'B-KT'), ('couple', 'NN', 'I-KT'), ('year', 'NNS', 'I-KT'), (',', ',', 'O'), ('always', 'RB', 'O'), ('want', 'VBN', 'O'), ('something', 'NN', 'B-KT'), ('technical', 'JJ', 'O'), ('intellectually', 'RB', 'O'), ('reward', 'VBG', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb70598>
# ['cool company brand', 'interesting project', 'unhappy career good couple year', 'something']
# ['cool company brand', 'interesting project', 'unhappy career good couple year', 'something']
# tree2conlltags [('learn', 'VBG', 'O'), ('start', 'VBD', 'O'), ('fcc', 'NN', 'B-KT'), ('couple', 'NN', 'I-KT'), ('year', 'NNS', 'I-KT'), ('ago', 'RB', 'O'), (',', ',', 'O'), ('go', 'VBD', 'O'), ('couple', 'NN', 'B-KT'), ('spurt', 'NNS', 'I-KT'), ("'d", 'MD', 'O'), ('systematically', 'RB', 'O'), ('progress', 'VB', 'O'), ('month', 'NNS', 'B-KT'), ('life', 'NN', 'I-KT'), ('get', 'VBD', 'O'), ('way', 'NN', 'B-KT'), ("'d", 'MD', 'O'), ('stall', 'VB', 'O'), ('nothing', 'NN', 'B-KT'), ('month', 'NNS', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb70598>
# ['fcc couple year', 'couple spurt', 'month life', 'way', 'nothing month']
# ['fcc couple year', 'couple spurt', 'month life', 'way', 'nothing month']
# tree2conlltags [('summer', 'NN', 'B-KT'), ('truly', 'RB', 'O'), ('sat', 'JJ', 'O'), ('pledge', 'VBD', 'O'), ('dedicate', 'VB', 'O'), ('program', 'VBG', 'O'), ("'s", 'VBZ', 'O'), ('finally', 'RB', 'O'), ('pay', 'VBN', 'O'), ('!', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb70598>
# ['summer']
# ['summer']
# tree2conlltags [('follow', 'VBD', 'O'), ('set', 'NN', 'B-KT'), ('course', 'NN', 'I-KT'), ('fcc', 'NN', 'I-KT'), ('front', 'JJ', 'B-KT'), ('end', 'NN', 'I-KT'), ('cert', 'NN', 'I-KT'), ('branch', 'VBG', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb70598>
# ['set course fcc front end cert']
# ['set course fcc front end cert']
# tree2conlltags [('bit', 'NNS', 'B-KT'), ('advice', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb70598>
# ['bit advice']
# ['bit advice']
# tree2conlltags [('get', 'VB', 'O'), ('codepen', 'JJ', 'O'), ('quickly', 'RB', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb70598>
# []
# []
# tree2conlltags [('learn', 'NN', 'B-KT'), ('git', 'NN', 'I-KT'), (',', ',', 'O'), ('learn', 'VBP', 'O'), ('command', 'NN', 'B-KT'), ('line', 'NN', 'I-KT'), (',', ',', 'O'), ('learn', 'VB', 'O'), ('structure', 'NN', 'B-KT'), ('professional', 'JJ', 'O'), ('look', 'VBG', 'O'), ('front', 'JJ', 'B-KT'), ('end', 'NN', 'I-KT'), ('project', 'NN', 'I-KT'), (',', ',', 'O'), ('learn', 'VB', 'O'), ('gulp', 'NN', 'B-KT'), ('grunt', 'NN', 'I-KT'), (',', ',', 'O'), ('learn', 'VB', 'O'), ('manage', 'VB', 'O'), ('dependency', 'NNS', 'B-KT'), ('npm', 'NN', 'I-KT'), (',', ',', 'O'), ('learn', 'JJ', 'B-KT'), ('sass', 'NN', 'I-KT'), (',', ',', 'O'), ('get', 'VB', 'O'), ('project', 'NNS', 'B-KT'), ('host', 'VBN', 'O'), ('github', 'NN', 'B-KT'), ('page', 'NNS', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb70598>
# ['learn git', 'command line', 'structure', 'front end project', 'gulp grunt', 'dependency npm', 'learn sass', 'project', 'github page']
# ['learn git', 'command line', 'structure', 'front end project', 'gulp grunt', 'dependency npm', 'learn sass', 'project', 'github page']
# tree2conlltags [('none', 'NN', 'B-KT'), ('skills/technologies', 'NNS', 'I-KT'), ('particularly', 'RB', 'O'), ('complicate', 'VBN', 'O'), ('learn', 'VB', 'O'), (',', ',', 'O'), ('make', 'VB', 'O'), ('far', 'RB', 'O'), ('attractive', 'JJ', 'B-KT'), ('potential', 'JJ', 'I-KT'), ('employer', 'NN', 'I-KT'), ('probably', 'RB', 'O'), ('skill', 'NNS', 'B-KT'), ("'ll", 'MD', 'O'), ('use', 'VBG', 'O'), ('job', 'NN', 'B-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb704a8>
# ['none skills/technologies', 'attractive potential employer', 'skill', 'job']
# ['none skills/technologies', 'attractive potential employer', 'skill', 'job']
# tree2conlltags [('one', 'CD', 'O'), ('biggest', 'JJS', 'O'), ('reason', 'NNS', 'B-KT'), ('able', 'JJ', 'O'), ('speak', 'VB', 'O'), ('confidently', 'RB', 'O'), ('ability', 'NNS', 'B-KT'), ('interview', 'NNS', 'I-KT'), ('make', 'VBN', 'O'), ('effort', 'NN', 'B-KT'), ('learn', 'VB', 'O'), ('use', 'VB', 'O'), ('modern', 'JJ', 'B-KT'), ('front', 'JJ', 'I-KT'), ('end', 'NN', 'I-KT'), ('eco-system', 'NN', 'I-KT'), ('reasonably', 'JJ', 'B-KT'), ('professional', 'JJ', 'I-KT'), ('way', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb704a8>
# ['reason', 'ability interview', 'effort', 'modern front end eco-system reasonably professional way']
# ['reason', 'ability interview', 'effort', 'modern front end eco-system reasonably professional way']
# tree2conlltags [('react', 'NN', 'B-KT'), ("n't", 'RB', 'O'), ('hard', 'JJ', 'O'), ('learn', 'VB', 'O'), ('(', '(', 'O'), ('much', 'RB', 'O'), ('might', 'MD', 'O'), ('seem', 'VB', 'O'), ('hard', 'RB', 'O'), ('first', 'JJ', 'B-KT'), ('glance', 'NN', 'I-KT'), (')', ')', 'O'), (',', ',', 'O'), ('look', 'VBZ', 'O'), ('great', 'JJ', 'B-KT'), ('cv', 'NN', 'I-KT'), (',', ',', 'O'), ('massively', 'RB', 'O'), ('demand', 'NN', 'B-KT'), ('right', 'RB', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb70598>
# ['react', 'first glance', 'great cv', 'demand']
# ['react', 'first glance', 'great cv', 'demand']
# tree2conlltags [("n't", 'RB', 'O'), ('find', 'VB', 'O'), ('fcc', 'JJ', 'O'), ('great', 'JJ', 'O'), ('learn', 'VBG', 'O'), ('react', 'NN', 'B-KT'), ('(', '(', 'O'), ('may', 'MD', 'O'), ('change', 'VBN', 'O'), ('fcc', 'NN', 'B-KT'), ('beta', 'NN', 'I-KT'), ('?', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb70598>
# ['react', 'fcc beta']
# ['react', 'fcc beta']
# tree2conlltags [(')', ')', 'O'), ('-', ':', 'O'), ('good', 'JJ', 'B-KT'), ('place', 'NN', 'I-KT'), ('start', 'VB', 'O'), ('-', ':', 'O'), ('https', 'NN', 'B-KT'), (':', ':', 'O'), ('//www.udemy.com/react-redux/learn/v4/overview', 'JJ', 'O'), ('consistent', 'JJ', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb706d8>
# ['good place', 'https']
# ['good place', 'https']
# tree2conlltags [('set', 'VBD', 'O'), ('block', 'NNS', 'B-KT'), ('time', 'NN', 'I-KT'), ('every', 'DT', 'O'), ('day', 'NN', 'B-KT'), ('calendar', 'NN', 'I-KT'), ('learn', 'VB', 'O'), ('build', 'VB', 'O'), ('project', 'NNS', 'B-KT'), ('week', 'NNS', 'I-KT'), ('work', 'VBG', 'O'), ('25', 'CD', 'O'), ('hour', 'NNS', 'B-KT'), ('outside', 'IN', 'I-KT'), ('9-6', 'JJ', 'I-KT'), ('job', 'NN', 'I-KT'), ('(', '(', 'O'), ('wake', 'VBG', 'O'), ('6am', 'CD', 'O'), ('study', 'VB', 'O'), ('couple', 'NN', 'B-KT'), ('hour', 'NNS', 'I-KT'), (',', ',', 'O'), ('study', 'VBG', 'O'), ('evening', 'NNS', 'B-KT'), ('weekend', 'NNS', 'I-KT'), (')', ')', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb704a8>
# ['block time', 'day calendar', 'project week', 'hour outside 9-6 job', 'couple hour', 'evening weekend']
# ['block time', 'day calendar', 'project week', 'hour outside 9-6 job', 'couple hour', 'evening weekend']
# tree2conlltags [('smart', 'JJ', 'B-KT'), ('fit', 'JJ', 'I-KT'), ('study', 'NN', 'I-KT'), ('time', 'NN', 'I-KT'), ('around', 'IN', 'I-KT'), ('life', 'NN', 'I-KT'), ('way', 'NN', 'I-KT'), ('sustainable', 'JJ', 'B-KT'), ('circumstance', 'NNS', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb707c8>
# ['smart fit study time around life way sustainable circumstance']
# ['smart fit study time around life way sustainable circumstance']
# tree2conlltags [('codewars', 'NNS', 'B-KT'), ('-', ':', 'O'), ('great', 'JJ', 'B-KT'), ('way', 'NN', 'I-KT'), ('learn', 'VB', 'O'), ('javascript', 'NN', 'B-KT'), ('fundamental', 'NNS', 'I-KT'), ('truly', 'RB', 'O'), ('stretch', 'VB', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb707c8>
# ['codewars', 'great way', 'javascript fundamental']
# ['codewars', 'great way', 'javascript fundamental']
# tree2conlltags [('much', 'RB', 'O'), (',', ',', 'O'), ('realise', 'VBG', 'O'), ('project', 'NNS', 'B-KT'), ('get', 'VB', 'O'), ('foot', 'NN', 'B-KT'), ('door', 'NN', 'I-KT'), ('interview', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb707c8>
# ['project', 'foot door interview']
# ['project', 'foot door interview']
# tree2conlltags [('structure', 'NN', 'B-KT'), ('learning', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb707c8>
# ['structure learning']
# ['structure learning']
# tree2conlltags [('go', 'VBD', 'O'), ('job', 'NN', 'B-KT'), ('listing', 'NNS', 'I-KT'), ('early_on', 'RB', 'O'), ('learning', 'JJ', 'B-KT'), ('path', 'NN', 'I-KT'), ('list', 'VB', 'O'), ('technology', 'NNS', 'B-KT'), ('demand', 'VBN', 'O'), ('employer', 'NNS', 'B-KT'), ('build', 'VB', 'O'), ('plan', 'NN', 'B-KT'), ('learn', 'VB', 'O'), ('showcase', 'VB', 'O'), ('most/all', 'NN', 'B-KT'), ('project', 'NNS', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89dcb704a8>
# ['job listing', 'learning path', 'technology', 'employer', 'plan', 'most/all project']
# ['job listing', 'learning path', 'technology', 'employer', 'plan', 'most/all project']
# ...
# Error (not in corpus) , ,
# pos KeyErrors but CC
# IndexErrors (POS not found) i RB
# pos KeyErrors some DT
# pos KeyErrors in IN
# pos KeyErrors a DT
# pos KeyErrors few JJ
# Error (not in corpus) , ,
# Error (not in corpus) , ,
# Error (not in corpus) which WDT
# IndexErrors (POS not found) i VBP
# Error (not in corpus) for IN
# Error (not in corpus) and CC
# Error (not in corpus) . .
# pos KeyErrors some DT
# IndexErrors (POS not found) i VBP
# Error (not in corpus) from IN
# Error (not in corpus) my PRP$
# Error (not in corpus) : :
# pos KeyErrors it PRP
# pos KeyErrors important JJ
# Error (not in corpus) to TO
# Error (not in corpus) the DT
# Error (not in corpus) . .
# pos KeyErrors learn JJ
# Error (not in corpus) javascript NN
# pos KeyErrors before IN
# IndexErrors (POS not found) react NN
# Error (not in corpus) , ,
# IndexErrors (POS not found) angular NN
# pos KeyErrors or CC
# Error (not in corpus) jquery NN
# Error (not in corpus) ; :
# pos KeyErrors learn CC
# pos KeyErrors before IN
# pos KeyErrors or CC
# Error (not in corpus) . .
# Error (not in corpus) your PRP$
# pos KeyErrors will MD
# pos KeyErrors a DT
# pos KeyErrors easier JJR
# Error (not in corpus) and CC
# Error (not in corpus) you PRP
# pos KeyErrors will MD
# pos KeyErrors a DT
# Error (not in corpus) btter NN
# Error (not in corpus) of IN
# Error (not in corpus) what WP
# Error (not in corpus) and CC
# Error (not in corpus) how WRB
# pos KeyErrors in IN
# Error (not in corpus) these DT
# Error (not in corpus) . .
# Error (not in corpus) you PRP
# Error (not in corpus) should MD
# pos KeyErrors an DT
# pos KeyErrors in IN
# Error (not in corpus) what WP
# Error (not in corpus) the DT
# Error (not in corpus) to TO
# pos KeyErrors in IN
# Error (not in corpus) the DT
# Error (not in corpus) you PRP
# Error (not in corpus) . .
# Error (not in corpus) for IN
# pos KeyErrors me PRP
# Error (not in corpus) , ,
# Error (not in corpus) for IN
# pos KeyErrors a DT
# pos KeyErrors front JJ
# Error (not in corpus) and CC
# pos KeyErrors it PRP
# pos KeyErrors clear JJ
# Error (not in corpus) that IN
# IndexErrors (POS not found) overall VBP
# Error (not in corpus) the DT
# pos KeyErrors requested JJ
# pos KeyErrors good JJ
# Error (not in corpus) of IN
# Error (not in corpus) reactjs NN
# pos KeyErrors or CC
# IndexErrors (POS not found) angular NN
# Error (not in corpus) . .
# pos KeyErrors a DT
# Error (not in corpus) of IN
# pos KeyErrors both DT
# Error (not in corpus) ( (
# Error (not in corpus) and CC
# Error (not in corpus) vuejs NN
# Error (not in corpus) , ,
# pos KeyErrors but CC
# pos KeyErrors there EX
# Error (not in corpus) n't RB
# pos KeyErrors a DT
# Error (not in corpus) of IN
# Error (not in corpus) for IN
# pos KeyErrors it PRP
# pos KeyErrors in IN
# Error (not in corpus) ) )
# Error (not in corpus) and CC
# Error (not in corpus) to TO
# pos KeyErrors in IN
# IndexErrors (POS not found) angular NN
# Error (not in corpus) . .
# pos KeyErrors it PRP
# Error (not in corpus) that IN
# pos KeyErrors difficult JJ
# pos KeyErrors but CC
# IndexErrors (POS not found) i VBZ
# Error (not in corpus) the DT
# Error (not in corpus) of IN
# pos KeyErrors it PRP
# pos KeyErrors after IN
# Error (not in corpus) for IN
# pos KeyErrors real JJ
# pos KeyErrors in IN
# Error (not in corpus) my PRP$
# Error (not in corpus) . .
# Error (not in corpus) and CC
# Error (not in corpus) you PRP
# pos KeyErrors can MD
# pos KeyErrors me PRP
# Error (not in corpus) , ,
# pos KeyErrors it PRP
# pos KeyErrors useful JJ
# Error (not in corpus) . .
# pos KeyErrors after IN
# pos KeyErrors i JJ
# pos KeyErrors a DT
# pos KeyErrors solid JJ
# Error (not in corpus) of IN
# Error (not in corpus) the DT
# Error (not in corpus) of IN
# Error (not in corpus) webdev NN
# Error (not in corpus) and CC
# pos KeyErrors a DT
# pos KeyErrors few JJ
# pos KeyErrors good JJ
# Error (not in corpus) to TO
# Error (not in corpus) , ,
# IndexErrors (POS not found) i VB
# pos KeyErrors a DT
# Error (not in corpus) and CC
# Error (not in corpus) my PRP$
# Error (not in corpus) to TO
# Error (not in corpus) for IN
# Error (not in corpus) . .
# pos KeyErrors lucky JJ
# pos KeyErrors in IN
# Error (not in corpus) that DT
# Error (not in corpus) n't RB
# Error (not in corpus) to TO
# Error (not in corpus) for IN
# pos KeyErrors many JJ
# pos KeyErrors before IN
# pos KeyErrors a DT
# Error (not in corpus) from IN
# pos KeyErrors a DT
# Error (not in corpus) . .
# Error (not in corpus) they PRP
# pos KeyErrors me PRP
# pos KeyErrors a DT
# pos KeyErrors in IN
# Error (not in corpus) which WDT
# Error (not in corpus) to TO
# pos KeyErrors a DT
# pos KeyErrors small JJ
# Error (not in corpus) app NN
# pos KeyErrors in IN
# pos KeyErrors angular JJ
# Error (not in corpus) that WDT
# Error (not in corpus) would MD
# pos KeyErrors an DT
# pos KeyErrors certain JJ
# Error (not in corpus) api NN
# Error (not in corpus) . .
# pos KeyErrors though IN
# Error (not in corpus) n't RB
# pos KeyErrors a DT
# Error (not in corpus) of IN
# Error (not in corpus) the DT
# Error (not in corpus) app NN
# Error (not in corpus) the DT
# pos KeyErrors best JJS
# Error (not in corpus) could MD
# Error (not in corpus) , ,
# Error (not in corpus) the DT
# pos KeyErrors good JJ
# IndexErrors (POS not found) i VBP
# pos KeyErrors knew CD
# Error (not in corpus) of IN
# Error (not in corpus) . .
# pos KeyErrors it PRP
# Error (not in corpus) from IN
# pos KeyErrors perfect JJ
# Error (not in corpus) , ,
# pos KeyErrors but CC
# Error (not in corpus) they PRP
# Error (not in corpus) my PRP$
# Error (not in corpus) and CC
# Error (not in corpus) for IN
# pos KeyErrors an DT
# Error (not in corpus) . .
# pos KeyErrors it PRP
# pos KeyErrors a DT
# pos KeyErrors good JJ
# Error (not in corpus) and CC
# pos KeyErrors excited JJ
# Error (not in corpus) with IN
# Error (not in corpus) this DT
# pos KeyErrors new JJ
# Error (not in corpus) . .
# pos KeyErrors aware JJ
# Error (not in corpus) that IN
# Error (not in corpus) this DT
# Error (not in corpus) the DT
# Error (not in corpus) and CC
# pos KeyErrors will MD
# Error (not in corpus) and CC
# Error (not in corpus) my PRP$
# pos KeyErrors best JJS
# pos KeyErrors i JJ
# pos KeyErrors can MD
# pos KeyErrors a DT
# pos KeyErrors competent JJ
# Error (not in corpus) . .
# pos KeyErrors grateful JJ
# Error (not in corpus) for IN
# Error (not in corpus) . .
# pos KeyErrors though IN
# pos KeyErrors through IN
# pos KeyErrors other JJ
# Error (not in corpus) , ,
# pos KeyErrors it PRP
# Error (not in corpus) the DT
# pos KeyErrors important JJ
# Error (not in corpus) for IN
# pos KeyErrors me PRP
# pos KeyErrors in IN
# Error (not in corpus) this DT
# Error (not in corpus) . .
# Error (not in corpus) the DT
# pos KeyErrors structured JJ
# Error (not in corpus) and CC
# Error (not in corpus) the DT
# pos KeyErrors nice JJ
# pos KeyErrors important JJ
# Error (not in corpus) . .
# IndexErrors (POS not found) thank NN
# Error (not in corpus) you PRP
# pos KeyErrors all DT
# Error (not in corpus) ! .
# tree2conlltags [('hey', 'NN', 'B-KT'), ('guy', 'NNS', 'I-KT'), (',', ',', 'O'), ('like', 'IN', 'O'), ('title', 'NN', 'B-KT'), ('say', 'VBZ', 'O'), (',', ',', 'O'), ('hire', 'VBN', 'O'), ('front-end', 'JJ', 'B-KT'), ('developer', 'NN', 'I-KT'), ('9-10', 'JJ', 'B-KT'), ('month', 'NNS', 'I-KT'), ('start', 'VBD', 'O'), ('fcc', 'NN', 'B-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915a958>
# ['hey guy', 'title', 'front-end developer 9-10 month', 'fcc']
# ['hey guy', 'title', 'front-end developer 9-10 month', 'fcc']
# tree2conlltags [("'ve", 'VBP', 'O'), ('always', 'RB', 'O'), ('like', 'VBN', 'O'), ('read', 'VB', 'O'), ('thread', 'NNS', 'B-KT'), ('camper', 'NNS', 'I-KT'), ('get', 'VBD', 'O'), ('job', 'NN', 'B-KT'), (',', ',', 'O'), ('give', 'VBD', 'O'), ('lot', 'NN', 'B-KT'), ('motivation', 'NN', 'I-KT'), ('optimism', 'NN', 'I-KT'), ('study', 'NNS', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915a958>
# ['thread camper', 'job', 'lot motivation optimism study']
# ['thread camper', 'job', 'lot motivation optimism study']
# tree2conlltags [('think', 'VBP', 'O'), ('would', 'MD', 'O'), ('nice', 'JJ', 'B-KT'), ('share', 'NN', 'I-KT'), ('thought', 'NNS', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915a958>
# ['nice share thought']
# ['nice share thought']
# tree2conlltags [('course', 'NN', 'B-KT'), (',', ',', 'O'), ('experience', 'NN', 'B-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915aa98>
# ['course', 'experience']
# ['course', 'experience']
# tree2conlltags [('background', 'NN', 'B-KT'), (',', ',', 'O'), ('bachelor', 'NN', 'B-KT'), ('degree', 'NN', 'I-KT'), ('relate', 'VBN', 'O'), ('cs', 'VB', 'O'), (',', ',', 'O'), ('experience', 'NN', 'B-KT'), ('programming', 'NN', 'I-KT'), ('language', 'NNS', 'I-KT'), (',', ',', 'O'), ('particularly', 'RB', 'O'), ('python', 'NN', 'B-KT'), (',', ',', 'O'), ('use', 'VBN', 'O'), ('text', 'NN', 'B-KT'), ('data', 'NN', 'I-KT'), ('manipulation', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ab38>
# ['background', 'bachelor degree', 'experience programming language', 'python', 'text data manipulation']
# ['background', 'bachelor degree', 'experience programming language', 'python', 'text data manipulation']
# tree2conlltags [('impression', 'NNS', 'B-KT'), ('get', 'VBN', 'O'), ('study', 'NNS', 'B-KT'), (':', ':', 'O'), ('think', 'VBP', 'O'), ('truly', 'RB', 'O'), ('important', 'JJ', 'O'), ('truly', 'RB', 'O'), ('learn', 'VB', 'O'), ('basic', 'NNS', 'B-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ac28>
# ['impression', 'study', 'basic']
# ['impression', 'study', 'basic']
# tree2conlltags [('truly', 'RB', 'O'), ('learn', 'JJ', 'B-KT'), ('javascript', 'NN', 'I-KT'), ('learn', 'VBG', 'O'), ('react', 'NN', 'B-KT'), (',', ',', 'O'), ('angular', 'NN', 'B-KT'), ('even', 'RB', 'O'), ('jquery', 'NN', 'B-KT'), (';', ':', 'O'), ('learn', 'CC', 'O'), ('css', 'NN', 'B-KT'), ('learn', 'VBG', 'O'), ('bootstrap', 'NN', 'B-KT'), ('foundation', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ac28>
# ['learn javascript', 'react', 'angular', 'jquery', 'css', 'bootstrap foundation']
# ['learn javascript', 'react', 'angular', 'jquery', 'css', 'bootstrap foundation']
# tree2conlltags [('journey', 'NN', 'B-KT'), ('lot', 'NN', 'I-KT'), ('easier', 'JJR', 'O'), ('btter', 'NN', 'B-KT'), ('understanding', 'NN', 'I-KT'), ('thing', 'NNS', 'I-KT'), ('happen', 'VBG', 'O'), ('framework', 'NNS', 'B-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ac28>
# ['journey lot', 'btter understanding thing', 'framework']
# ['journey lot', 'btter understanding thing', 'framework']
# tree2conlltags [('keep', 'VB', 'O'), ('eye', 'NN', 'B-KT'), ('company', 'NNS', 'I-KT'), ('ask', 'VBG', 'O'), ('hire', 'VB', 'O'), ('someone', 'NN', 'B-KT'), ('position', 'NN', 'I-KT'), ('want', 'VBP', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ac28>
# ['eye company', 'someone position']
# ['eye company', 'someone position']
# tree2conlltags [(',', ',', 'O'), ('look', 'VBG', 'O'), ('front', 'JJ', 'B-KT'), ('end', 'NN', 'I-KT'), ('position', 'NN', 'I-KT'), ('clear', 'JJ', 'O'), ('overall', 'VBP', 'O'), ('requested', 'JJ', 'B-KT'), ('skill', 'NNS', 'I-KT'), ('good', 'JJ', 'B-KT'), ('knowledge', 'NN', 'I-KT'), ('reactjs', 'NN', 'I-KT'), ('angular', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ac28>
# ['front end position', 'requested skill good knowledge reactjs angular']
# ['front end position', 'requested skill good knowledge reactjs angular']
# tree2conlltags [('learn', 'VBD', 'O'), ('bit', 'NN', 'B-KT'), ('(', '(', 'O'), ('vuejs', 'NN', 'B-KT'), (',', ',', 'O'), ('unfortunately', 'RB', 'O'), ("n't", 'RB', 'O'), ('lot', 'NN', 'B-KT'), ('demand', 'NN', 'I-KT'), ('brazil', 'NN', 'I-KT'), (')', ')', 'O'), ('choose', 'VB', 'O'), ('focus', 'VB', 'O'), ('angular', 'NN', 'B-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ac28>
# ['bit', 'vuejs', 'lot demand brazil', 'angular']
# ['bit', 'vuejs', 'lot demand brazil', 'angular']
# tree2conlltags [('learn', 'VBG', 'O'), ('git', 'NN', 'B-KT'), ('difficult', 'JJ', 'O'), ('get', 'VBD', 'O'), ('hang', 'NN', 'B-KT'), ('start', 'VBD', 'O'), ('use', 'VBG', 'O'), ('real', 'JJ', 'B-KT'), ('project', 'NNS', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ac28>
# ['git', 'hang', 'real project']
# ['git', 'hang', 'real project']
# tree2conlltags [('trust', 'VB', 'O'), (',', ',', 'O'), ('useful', 'JJ', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ac28>
# []
# []
# tree2conlltags [('know', 'VBD', 'O'), ('solid', 'JJ', 'B-KT'), ('knowledge', 'NN', 'I-KT'), ('basic', 'NNS', 'I-KT'), ('webdev', 'NN', 'I-KT'), ('good', 'JJ', 'B-KT'), ('project', 'NNS', 'I-KT'), ('show', 'VB', 'O'), (',', ',', 'O'), ('buy', 'VBD', 'O'), ('domain', 'NN', 'B-KT'), ('host', 'VBD', 'O'), ('portfolio', 'NN', 'B-KT'), ('start', 'VB', 'O'), ('apply', 'VBG', 'O'), ('job', 'NNS', 'B-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ac28>
# ['solid knowledge basic webdev good project', 'domain', 'portfolio', 'job']
# ['solid knowledge basic webdev good project', 'domain', 'portfolio', 'job']
# tree2conlltags [('lucky', 'JJ', 'O'), ("n't", 'RB', 'O'), ('need', 'VB', 'O'), ('apply', 'VB', 'O'), ('many', 'JJ', 'B-KT'), ('position', 'NNS', 'I-KT'), ('get', 'VBD', 'O'), ('response', 'NN', 'B-KT'), ('company', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ac28>
# ['many position', 'response company']
# ['many position', 'response company']
# tree2conlltags [('send', 'VBD', 'O'), ('test', 'NN', 'B-KT'), ('make', 'VB', 'O'), ('small', 'JJ', 'B-KT'), ('app', 'NN', 'I-KT'), ('angular', 'JJ', 'O'), ('feature', 'VBG', 'O'), ('unit', 'NN', 'B-KT'), ('test', 'NNS', 'I-KT'), ('would', 'MD', 'O'), ('consume', 'VB', 'O'), ('certain', 'JJ', 'B-KT'), ('api', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ac28>
# ['test', 'small app', 'unit test', 'certain api']
# ['test', 'small app', 'unit test', 'certain api']
# tree2conlltags [('even', 'RB', 'O'), ('though', 'IN', 'O'), ("n't", 'RB', 'O'), ('lot', 'NN', 'B-KT'), ('experience', 'NN', 'I-KT'), ('polish', 'VBD', 'O'), ('app', 'NN', 'B-KT'), ('best', 'JJS', 'O'), ('could', 'MD', 'O'), (',', ',', 'O'), ('follow', 'VBG', 'O'), ('good', 'JJ', 'B-KT'), ('practice', 'NNS', 'I-KT'), ('knew', 'CD', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ac28>
# ['lot experience', 'app', 'good practice']
# ['lot experience', 'app', 'good practice']
# tree2conlltags [('far', 'RB', 'O'), ('perfect', 'JJ', 'O'), (',', ',', 'O'), ('like', 'VBD', 'O'), ('test', 'NN', 'B-KT'), ('call', 'VBD', 'O'), ('interview', 'NN', 'B-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915ac28>
# ['test', 'interview']
# ['test', 'interview']
# tree2conlltags [('good', 'JJ', 'B-KT'), ('company', 'NN', 'I-KT'), ('excited', 'JJ', 'B-KT'), ('new', 'JJ', 'I-KT'), ('step', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d915acc8>
# ['good company excited new step']
# ['good company excited new step']
# tree2conlltags [('aware', 'JJ', 'B-KT'), ('beginning', 'NN', 'I-KT'), ('keep', 'VB', 'O'), ('studying', 'NN', 'B-KT'), ('best', 'JJS', 'O'), ('become', 'VB', 'O'), ('competent', 'JJ', 'B-KT'), ('developer', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d91b4ae8>
# ['aware beginning', 'studying', 'competent developer']
# ['aware beginning', 'studying', 'competent developer']
# tree2conlltags [('grateful', 'JJ', 'B-KT'), ('fcc', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d91b4ae8>
# ['grateful fcc']
# ['grateful fcc']
# tree2conlltags [('even', 'RB', 'O'), ('though', 'IN', 'O'), ('probably', 'RB', 'O'), ('study', 'VBD', 'O'), ('source', 'NNS', 'B-KT'), (',', ',', 'O'), ('important', 'JJ', 'B-KT'), ('resource', 'NN', 'I-KT'), ('journey', 'NN', 'I-KT'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d91b4a98>
# ['source', 'important resource journey']
# ['source', 'important resource journey']
# tree2conlltags [('structured', 'JJ', 'B-KT'), ('curriculum', 'NN', 'I-KT'), ('nice', 'JJ', 'B-KT'), ('community', 'NN', 'I-KT'), ('important', 'JJ', 'O'), ('.', '.', 'O')]
# <itertools.groupby object at 0x7f89d91b4a98>
# ['structured curriculum nice community']
# ['structured curriculum nice community']
# tree2conlltags [('thank', 'NN', 'B-KT'), ('!', '.', 'O')]
# <itertools.groupby object at 0x7f89d91af7c8>
# ['thank']
# ['thank']
# number of treated posts (len(count)) :: 53
# lemm errs: 19235

# %%
############################
## allrecordsPreparation 3: revision of 2 to extend it for keyphrase candidate analysis
## some articles:
## -- https://stackoverflow.com/questions/34714162/preventing-splitting-at-apostrophies-when-tokenizing-words-using-nltk
############################

def allrecordsPreparation3(allrecords, STOPWORDS=nltk.corpus.stopwords.words('english'), punct = set(string.punctuation)):
    '''
    description: tokenization and POS tagging
    input: dict of allrecords texts and data from different sources
    treatment: separating only those with posts in the forum and tokenizing the posts
    output:
    1) list of lists, each with:
    -- id
    -- username
    -- link of the post
    -- tokenized text
    -- POS tagged text
    2) list of post ids
    '''
    print('in allrecordsPreparation (len(allrecords))::',len(allrecords))
 
       
    def HTMLtoText(u):
        #block arguments
        record = u["data"]
        forumpost = record['forum']['foundjob_msg']['text']
        if forumpost == '':
            return False
        forumpostID = record['forum']['foundjob_msg']['id']
        forumpostLINK = record['forum']['foundjob_msg']['link']
        soup_forumpost = BeautifulSoup(forumpost)
        soup_forumpostTEXT = soup_forumpost.find('body').get_text().replace('’',"'")
        tksoup_forumpostTEXT = [
                                #nltk.stem.WordNetLemmatizer().lemmatize(token.lower()) 
                                token.lower()
                                for token in nltk.word_tokenize(soup_forumpostTEXT)
                                #if token.lower() not in STOPWORDS 
                                #and not re.match(r'\d+?', token)
                                #and not all(char in set(string.punctuation) for char in token)
                               ]
        return forumpostID, forumpostLINK, tksoup_forumpostTEXT
    
    def approxsts(text):
        modtext = []
        for w in tksoup_forumpostTEXT:
            w = w.lower()
            rws = []
            if len(w) > 1 and len({'.','-',':'}.intersection(w)) >= 1:
                #print(w)
                for punc in {'.','-',':'}.intersection(w):
                    rws = w.replace(punc, ' '+punc+' ').split()
                #print(rws)
            if len(rws) == 0:
                modtext.append(w)
            else:
                for w in rws:
                    modtext.append(w)
        return modtext
    
    def lemmatizationofpos(postxt, lemmws):
        lemmposws = []
        counterrors = 0
        countKerrors = 0
        countIerrors = 0
        countNCerrors = 0
        for posw in postxt:
            w = posw[0]
            pos = posw[1]
            if nltk.corpus.wordnet.synsets(w):
                try:
                    n = ''
                    if nltk.corpus.wordnet.synsets(w,pos[0].lower())[0].root_hypernyms()[0].name().split('.')[0] == 'entity':
                        n = w
                    else:
                        n = nltk.corpus.wordnet.synsets(w,pos[0].lower())[0].root_hypernyms()[0].name().split('.')[0]
                    if pos[0] == 'V':
                        n = nltk.stem.wordnet.WordNetLemmatizer().lemmatize(w,'v')
                    if pos == 'NNS' or pos == 'NN$':
                        n = nltk.stem.wordnet.WordNetLemmatizer().lemmatize(w)
                    #print(w, nltk.corpus.wordnet.synsets(w,pos[0].lower())[0].root_hypernyms(), n)
                    lemmposws.append((w,True,n,pos))
                    lemmws.append(n)
                except KeyError: #in some cases the POS tag is not recognised by wordnet synset
                    print("pos KeyErrors", w,pos)
                    lemmposws.append((w,False,w,pos))
                    lemmws.append(w)
                    counterrors += 1
                    countKerrors += 1
                except IndexError:
                    print("IndexErrors (POS not found)", w,pos) #in some cases (w,pos) pair was not found at some point of the synsets root hyernyms
                    #print(nltk.corpus.wordnet.synsets(w,pos[0].lower()))
                    lemmposws.append((w,False,w,pos))
                    lemmws.append(w)
                    counterrors += 1
                    countIerrors += 1
            else:
                #print(w, [])
                print("Error (not in corpus)", w,pos)
                lemmposws.append((w,False,w,pos))
                lemmws.append(w)
                counterrors += 1
                countNCerrors += 1
        #print("\n\ntotal number of errors : ", counterrors)
        #print("total number of noPOSerrors : ", countKerrors)
        #print("total number of indexerrors : ", countIerrors)
        #print("total number of nonincorpuserrors : ", countNCerrors)
        return lemmposws, counterrors
      
    
    lemmws = []
    lemmposrecs = []
    count = 0
    lemerrors = 0
    for i, u in enumerate(allrecords):
        ## Getting the data as a text from HTML format (raw dataset)
        userdata = HTMLtoText(u)
        if userdata != False:
            forumpostID, forumpostLINK, tksoup_forumpostTEXT = userdata
            
            ## Sentence identification, tokenization and POS
            txt2possts = []
            st = []
            for token in tksoup_forumpostTEXT:
                st.append(token)
                if re.match(r'^[.!?]+|\n$', token):
                    postst = nltk.pos_tag(st)
                    txt2possts.append(postst)
                    st = []
            if not re.match(r'^[.!?]+|\n$', token):
                posst = nltk.pos_tag(st)
                txt2possts.append(posst)

           
            ## Lemm text
            lemmpostxt = []
            for posst in txt2possts:
                lemst, err = lemmatizationofpos(posst, lemmws)
                lemmpostxt.append(lemst)
                lemerrors += err

            
          
            ## Adding data to the new created dataset
            for ii, lemmposst in enumerate(lemmpostxt):
                candidates = extract_candidate_chunks(lemmposst)
                print(candidates)
                for cand in candidates:
                    if cand not in lemmws:
                        lemmws.append(cand)
                lemmposrecs.append((
                                'f_'+forumpostID,
                                u["user"],
                                str(i)+'_'+str(ii),
                                lemmposst,
                                candidates
                                ))
            count += 1

    print("number of treated posts (len(count)) ::", count)
    print("lemm errs:", lemerrors)
    #return all_posedsts, forum_ids
    return lemmposrecs, nltk.FreqDist(lemmws)

# %%
def cleaningtext(st, STOPWORDS = nltk.corpus.stopwords.words('english')):
    treated_st = []
    countwds = len(st)
    for w in st:
        if 'freecodecamp' in w:
            w = w.replace('freecodecamp','fcc')
        treated_st.append(w)
    return treated_st, countwds

# %%
############################
## gensim_models2 re-evaluated: modification of gensim_model2's cleanedsts_from_lemmpostxts to fit keyphrases
############################

def gensim_models2(lemmposrecs, NUM_TOPICS = 15, lemmws_fd = {}, wordimportance = {}, nltk = nltk, gensim = gensim):
    
    def cleanedsts_from_lemmpostxts2(lemmposrecs, STOPWORDS = nltk.corpus.stopwords.words('english')):
        redo_corpus_by_sts = []
        for lemmpos_r in lemmposrecs:
            candidates = lemmpos_r[4]
            treated_lemmcands = cleaningtext(candidates)[0] #passing candidates only
            redo_corpus_by_sts.append(treated_lemmcands) 
        
        #print(len(redo_corpus_by_sts), redo_corpus_by_sts[-1])
        return redo_corpus_by_sts
        
    def basedonBOW(redo_corpus_by_sts):
        dictionary = gensim.corpora.Dictionary(redo_corpus_by_sts) #[token for st in redo_corpus_by_sts for token in st]
        corpus = [dictionary.doc2bow(text) for text in redo_corpus_by_sts]
        return corpus, dictionary
    
    def basedonTFIDF(corpus):
        return gensim.models.TfidfModel(corpus)
    
    def basedonOTHER(redo_corpus_by_sts, dictionary, wordimportance):
        
        def metriccalc(w):
            if w in wordimportance:
                return 1.0+2.0**float(wordimportance[w])
            else:
                return 0.0

        corpus = []
        for sts in redo_corpus_by_sts:
            st = []
            for w in sts:
                st.append((dictionary.token2id[w], metriccalc(w)))
            corpus.append(st)
        return corpus
        
    
    redo_corpus_by_sts  = cleanedsts_from_lemmpostxts2(lemmposrecs)
    
    corpus, dictionary = basedonBOW(redo_corpus_by_sts)
    if wordimportance == {'tfidf':True}:
        tfidf = basedonTFIDF(corpus)
        corpus = tfidf[corpus]
    if wordimportance != {} and wordimportance != {'tfidf':True}:
        corpus = basedonOTHER(redo_corpus_by_sts, dictionary, wordimportance)
    
    
    lda_model = gensim.models.LdaModel(corpus=corpus, num_topics=NUM_TOPICS, minimum_probability=0.005, per_word_topics = True, minimum_phi_value = 0.001, id2word=dictionary)
    lsi_model = gensim.models.LsiModel(corpus=corpus, num_topics=NUM_TOPICS, id2word=dictionary)

   
    return lda_model, lsi_model, redo_corpus_by_sts, corpus, dictionary

# %%
with open('../data/jobproject_forum.json','r') as message:
    otp = json.load(message)
print(len(otp))
allrecords = [{ "user": k, "data": otp[k] }  for k in otp]
print(len(allrecords))
# Out:
# 90
# 90

# %%
lemmposrecs, lemmws_fd = allrecordsPreparation3(allrecords)
# Out:
# in allrecordsPreparation (len(allrecords)):: 90
# Error (not in corpus) everybody NN
# Error (not in corpus) , ,
# pos KeyErrors i JJ
# Error (not in corpus) 've VBP
# pos KeyErrors two CD
# pos KeyErrors full JJ
# Error (not in corpus) , ,
# pos KeyErrors all DT
# Error (not in corpus) to TO
# IndexErrors (POS not found) fcc VB
# Error (not in corpus) . .
# pos KeyErrors one CD
# pos KeyErrors mean JJ
# pos KeyErrors while IN
# Error (not in corpus) the DT
# pos KeyErrors other JJ
# Error (not in corpus) ror VBP
# Error (not in corpus) + JJ
# pos KeyErrors angular JJ
# Error (not in corpus) + NN
# Error (not in corpus) postgresql NN
# Error (not in corpus) . .
# pos KeyErrors a DT
# pos KeyErrors brief JJ
# pos KeyErrors about IN
# Error (not in corpus) myself PRP
# Error (not in corpus) : :
# pos KeyErrors in IN
# Error (not in corpus) . .
# Error (not in corpus) 've VBP
# Error (not in corpus) my PRP$
# pos KeyErrors in IN
# pos KeyErrors signal JJ
# Error (not in corpus) . .
# Error (not in corpus) 've VBP
# pos KeyErrors on IN
# pos KeyErrors audio JJ
# Error (not in corpus) codecs NN
# Error (not in corpus) , ,
# pos KeyErrors like IN
# Error (not in corpus) atmos NN
# Error (not in corpus) , ,
# Error (not in corpus) dd+ NN
# Error (not in corpus) , ,
# Error (not in corpus) etc NN
# Error (not in corpus) for IN
# pos KeyErrors two CD
# Error (not in corpus) for IN
# pos KeyErrors a DT
# Error (not in corpus) which WDT
# Error (not in corpus) , ,
# pos KeyErrors few JJ
# pos KeyErrors across IN
# Error (not in corpus) the DT
# Error (not in corpus) . .
# pos KeyErrors one CD
# Error (not in corpus) of IN
# Error (not in corpus) them PRP
# Error (not in corpus) . .
# Error (not in corpus) to TO
# pos KeyErrors about IN
# pos KeyErrors fcc JJ
# Error (not in corpus) via IN
# Error (not in corpus) 's POS
# Error (not in corpus) quora JJ
# Error (not in corpus) . .
# Error (not in corpus) my PRP$
# Error (not in corpus) and CC
# Error (not in corpus) of IN
# pos KeyErrors on IN
# Error (not in corpus) the DT
# pos KeyErrors same JJ
# pos KeyErrors professional JJ
# Error (not in corpus) i.e NN
# Error (not in corpus) . .
# Error (not in corpus) codecs NN
# Error (not in corpus) and CC
# pos KeyErrors all DT
# Error (not in corpus) , ,
# pos KeyErrors on IN
# pos KeyErrors fcc JJ
# Error (not in corpus) . .
# pos KeyErrors after IN
# pos KeyErrors 6 CD
# Error (not in corpus) of IN
# pos KeyErrors hard JJ
# Error (not in corpus) , ,
# pos KeyErrors i JJ
# Error (not in corpus) 've VBP
# Error (not in corpus) myself PRP
# pos KeyErrors two CD
# pos KeyErrors full JJ
# Error (not in corpus) ( (
# Error (not in corpus) the DT
# pos KeyErrors best JJS
# Error (not in corpus) , ,
# pos KeyErrors both DT
# pos KeyErrors remote JJ
# Error (not in corpus) ) )
# Error (not in corpus) . .
# pos KeyErrors i JJ
# pos KeyErrors will MD
# Error (not in corpus) from IN
# Error (not in corpus) for IN
# pos KeyErrors both DT
# Error (not in corpus) 70-80hrs CD
# pos KeyErrors a DT
# Error (not in corpus) . .
# Error (not in corpus) to TO
# pos KeyErrors much JJ
# pos KeyErrors as IN
# pos KeyErrors can MD
# Error (not in corpus) , ,
# IndexErrors (POS not found) hence VB
# Error (not in corpus) the DT
# Error (not in corpus) . .
# Error (not in corpus) to TO
# Error (not in corpus) beginners:1 VB
# Error (not in corpus) ) )
# Error (not in corpus) n't RB
# Error (not in corpus) 'why NNP
# Error (not in corpus) ' POS
# Error (not in corpus) and CC
# Error (not in corpus) 'how NNP
# Error (not in corpus) ' POS
# Error (not in corpus) . .
# pos KeyErrors it PRP
# pos KeyErrors may MD
# Error (not in corpus) ' ''
# Error (not in corpus) , ,
# pos KeyErrors but CC
# Error (not in corpus) that DT
# Error (not in corpus) 's VBZ
# Error (not in corpus) what WP
# Error (not in corpus) for IN
# Error (not in corpus) me.2 NN
# Error (not in corpus) ) )
# Error (not in corpus) n't RB
# pos KeyErrors on IN
# Error (not in corpus) . .
# Error (not in corpus) , ,
# Error (not in corpus) stackoverflow VB
# Error (not in corpus) . .
# pos KeyErrors few JJ
# IndexErrors (POS not found) online NN
# Error (not in corpus) . .
# Error (not in corpus) coursera NN
# pos KeyErrors full JJ
# Error (not in corpus) for IN
# pos KeyErrors mean JJ
# Error (not in corpus) . .
# Error (not in corpus) this DT
# pos KeyErrors me PRP
# pos KeyErrors some DT
# pos KeyErrors good JJ
# Error (not in corpus) concepts.3 NN
# Error (not in corpus) ) )
# Error (not in corpus) and CC
# Error (not in corpus) , ,
# Error (not in corpus) n't RB
# Error (not in corpus) the DT
# pos KeyErrors or CC
# Error (not in corpus) . .
# Error (not in corpus) ! .
# pos KeyErrors a DT
# Error (not in corpus) ! .
# IndexErrors (POS not found) i RB
# Error (not in corpus) would MD
# Error (not in corpus) to TO
# Error (not in corpus) from IN
# Error (not in corpus) the DT
# Error (not in corpus) of IN
# Error (not in corpus) my PRP$
# Error (not in corpus) for IN
# Error (not in corpus) and CC
# Error (not in corpus) this DT
# pos KeyErrors great JJ
# Error (not in corpus) . .
# Error (not in corpus) without IN
# Error (not in corpus) would MD
# Error (not in corpus) this DT
# Error (not in corpus) . .
# ['hello', 'NN', 'B-KT', 'everybody', 'NN', 'I-KT', ',', ',', 'O', "'ve", 'VBP', 'O', 'get', 'VBN', 'O', 'two', 'CD', 'O', 'full', 'JJ', 'B-KT', 'stack', 'NN', 'I-KT', 'developer', 'NN', 'I-KT', 'job', 'NN', 'I-KT', 'offer', 'NNS', 'I-KT', ',', ',', 'O', 'thanks', 'NNS', 'B-KT', 'fcc', 'VB', 'O', '.', '.', 'O']
# <itertools.groupby object at 0x7f89dd502ea8>
# True <itertools._grouper object at 0x7f89dd540828>
# /home/ec/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-9aa438269348> in <module>()
# ----> 1 lemmposrecs, lemmws_fd = allrecordsPreparation3(allrecords)
#
# <ipython-input-7-43d058b9605e> in allrecordsPreparation3(allrecords, STOPWORDS, punct)
#     144             ## Adding data to the new created dataset
#     145             for ii, lemmposst in enumerate(lemmpostxt):
# --> 146                 candidates = extract_candidate_chunks(lemmposst)
#     147                 for cand in candidates:
#     148                     if cand not in lemmws:
#
# <ipython-input-21-f27be3bfe2d0> in extract_candidate_chunks(lemmposst, grammar, STOPWORDS)
#      27         print(key, group)
#      28         if key:
# ---> 29             for x in group:
#      30                 #print(x)
#      31                 candidates.append(x)
#
# <ipython-input-21-f27be3bfe2d0> in <lambda>(w_TUPLE)
#      24     candidates = []
#      25     print(itertools.groupby(all_chunks, lambda w_TUPLE: w_TUPLE[2] != 'O'))
# ---> 26     for key, group in itertools.groupby(all_chunks, lambda w_TUPLE: w_TUPLE[2] != 'O'):
#      27         print(key, group)
#      28         if key:
#
# IndexError: string index out of range

# %%
lda_model, lsi_model, redo_corpus_by_sts, corpus, dictionary = gensim_models2(lemmposrecs, 
                                                                                NUM_TOPICS=20,
                                                                                wordimportance = {'tfidf':True})

# %%
lda_model.print_topics(num_words=20)
# Out:
# [(0,
#   '0.008*"interview" + 0.007*"career" + 0.007*"month" + 0.005*"email job offer morning" + 0.005*"new career front" + 0.005*"people “hey" + 0.005*"idea type question" + 0.005*"year full time job" + 0.005*"way networking" + 0.005*"feel"'),
#  (1,
#   '0.023*"company" + 0.014*"job" + 0.009*"interview" + 0.007*"portfolio" + 0.006*"start" + 0.006*"month" + 0.005*"process" + 0.005*"prototype" + 0.005*"lot" + 0.005*"fcc"'),
#  (2,
#   '0.007*"dream job" + 0.006*"something" + 0.005*"way" + 0.005*"anything" + 0.005*"lot" + 0.004*"interview" + 0.004*"time" + 0.004*"code" + 0.004*"big thanks camper anywho" + 0.004*"informed decision possible company"'),
#  (3,
#   '0.010*"job" + 0.010*"company" + 0.010*"day" + 0.010*"fcc" + 0.009*"opportunity" + 0.007*"hey fellow camper" + 0.007*"year" + 0.006*"interview process" + 0.006*"month" + 0.005*"something"'),
#  (4,
#   '0.009*"github" + 0.008*"bit" + 0.008*"story" + 0.007*"time" + 0.007*"information" + 0.005*"shot" + 0.004*"fcc" + 0.004*"advice" + 0.004*"growth past self" + 0.004*"one"'),
#  (5,
#   '0.012*"week" + 0.006*"thats" + 0.005*"process" + 0.005*"hi everyone" + 0.005*"day" + 0.004*"summer" + 0.004*"code line line" + 0.004*"next month" + 0.004*"google" + 0.004*"indonesia"'),
#  (6,
#   '0.009*"code" + 0.008*"project" + 0.006*"recruiter" + 0.006*"others" + 0.004*"share" + 0.004*"data structure algorithm way" + 0.004*"omg" + 0.004*"portfolio reference" + 0.004*"real code" + 0.004*"example"'),
#  (7,
#   '0.010*"opportunity" + 0.006*"yesterday" + 0.006*"job" + 0.005*"interview job" + 0.005*"resume" + 0.005*"try" + 0.004*"help" + 0.004*"developer" + 0.004*"web dev" + 0.004*"work"'),
#  (8,
#   '0.015*"thank" + 0.007*"portfolio" + 0.006*"job" + 0.006*"question" + 0.005*"interview" + 0.005*"call" + 0.005*"impression" + 0.005*"web development" + 0.004*"project" + 0.004*"front end full stack developer job last tuesday"'),
#  (9,
#   '0.009*"interview" + 0.007*"thanks" + 0.007*"challenge" + 0.007*"project" + 0.007*"thing" + 0.006*"fcc" + 0.005*"junior" + 0.005*"javascript" + 0.004*"year" + 0.004*"opposite in-house"'),
#  (10,
#   '0.013*"break" + 0.011*"thanks" + 0.007*"job" + 0.006*"time" + 0.006*"task" + 0.005*"site" + 0.005*"experience" + 0.005*"end" + 0.004*"people" + 0.004*"logical person"'),
#  (11,
#   '0.011*"lot" + 0.006*"goal" + 0.006*"way" + 0.006*"job" + 0.006*"developer" + 0.005*"udacity" + 0.005*"everyone" + 0.005*"time" + 0.004*"fcc" + 0.004*"job application"'),
#  (12,
#   '0.014*"interview" + 0.010*"thank" + 0.008*"job" + 0.006*"first developer job" + 0.006*"edit" + 0.005*"project" + 0.005*"year experience" + 0.004*"mountain" + 0.004*"fcc blog" + 0.004*"right call"'),
#  (13,
#   '0.014*"fcc" + 0.009*"year" + 0.008*"thing" + 0.007*"advice" + 0.006*"job" + 0.006*"lot" + 0.006*"offer" + 0.005*"interview" + 0.005*"employer" + 0.005*"project"'),
#  (14,
#   '0.009*"happy coding" + 0.007*"time" + 0.005*"developer" + 0.004*"cheer" + 0.004*"nope" + 0.004*"online course university like harvard princeton" + 0.004*"all.6" + 0.004*"coursera full stack course mean stack" + 0.004*"thing lot" + 0.004*"learning"'),
#  (15,
#   '0.010*"people" + 0.009*"job" + 0.007*"something" + 0.007*"application" + 0.007*"company" + 0.006*"way" + 0.005*"question" + 0.004*"skill" + 0.004*"look code project month" + 0.004*"good company excited new step"'),
#  (16,
#   '0.014*"people" + 0.008*"company" + 0.007*"job" + 0.007*"project" + 0.006*"resume" + 0.004*"today" + 0.004*"experience" + 0.004*"year" + 0.004*"next day" + 0.004*"article"'),
#  (17,
#   '0.015*"time" + 0.010*"experience" + 0.006*"year" + 0.005*"day" + 0.005*"thing" + 0.005*"merry christmas" + 0.005*"learn javascript" + 0.005*"guy" + 0.005*"front-end certificate end october" + 0.005*"online course"'),
#  (18,
#   '0.011*"month" + 0.011*"much time" + 0.010*"job" + 0.008*"day" + 0.008*"many time" + 0.007*"first interview" + 0.007*"complex application" + 0.005*"august" + 0.005*"part journey" + 0.005*"stuff"'),
#  (19,
#   '0.016*"job" + 0.009*"company" + 0.008*"candidate" + 0.007*"month" + 0.007*"time" + 0.005*"chance" + 0.005*"resume" + 0.005*"last month" + 0.005*"interview" + 0.004*"structured curriculum nice community"')]

# %%
#lda_model, lsi_model, redo_corpus_by_sts, corpus, dictionary = gensim_models2(lemmposrecs, 
#                                                                                NUM_TOPICS=20,
#                                                                                wordimportance = {'tfidf':True})

#lda_model.print_topics(num_words=15)

#[' '.join([l for wr in rec[3] for w,_,l,pos in wr]) for rec in lemmposrecs]
#[[l for wr in rec[3] for w,_,l,pos in wr] for rec in lemmposrecs]
#[' '.join([cand for cand in rec[4]]) for rec in lemmposrecs]
##https://stackoverflow.com/questions/46282473/error-while-identify-the-coherence-value-from-lda-model
#texts = [[dictionary[word_id] for word_id, freq in doc] for doc in corpus]
#texts

#coherence_model_lda = gensim.models.coherencemodel.CoherenceModel(model=lda_model, 
#                                                                  texts=texts,
#                                                                  #corpus=corpus,
#                                                                  window_size=20,
#                                                                  dictionary=dictionary, 
#                                                                  coherence='c_uci')
#coherence_lda = coherence_model_lda.get_coherence()
#print('\nCoherence Score: ', coherence_lda)

#coherence_model_lda = gensim.models.CoherenceModel(model=lda_model, 
#                                                   texts=texts, 
#                                                   dictionary=dictionary,
#                                                   coherence='c_v')
#coherence_lda = coherence_model_lda.get_coherence()
#print('\nCoherence Score: ', coherence_lda)

## Compute Coherence Score using UMass
#coherence_model_lda = gensim.models.coherencemodel.CoherenceModel(model=lda_model, 
#                                     #texts=[[l for wr in rec[3] for w,_,l,pos in wr] for rec in lemmposrecs],
#                                     corpus = corpus,
#                                     dictionary=dictionary, 
#                                     coherence="u_mass")
#coherence_lda = coherence_model_lda.get_coherence()
#print('\nCoherence Score: ', coherence_lda)

#print('\nPerplexity: ', lda_model.log_perplexity(corpus))

#dictionary
#corpus

# %%
TOPICS = range(2,61,2)
cv_coherence_values = []
for numtopics in TOPICS:
    print('\n\nFor NUM_TOPICS:', numtopics)
    lda_model, lsi_model, redo_corpus_by_sts, corpus, dictionary = gensim_models2(lemmposrecs, NUM_TOPICS=numtopics, wordimportance = {'tfidf':True})
    umass_coherence_model_lda = gensim.models.coherencemodel.CoherenceModel(model=lda_model, 
                                     #texts=[[l for wr in rec[3] for w,_,l,pos in wr] for rec in lemmposrecs],
                                     corpus = corpus,
                                     dictionary=dictionary, 
                                     coherence="u_mass")
    umass_coherence_lda = umass_coherence_model_lda.get_coherence()
    print('U-Mass Coherence Score: ', umass_coherence_lda)
    texts = [[dictionary[word_id] for word_id, freq in doc] for doc in corpus]
    cv_coherence_model_lda = gensim.models.coherencemodel.CoherenceModel(model=lda_model, 
                                     texts=texts,
                                     dictionary=dictionary, 
                                     coherence="c_v")
    cv_coherence_lda = cv_coherence_model_lda.get_coherence()
    cv_coherence_values.append(cv_coherence_lda)
    print('C_V Coherence Score: ', cv_coherence_lda)
    print('Perplexity: ', lda_model.log_perplexity(corpus))
# Out:
# For NUM_TOPICS: 2
# U-Mass Coherence Score:  -16.8938695279
# C_V Coherence Score:  0.703913103146
# Perplexity:  -8.7284637134
#
#
# For NUM_TOPICS: 4
# U-Mass Coherence Score:  -18.7447908539
# C_V Coherence Score:  0.730136518244
# Perplexity:  -9.3836907216
#
#
# For NUM_TOPICS: 6
# U-Mass Coherence Score:  -19.1548461816
# C_V Coherence Score:  0.733100807884
# Perplexity:  -9.85884336249
#
#
# For NUM_TOPICS: 8
# U-Mass Coherence Score:  -19.4453592718
# C_V Coherence Score:  0.737096786502
# Perplexity:  -10.1959791013
#
#
# For NUM_TOPICS: 10
# U-Mass Coherence Score:  -19.8066344133
# C_V Coherence Score:  0.741129762466
# Perplexity:  -10.4754780786
#
#
# For NUM_TOPICS: 12
# U-Mass Coherence Score:  -20.1601416735
# C_V Coherence Score:  0.74934387646
# Perplexity:  -10.7261846838
#
#
# For NUM_TOPICS: 14
# U-Mass Coherence Score:  -20.7302062511
# C_V Coherence Score:  0.771180986817
# Perplexity:  -10.9378839042
#
#
# For NUM_TOPICS: 16
# U-Mass Coherence Score:  -21.0295925544
# C_V Coherence Score:  0.778190714878
# Perplexity:  -11.1030033992
#
#
# For NUM_TOPICS: 18
# U-Mass Coherence Score:  -20.9555783306
# C_V Coherence Score:  0.783075079111
# Perplexity:  -11.2828366017
#
#
# For NUM_TOPICS: 20
# U-Mass Coherence Score:  -21.0197322644
# C_V Coherence Score:  0.78688712894
# Perplexity:  -11.4046833774
#
#
# For NUM_TOPICS: 22
# U-Mass Coherence Score:  -20.9066233282
# C_V Coherence Score:  0.785121485354
# Perplexity:  -11.5669377168
#
#
# For NUM_TOPICS: 24
# U-Mass Coherence Score:  -21.120874692
# C_V Coherence Score:  0.793166110398
# Perplexity:  -11.6831998283
#
#
# For NUM_TOPICS: 26
# U-Mass Coherence Score:  -20.9524255807
# C_V Coherence Score:  0.787499102966
# Perplexity:  -11.7993013914
#
#
# For NUM_TOPICS: 28
# U-Mass Coherence Score:  -20.8659729101
# C_V Coherence Score:  0.784202514327
# Perplexity:  -11.9171770116
#
#
# For NUM_TOPICS: 30
# U-Mass Coherence Score:  -20.8548504852
# C_V Coherence Score:  0.78187671157
# Perplexity:  -12.0323592412
#
#
# For NUM_TOPICS: 32
# U-Mass Coherence Score:  -20.742168939
# C_V Coherence Score:  0.775509227235
# Perplexity:  -12.1105403903
#
#
# For NUM_TOPICS: 34
# U-Mass Coherence Score:  -20.7275467819
# C_V Coherence Score:  0.774122590269
# Perplexity:  -12.2161112633
#
#
# For NUM_TOPICS: 36
# U-Mass Coherence Score:  -20.6996937059
# C_V Coherence Score:  0.774976637329
# Perplexity:  -12.2973978874
#
#
# For NUM_TOPICS: 38
# U-Mass Coherence Score:  -20.6149946127
# C_V Coherence Score:  0.770739950698
# Perplexity:  -12.3674476054
#
#
# For NUM_TOPICS: 40
# U-Mass Coherence Score:  -20.671330362
# C_V Coherence Score:  0.766511337083
# Perplexity:  -12.4236651685
#
#
# For NUM_TOPICS: 42
# U-Mass Coherence Score:  -20.6530010122
# C_V Coherence Score:  0.769011564783
# Perplexity:  -12.5525407089
#
#
# For NUM_TOPICS: 44
# U-Mass Coherence Score:  -20.5570116288
# C_V Coherence Score:  0.760463846924
# Perplexity:  -12.5762535029
#
#
# For NUM_TOPICS: 46
# U-Mass Coherence Score:  -20.4911899447
# C_V Coherence Score:  0.751228324996
# Perplexity:  -12.6466188019
#
#
# For NUM_TOPICS: 48
# U-Mass Coherence Score:  -20.5293649799
# C_V Coherence Score:  0.752849375608
# Perplexity:  -12.7603708581
#
#
# For NUM_TOPICS: 50
# U-Mass Coherence Score:  -20.4135103793
# C_V Coherence Score:  0.741699229103
# Perplexity:  -12.7915243523
#
#
# For NUM_TOPICS: 52
# U-Mass Coherence Score:  -20.4244529985
# C_V Coherence Score:  0.74127961921
# Perplexity:  -12.8448269887
#
#
# For NUM_TOPICS: 54
# U-Mass Coherence Score:  -20.369923714
# C_V Coherence Score:  0.736449777636
# Perplexity:  -12.92358774
#
#
# For NUM_TOPICS: 56
# U-Mass Coherence Score:  -20.2989870264
# C_V Coherence Score:  0.726533785587
# Perplexity:  -12.9450654898
#
#
# For NUM_TOPICS: 58
# U-Mass Coherence Score:  -20.2927208387
# C_V Coherence Score:  0.728114546408
# Perplexity:  -13.0373906911
#
#
# For NUM_TOPICS: 60
# U-Mass Coherence Score:  -20.2238922281
# C_V Coherence Score:  0.720738029116
# Perplexity:  -13.1077758349

# %%
#https://www.quora.com/Can-I-combine-LSI-and-K-means-for-text-document-clustering-Are-there-any-sources-to-learn-about-it
#http://sujitpal.blogspot.com/2014/08/topic-modeling-with-gensim-over-past.html

# %%
##https://stackoverflow.com/questions/14261903/how-can-i-open-the-interactive-matplotlib-window-in-ipython-notebook
# %matplotlib inline 
import matplotlib.pyplot as plt
limit=61; start=2; step=2;
x = range(start, limit, step)
plt.plot(x, cv_coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
lda_model, lsi_model, redo_corpus_by_sts, corpus, dictionary = gensim_models2(lemmposrecs, NUM_TOPICS=40, wordimportance = {'tfidf':True})

# %%
lda_model.print_topics(num_topics=40)

# %%
lda_model, lsi_model, redo_corpus_by_sts, corpus, dictionary = gensim_models2(lemmposrecs, NUM_TOPICS=30, wordimportance = {'tfidf':True})

# %%
lsi_model.print_topics(num_topics=30, num_words=15)

# %% [markdown]
# ### TODO
# k-means to approximate the number of topics before trying a more elaborate form
# Check and improve previous work:
# * https://github.com/evaristoc/fccgitterDataScience/blob/master/Identifying%20Relevant%20Topics%20in%20a%20Chatroom.ipynb
# * https://stackoverflow.com/questions/24816912/number-of-latent-semantic-indexing-topics
# * https://stackoverflow.com/questions/9582291/how-do-we-decide-the-number-of-dimensions-for-latent-semantic-analysis/9759218#9759218
# Also check:
# * https://datascienceplus.com/evaluation-of-topic-modeling-topic-coherence/
# * https://radimrehurek.com/gensim/models/hdpmodel.html
# * https://datascience.stackexchange.com/questions/128/latent-dirichlet-allocation-vs-hierarchical-dirichlet-process
# * https://nlpforhackers.io/recipe-text-clustering/
# * https://www.quora.com/Latent-Dirichlet-Allocation-LDA-What-is-the-best-way-to-determine-k-number-of-topics-in-topic-modeling
# * http://nbviewer.jupyter.org/github/bmabey/hacker_news_topic_modelling/blob/master/HN%20Topic%20Model%20Talk.ipynb#topic=3&lambda=1&term=
# * https://stackoverflow.com/questions/50106516/k-means-for-topic-modelling-elbow-method
# * https://shuaiw.github.io/2016/12/22/topic-modeling-and-tsne-visualzation.html
# * http://wdsinet.org/Annual_Meetings/2016_Proceedings/papers/Paper45.pdf
# * http://ramet.elte.hu/~podani/Methods.htm
# * https://hk.saowen.com/a/edc29232eae094158f66e8ff3f08d6f35b8a2a45d628fce8917d2dce6f94282e
# * https://rare-technologies.com/validating-gensims-topic-coherence-pipeline/
# * http://sujitpal.blogspot.com/2014/08/topic-modeling-with-gensim-over-past.html
# * https://www.searchenginejournal.com/latent-semantic-indexing-wont-help-seo/240705/

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import Normalizer
from sklearn import metrics
from sklearn.cluster import KMeans

NUM_CLUSTERS = 8

from scipy.spatial.distance import cdist, pdist
K = list(range(1, n_components+1))
KM = [KMeans(n_clusters=k).fit(X) for k in K]
centroids = [k.cluster_centers_ for k in KM]

D_k = [cdist(X, cent, 'euclidean') for cent in centroids]
cIdx = [numpy.argmin(D,axis=1) for D in D_k]
dist = [numpy.min(D,axis=1) for D in D_k]
avgWithinSS = [sum(d)/X.shape[0] for d in dist]


kIdx = 8-1

# elbow curve
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(K, avgWithinSS, 'b*-')
ax.plot(K[kIdx], avgWithinSS[kIdx], marker='o', markersize=12, 
markeredgewidth=2, markeredgecolor='r', markerfacecolor='None')
plt.grid(True)
plt.xlabel('Number of clusters')
plt.ylabel('Average within-cluster sum of squares')
plt.title('Elbow for KMeans clustering')


###############################################################################
# Do the actual clustering

true_k = 8


km = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)

print("Clustering sparse data with %s" % km)
newX = numpy.array(pandas.concat([pandas.DataFrame(X),datadf_foran['timestamp_norm'].reset_index()['timestamp_norm']],axis=1))
km.fit(newX)

print()

labels = [x for x in range(datadf_foran.shape[0])]
print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels, km.labels_))
print("Completeness: %0.3f" % metrics.completeness_score(labels, km.labels_))
print("V-measure: %0.3f" % metrics.v_measure_score(labels, km.labels_))
print("Adjusted Rand-Index: %.3f"
      % metrics.adjusted_rand_score(labels, km.labels_))
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(newX, km.labels_, sample_size=1000))

print()


fig_clusters = plt.figure()
fig_clusters.suptitle('Clusters over first 2 Components')
ax = fig_clusters.add_subplot(111)
ax.set_xlabel('Component I')
ax.set_ylabel('Component II')
plt.scatter(newX[:,0],newX[:,1], c=km.fit_predict(newX))
plt.show()

# %% [markdown]
# ### TODO

# %%
############################
## raw_lda_frankjupyter2: modified to fit allrecordsPreparation2
############################
def raw_lda_frankjupyter2(lemmposrecs, wordimportance, metmodel=2, STOPWORDS=nltk.corpus.stopwords.words('english')):
    '''
    description: modified model based on https://www.frankcleary.com/svd/ for a more raw construction of a lda
    '''
    
   
    def metriccalc(st, normalizer, wordimportance):
        '''
        description:
        text normalization based on ALL characters in the sentence; why? Example: if two writers wrote 20 words, 2 of them very important, but one of them wrote half of characters stopwords, those 2 words wouldnt be penalized accordingly for this writer: the other wrote more important content
        '''       
        metfuncs = [
            lambda w: math.pow(0.1+float(wordimportance[w]),textbow[w]/normalizer) if w in list(wordimportance.keys()) else 0.0, #a sort of idf-normalization based on number of words in the text: the more the words in a text, the more important
            lambda w: float(wordimportance[w])*textbow[w] if w in list(wordimportance.keys()) else 0.0, #good but ignore those words with worimportance too low or 0 but that are frequent in text
            lambda w: 1.0+2.0**float(wordimportance[w]) if w in list(wordimportance.keys()) else 0.0, #<- probably the best one; because it is not normilized this indicator would simply say that if it has the word at least once is already on topic
            lambda w: float(wordimportance[w]) + textbow[w]/normalizer if w in list(wordimportance.keys()) else 0.0,
            lambda w: (1.0+textbow[w]/normalizer)*float(wordimportance[w]) if w in list(wordimportance.keys()) else 0.0, #<- apparently the second best with the adhoc word ranking
            lambda w: normalizer/textbow[w]*wordimportance[w]/sum(list(wordimportance.values())), #tfidf-ish
            lambda w: float(wordimportance[w]) if w in list(wordimportance.keys()) else 0.0
        ]
        likedict = collections.defaultdict(float)
        textbow = collections.Counter(st)
        for w in st:
            likedict[w] = metfuncs[metmodel](w)
        return likedict

    #redo_corpus_by_sts = []
    words_df = pandas.DataFrame()
    textreference = {}
    
    
    for textindex, lemmpos_r in enumerate(lemmposrecs):
        lemmpos_t = lemmpos_r[3]
        #print('lemmpos_t', len(lemmpos_t))
        lemm_sts = ''
        for lemmpos_TUPLE in lemmpos_t:
            w = lemmpos_TUPLE[2]
            lemm_sts = lemm_sts + w + ' '
        sts = lemm_sts.split('.')
        for stindex, lemmpos_st in enumerate(sts):
            treated_st, lensts = cleaningtext(lemmpos_st.split(), STOPWORDS=STOPWORDS)        
            #print('treated_st', lensts)
            if len(treated_st) > 3:
                likedict = metriccalc(treated_st, lensts, wordimportance)
                st_df = pandas.DataFrame.from_dict(likedict, orient='index')
                textindexing = str(textindex)+'_'+str(stindex)
                st_df.columns = [textindexing]
                textreference[textindexing] = {}
                textreference[textindexing]['treated_st'] = treated_st
                #st_df.columns = [str(count)]
                words_df = words_df.join(st_df, how='outer', )
    
    words_df = words_df.fillna(0)
    print("Number of unique words: %s" % len(words_df))
    print(words_df.head(10))
    #print(words_df.sort(columns=words_df.columns[0], ascending=False).head(10))
    
    return words_df, textreference
